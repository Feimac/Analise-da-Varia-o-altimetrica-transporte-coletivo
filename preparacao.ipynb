# %%
import pandas as pd
import geopandas as gpd
from shapely import wkb
import matplotlib.pyplot as plt
import folium
# === 1. Ler CSV ===

dados_altimetria_4326 = pd.read_csv('alt_curva_de_nivel.csv')
dados_linhas_4326 = pd.read_csv('dados_shapes_onibus_urbs_consolidado_threads.csv')
dados_pontos = pd.read_csv('dados_pontos_onibus_urbs_consolidado_threads.csv')

# %%
dados_pontos
# Out:
#                                             NOME     NUM   Latitude  \
# 0           Rua Des. Westphalen, 1345 - Rebouças  110061 -25.444264
# 1              Rua Lamenha Lins, 1592 - Rebouças  150721 -25.449942
# 2      R. Myltho Anselmo da Silva, 1160 - Mercês  110134 -25.419373
# 3          Rua Arthur Leinig, 785 - Vista Alegre  190977 -25.409838
# 4               Rua Alferes Poli, 787 - Rebouças  110024 -25.443478
# ...                                          ...     ...        ...
# 13193             Av. Luiz Xavier - Boca Maldita  110206 -25.432103
# 13194                             Memorial Árabe  110002 -25.423637
# 13195              Rua Jacarezinho, 620 - Mercês  190211 -25.423812
# 13196                              Bosque Alemão  190419 -25.407180
# 13197     Praça Tiradentes - 979 - Linha Turismo  101016 -25.429586
#
#        Longitude  SEQ  GRUPO    SENTIDO             TIPO  ID_do_Itinerario  \
# 0     -49.267577   28    NaN  Guanabara  Novo mobiliário             13513
# 1     -49.270820   32    NaN  Guanabara  Novo mobiliário             13513
# 2     -49.287072   15    NaN  Guanabara  Novo mobiliário             13513
# 3     -49.291969    9    NaN  Guanabara   Sem demarcação             13513
# 4     -49.270141   13    NaN  Jd Mercês  Novo mobiliário             13533
# ...          ...  ...    ...        ...              ...               ...
# 13193 -49.274256   29    NaN    Turismo    Linha Turismo              1065
# 13194 -49.268607    9    NaN    Turismo    Linha Turismo              1065
# 13195 -49.294582   26    NaN    Turismo    Linha Turismo              1065
# 13196 -49.284990   13    NaN    Turismo    Linha Turismo             10253
# 13197 -49.271544   28    NaN    Turismo    Linha Turismo              1065
#
#        COD
# 0      160
# 1      160
# 2      160
# 3      160
# 4      160
# ...    ...
# 13193  979
# 13194  979
# 13195  979
# 13196  979
# 13197  979
#
# [13198 rows x 10 columns]

# %%
dados_linhas_4326 = dados_linhas_4326[dados_linhas_4326['COD'] == 500].reset_index(drop=True)
dados_linhas_4326 = dados_linhas_4326[dados_linhas_4326['SHP'] == 1940].reset_index(drop=True)

# %%
dados_linhas_4326 = dados_linhas_4326[dados_linhas_4326['COD'] == 521].reset_index(drop=True)
dados_linhas_4326 = dados_linhas_4326[dados_linhas_4326['SHP'] == 1964].reset_index(drop=True)

# %%
dados_linhas_4326
# Out:
#       SHP   Latitude  Longitude  COD
# 0    1940 -25.516848 -49.230057  500
# 1    1940 -25.516868 -49.230132  500
# 2    1940 -25.516920 -49.230100  500
# 3    1940 -25.517024 -49.230042  500
# 4    1940 -25.517186 -49.229950  500
# ..    ...        ...        ...  ...
# 555  1940 -25.433545 -49.269572  500
# 556  1940 -25.433583 -49.269682  500
# 557  1940 -25.433632 -49.269817  500
# 558  1940 -25.433678 -49.269951  500
# 559  1940 -25.433788 -49.270266  500
#
# [560 rows x 4 columns]

# %%
def converte_srid(df):

  # Criar geometria de pontos a partir das colunas Longitude e Latitude
  gdf = gpd.GeoDataFrame(
      df,
      geometry=gpd.points_from_xy(df['Longitude'], df['Latitude']),
      crs="EPSG:4326"  # Sistema original (WGS 84)
  )
  # Reprojetar para EPSG:3a1982 (SIRGAS 2000 / UTM zone 22S)
  gdf_utm = gdf.to_crs(epsg=31982)
  return gdf_utm


def define_crs_srid(df):
    from shapely import wkb
    import geopandas as gpd

    def safe_wkb_to_geom(hex_wkb):
        if isinstance(hex_wkb, str):
            return wkb.loads(bytes.fromhex(hex_wkb))
        return None

    df['geometry'] = df['geom'].apply(safe_wkb_to_geom)

    gdf = gpd.GeoDataFrame(df, geometry='geometry')
    gdf.set_crs(epsg=31982, inplace=True)  # ⚠️ Define sem reprojetar
    return gdf


dados_linhas = converte_srid(dados_linhas_4326)
dados_altimetria = define_crs_srid(dados_altimetria_4326)
#dados_linhas_uni = dados_linhas[dados_linhas['SHP'] == 1940].reset_index(drop=True)
#dados_linhas_uni = dados_linhas_uni.head(50000).reset_index(drop=True)

# %%
from shapely.strtree import STRtree
from shapely.geometry.base import BaseGeometry

# 1. Lista de geometrias
geoms_linhas = list(dados_altimetria['geometry'])

# 2. Criar árvore
tree = STRtree(geoms_linhas)

# 3. Inicializar listas
idx_mais_proxima = []
idx_segunda_mais_proxima = []

# 4. Definir raio de busca (em metros)
raio_metros = 50  # Ajuste conforme seu CRS

for ponto in dados_linhas['geometry']:
    # Obter índices das curvas candidatas no buffer
    idx_candidatos = tree.query(ponto.buffer(raio_metros))  # Retorna índices (int) na versão <2.0

    # Obter as geometrias reais usando os índices
    geoms_candidatas = [geoms_linhas[i] for i in idx_candidatos if isinstance(geoms_linhas[i], BaseGeometry)]

    # Ordenar pelas distâncias
    ordenadas = sorted(zip(idx_candidatos, geoms_candidatas), key=lambda tup: ponto.distance(tup[1]))

    # Adicionar os dois índices mais próximos
    if len(ordenadas) >= 2:
        idx_mais_proxima.append(ordenadas[0][0])
        idx_segunda_mais_proxima.append(ordenadas[1][0])
    elif len(ordenadas) == 1:
        idx_mais_proxima.append(ordenadas[0][0])
        idx_segunda_mais_proxima.append(None)
    else:
        idx_mais_proxima.append(None)
        idx_segunda_mais_proxima.append(None)

# 5. Adicionar ao DataFrame
dados_linhas['idx_mais_proxima'] = idx_mais_proxima
dados_linhas['idx_segunda_mais_proxima'] = idx_segunda_mais_proxima

# 6. Opcional: extrair dados das curvas mais próximas
linhas1 = dados_altimetria.loc[dados_linhas['idx_mais_proxima'].dropna().astype(int)].reset_index(drop=True)
linhas2 = dados_altimetria.loc[dados_linhas['idx_segunda_mais_proxima'].dropna().astype(int)].reset_index(drop=True)

# 7. Concatenar
resultado = pd.concat([
    dados_linhas.reset_index(drop=True),
    linhas1.add_prefix('linha1_'),
    linhas2.add_prefix('linha2_')
], axis=1)

# %%
from shapely.strtree import STRtree
import numpy as np
import pandas as pd

# 1. Converter para lista de geometrias
geoms_linhas = dados_altimetria['geometry'].tolist()

# 2. Criar árvore
tree = STRtree(geoms_linhas)

# 3. Pré-alocar arrays para os índices
n_pontos = len(dados_linhas)
idx_mais_proxima = np.full(n_pontos, -1, dtype=int)
idx_segunda_mais_proxima = np.full(n_pontos, -1, dtype=int)

# 4. Definir raio de busca
raio_metros = 50

# 5. Iteração otimizada
for i, ponto in enumerate(dados_linhas['geometry']):
    # Encontrar geometrias dentro do buffer
    candidatos = tree.query(ponto.buffer(raio_metros))
    
    if len(candidatos) > 0:
        # Calcular distâncias
        distancias = [ponto.distance(geoms_linhas[idx]) for idx in candidatos]
        
        # Obter índices ordenados
        ordenados = [idx for _, idx in sorted(zip(distancias, candidatos))]
        
        # Armazenar resultados
        idx_mais_proxima[i] = ordenados[0]
        if len(ordenados) > 1:
            idx_segunda_mais_proxima[i] = ordenados[1]

# 6. Converter para Series com NaN onde não houve match
dados_linhas = dados_linhas.copy()
dados_linhas['idx_mais_proxima'] = [idx if idx != -1 else np.nan for idx in idx_mais_proxima]
dados_linhas['idx_segunda_mais_proxima'] = [idx if idx != -1 else np.nan for idx in idx_segunda_mais_proxima]

# 7. Extração segura de dados - MANTENDO A ORIGINAL QUE FUNCIONA
linhas1 = dados_altimetria.loc[dados_linhas['idx_mais_proxima'].dropna().astype(int)].reset_index(drop=True)
linhas2 = dados_altimetria.loc[dados_linhas['idx_segunda_mais_proxima'].dropna().astype(int)].reset_index(drop=True)

# 8. Concatenar como no código original
resultado = pd.concat([
    dados_linhas.reset_index(drop=True),
    linhas1.add_prefix('linha1_'),
    linhas2.add_prefix('linha2_')
], axis=1)

# %%
from shapely.strtree import STRtree
from shapely.geometry import Point, LineString
import numpy as np
import pandas as pd

# 1. Converter para lista de geometrias
geoms_linhas = dados_altimetria['geometry'].tolist()

# 2. Criar árvore
tree = STRtree(geoms_linhas)

# 3. Pré-alocar arrays para os índices
n_pontos = len(dados_linhas)
idx_mais_proxima = np.full(n_pontos, -1, dtype=int)
idx_segunda_mais_proxima = np.full(n_pontos, -1, dtype=int)

# 4. Definir raio de busca
raio_metros = 300

# 5. Iteração otimizada com seleção de curvas opostas
for i, ponto in enumerate(dados_linhas['geometry']):
    # Encontrar geometrias dentro do buffer
    candidatos = tree.query(ponto.buffer(raio_metros))
    
    if len(candidatos) > 0:
        # Calcular distâncias e pontos mais próximos
        distancias = []
        pontos_mais_proximos = []
        
        for idx in candidatos:
            linha = geoms_linhas[idx]
            ponto_prox = linha.interpolate(linha.project(ponto))
            dist = ponto.distance(ponto_prox)
            distancias.append(dist)
            pontos_mais_proximos.append(ponto_prox)
        
        # Ordenar candidatos por distância
        candidatos_ordenados = [idx for _, idx in sorted(zip(distancias, candidatos))]
        pontos_ordenados = [p for _, p in sorted(zip(distancias, pontos_mais_proximos))]
        
        # Selecionar a curva mais próxima
        idx_mais_proxima[i] = candidatos_ordenados[0]
        ponto_base = pontos_ordenados[0]
        
        # Encontrar curva oposta (do outro lado do ponto)
        for j in range(1, len(candidatos_ordenados)):
            idx_candidato = candidatos_ordenados[j]
            ponto_candidato = pontos_ordenados[j]
            
            # Calcular vetores para determinar o lado
            vetor_base = np.array([ponto.x - ponto_base.x, ponto.y - ponto_base.y])
            vetor_candidato = np.array([ponto_candidato.x - ponto_base.x, ponto_candidato.y - ponto_base.y])
            
            # Produto vetorial para determinar o lado (z-component)
            produto_vetorial = vetor_base[0] * vetor_candidato[1] - vetor_base[1] * vetor_candidato[0]
            
            # Se estiverem em lados opostos (produto vetorial com sinais diferentes)
            if abs(produto_vetorial) > 1e-8:  # Evitar erros numéricos
                idx_segunda_mais_proxima[i] = idx_candidato
                break
        else:
            # Se não encontrou curva oposta, usar a segunda mais próxima
            if len(candidatos_ordenados) > 1:
                idx_segunda_mais_proxima[i] = candidatos_ordenados[1]

# 6. Converter para Series com NaN onde não houve match
dados_linhas = dados_linhas.copy()
dados_linhas['idx_mais_proxima'] = [idx if idx != -1 else np.nan for idx in idx_mais_proxima]
dados_linhas['idx_segunda_mais_proxima'] = [idx if idx != -1 else np.nan for idx in idx_segunda_mais_proxima]

# 7. Extração de dados com tratamento de índices ausentes
linhas1 = pd.DataFrame()
linhas2 = pd.DataFrame()

# Preencher com dados reais onde existem índices válidos
if not dados_linhas['idx_mais_proxima'].isna().all():
    validos = dados_linhas['idx_mais_proxima'].dropna().astype(int)
    linhas1 = dados_altimetria.loc[validos].reset_index(drop=True)
    linhas1 = linhas1.add_prefix('linha1_')

if not dados_linhas['idx_segunda_mais_proxima'].isna().all():
    validos = dados_linhas['idx_segunda_mais_proxima'].dropna().astype(int)
    linhas2 = dados_altimetria.loc[validos].reset_index(drop=True)
    linhas2 = linhas2.add_prefix('linha2_')

# 8. Concatenar resultados garantindo alinhamento
resultado = pd.concat([
    dados_linhas.reset_index(drop=True),
    linhas1,
    linhas2
], axis=1)

# Preencher NaN para colunas faltantes
for col in linhas1.columns:
    if col not in resultado:
        resultado[col] = np.nan
for col in linhas2.columns:
    if col not in resultado:
        resultado[col] = np.nan

# %%
resultado
# Out:
#       SHP   Latitude  Longitude  COD                        geometry  \
# 0    1940 -25.516848 -49.230057  500  POINT (677867.964 7176636.679)
# 1    1940 -25.516868 -49.230132  500  POINT (677860.394 7176634.601)
# 2    1940 -25.516920 -49.230100  500  POINT (677863.492 7176628.828)
# 3    1940 -25.517024 -49.230042  500  POINT (677869.217 7176617.221)
# 4    1940 -25.517186 -49.229950  500  POINT (677878.173 7176599.136)
# ..    ...        ...        ...  ...                             ...
# 555  1940 -25.433545 -49.269572  500  POINT (674016.047 7185916.227)
# 556  1940 -25.433583 -49.269682  500   POINT (674004.99 7185912.217)
# 557  1940 -25.433632 -49.269817  500  POINT (673991.285 7185906.934)
# 558  1940 -25.433678 -49.269951  500  POINT (673977.747 7185901.971)
# 559  1940 -25.433788 -49.270266  500  POINT (673945.945 7185890.223)
#
#      idx_mais_proxima  idx_segunda_mais_proxima  linha1_gid  \
# 0               19598                     15454      115013
# 1               19598                     19674      115013
# 2               19598                     15454      115013
# 3               19598                     15454      115013
# 4               15454                     19598      115086
# ..                ...                       ...         ...
# 555             21013                     22035      116421
# 556             21013                     22035      116421
# 557             21013                     22035      116421
# 558             21013                     22035      116421
# 559             21013                     20857      116421
#
#             linha1_layer  linha1_elevation  ...         linha2_layer  \
# 0    CURVA INTERMEDIARIA             881.0  ...  CURVA INTERMEDIARIA
# 1    CURVA INTERMEDIARIA             881.0  ...  CURVA INTERMEDIARIA
# 2    CURVA INTERMEDIARIA             881.0  ...  CURVA INTERMEDIARIA
# 3    CURVA INTERMEDIARIA             881.0  ...  CURVA INTERMEDIARIA
# 4    CURVA INTERMEDIARIA             881.0  ...  CURVA INTERMEDIARIA
# ..                   ...               ...  ...                  ...
# 555         CURVA MESTRA             895.0  ...  CURVA INTERMEDIARIA
# 556         CURVA MESTRA             895.0  ...  CURVA INTERMEDIARIA
# 557         CURVA MESTRA             895.0  ...  CURVA INTERMEDIARIA
# 558         CURVA MESTRA             895.0  ...  CURVA INTERMEDIARIA
# 559         CURVA MESTRA             895.0  ...  CURVA INTERMEDIARIA
#
#     linha2_elevation  linha2_data_voo linha2_data_rest  \
# 0              881.0  1972 / NOV-1979      1972 / 1980
# 1              882.0  1972 / NOV-1979      1972 / 1980
# 2              881.0  1972 / NOV-1979      1972 / 1980
# 3              881.0  1972 / NOV-1979      1972 / 1980
# 4              881.0  1972 / NOV-1979      1972 / 1980
# ..               ...              ...              ...
# 555            894.0  1972 / NOV-1979      1972 / 1980
# 556            894.0  1972 / NOV-1979      1972 / 1980
# 557            894.0  1972 / NOV-1979      1972 / 1980
# 558            894.0  1972 / NOV-1979      1972 / 1980
# 559            896.0  1972 / NOV-1979      1972 / 1980
#
#              linha2_resp_tec  linha2_escala linha2_curvas_m linha2_shape_len  \
# 0    GEOFOTO SA / SAESP LTDA        1:2.000             1.0        68.800874
# 1    GEOFOTO SA / SAESP LTDA        1:2.000             1.0      2914.147072
# 2    GEOFOTO SA / SAESP LTDA        1:2.000             1.0        68.800874
# 3    GEOFOTO SA / SAESP LTDA        1:2.000             1.0        68.800874
# 4    GEOFOTO SA / SAESP LTDA        1:2.000             1.0      2695.441565
# ..                       ...            ...             ...              ...
# 555  GEOFOTO SA / SAESP LTDA        1:2.000             1.0      2941.633485
# 556  GEOFOTO SA / SAESP LTDA        1:2.000             1.0      2941.633485
# 557  GEOFOTO SA / SAESP LTDA        1:2.000             1.0      2941.633485
# 558  GEOFOTO SA / SAESP LTDA        1:2.000             1.0      2941.633485
# 559  GEOFOTO SA / SAESP LTDA        1:2.000             1.0      3706.612046
#
#                                            linha2_geom  \
# 0    0105000020E61000000100000001020000000D00000000...
# 1    0105000020E61000000100000001020000003601000000...
# 2    0105000020E61000000100000001020000000D00000000...
# 3    0105000020E61000000100000001020000000D00000000...
# 4    0105000020E61000000100000001020000004F01000000...
# ..                                                 ...
# 555  0105000020E6100000010000000102000000F801000000...
# 556  0105000020E6100000010000000102000000F801000000...
# 557  0105000020E6100000010000000102000000F801000000...
# 558  0105000020E6100000010000000102000000F801000000...
# 559  0105000020E6100000010000000102000000C502000000...
#
#                                        linha2_geometry
# 0    MULTILINESTRING ((677868.663 7176571.723, 6778...
# 1    MULTILINESTRING ((677975.053 7177199.693, 6779...
# 2    MULTILINESTRING ((677868.663 7176571.723, 6778...
# 3    MULTILINESTRING ((677868.663 7176571.723, 6778...
# 4    MULTILINESTRING ((678002.153 7177108.563, 6780...
# ..                                                 ...
# 555  MULTILINESTRING ((674443.723 7186799.693, 6744...
# 556  MULTILINESTRING ((674443.723 7186799.693, 6744...
# 557  MULTILINESTRING ((674443.723 7186799.693, 6744...
# 558  MULTILINESTRING ((674443.723 7186799.693, 6744...
# 559  MULTILINESTRING ((674142.033 7186799.693, 6741...
#
# [560 rows x 29 columns]

# %%
resultado1 = resultado[resultado['COD'] == 22]

# %%
resultado1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 resultado1
#
# NameError: name 'resultado1' is not defined

# %%
#resultado2 = resultado1.head(10)
resultado1 = resultado[resultado['SHP'] == 1940]

# %%
# Função para calcular a elevação interpolada para uma única linha
import numpy as np
def interpolar_altimetria(row):
    ponto = row['geometry']
    linha1_geom = row['linha1_geometry']
    linha2_geom = row['linha2_geometry']
    elevacao1 = row['linha1_elevation']
    elevacao2 = row['linha2_elevation']

    # Lidar com casos onde as geometrias ou elevações são nulas
    if pd.isna(elevacao1) and pd.isna(elevacao2):
        return np.nan # Não há dados para interpolar

    if pd.isna(elevacao1) and not pd.isna(elevacao2):
        return elevacao2 # Se apenas uma elevação estiver disponível, use-a
    if not pd.isna(elevacao1) and pd.isna(elevacao2):
        return elevacao1 # Se apenas uma elevação estiver disponível, use-a

    # Se ambas as elevações são válidas, prossiga com a interpolação ponderada
    if linha1_geom and linha2_geom:
        distancia1 = ponto.distance(linha1_geom)
        distancia2 = ponto.distance(linha2_geom)

        # Evitar divisão por zero se ambas as distâncias forem zero (ponto está sobre ambas as linhas)
        if distancia1 == 0 and distancia2 == 0:
            return (elevacao1 + elevacao2) / 2
        elif distancia1 == 0:
            return elevacao1 # Ponto está na linha 1
        elif distancia2 == 0:
            return elevacao2 # Ponto está na linha 2

        # Fórmula de interpolação ponderada inversa da distância (IDW)
        # Mais próximo significa maior peso.
        # Peso da linha 1 = 1/distancia1
        # Peso da linha 2 = 1/distancia2
        peso1 = 1 / distancia1
        peso2 = 1 / distancia2

        elevacao_interpolada = (elevacao1 * peso1 + elevacao2 * peso2) / (peso1 + peso2)
        return elevacao_interpolada
    else:
        return np.nan # Geometrias nulas ou inválidas

# Aplicar a função a cada linha do DataFrame
# Usamos .copy() para evitar SettingWithCopyWarning
resultado_copia = resultado.copy()
resultado_copia['altimetria_interpolada'] = resultado_copia.apply(interpolar_altimetria, axis=1)

# %%
#resultado_copia = resultado_copia.head(200)


# 1. Calcular o centro do mapa
lat_center = resultado_copia['Latitude'].mean()
lon_center = resultado_copia['Longitude'].mean()

# 2. Criar mapa Folium centrado
m = folium.Map(location=[lat_center, lon_center], zoom_start=15)

# 3. Adicionar pontos no mapa
for idx, row in resultado_copia.iterrows():
    folium.CircleMarker(
        location=[row['Latitude'], row['Longitude']],
        radius=3,
        color='blue',
        fill=True,
        fill_opacity=0.7,
        popup=f"SHP: {row['SHP']}, COD: {row['COD']}"
    ).add_to(m)

# 4. Exibir mapa
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bc9ec40496c11f7e40613415335cdad9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bc9ec40496c11f7e40613415335cdad9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bc9ec40496c11f7e40613415335cdad9 = L.map(
#                 &quot;map_bc9ec40496c11f7e40613415335cdad9&quot;,
#                 {
#                     center: [-25.472152698921207, -49.25169232440742],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d9f559a5f89e1833da689427ee5b5d4f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d9f559a5f89e1833da689427ee5b5d4f.addTo(map_bc9ec40496c11f7e40613415335cdad9);
#
#
#             var circle_marker_0b7f05df762e8404b39ba5d09e912754 = L.circleMarker(
#                 [-25.516848128860715, -49.23005693809807],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bc9ec40496c11f7e40613415335cdad9);
#
#
#         var popup_3af8079df8a862450d48166d996e6f4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_813ac61e3d0246f0259b3a3f94344be7 = $(`&lt;div id=&quot;html_813ac61e3d0246f0259b3a3f94344be7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SHP: 1940, COD: 500&lt;/div&gt;`)[0];
#                 popup_3af8079df8a862450d48166d996e6f4c.setContent(html_813ac61e3d0246f0259b3a3f94344be7);
#
#
#
#         circle_marker_0b7f05df762e8404b39ba5d09e912754.bindPopup(popup_3af8079df8a862450d48166d996e6f4c)
#         ;
#
#
#
#
#             var circle_marker_379ede4597bd8e1703d9edbaa2d371f0 = L.circleMarker(
#                 [-25.51686779171, -49.23013196903002],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bc9ec40496c11f7e40613415335cdad9);
#
#
#         var popup_d331baf2b0d996767f887f241614bb35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9ce146c0b7b71b4118c3f0393d58bc2 = $(`&lt;div id=&quot;html_c9ce146c0b7b71b4118c3f0393d58bc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SHP: 1940, COD: 500&lt;/div&gt;`)[0];
#                 popup_d331baf2b0d996767f887f241614bb35.setContent(html_c9ce146c0b7b71b4118c3f0393d58bc2);
#
#
#
#         circle_marker_379ede4597bd8e1703d9edbaa2d371f0.bindPopup(popup_d331baf2b0d996767f887f241614bb35)
#         ;
#
#
#
#
#             var circle_marker_39a37d15cc07f179936e31e49b535426 = L.circleMarker(
#                 [-25.516919527273075, -49.2301003821536],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_bc9ec40496c11f7e40613415335cdad9);
#
#
#         var popup_eb475944d0160dd4a3debf0c0a92af32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1414da1c70f5b8b98a84577bc461483 = $(`&lt;div id=&quot;html_d1414da1c70f5b8b98a84577bc461483&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SHP: 1940, COD: 500&lt;/div&gt;`)[0];
#                 popup_eb475944d0160dd4a3debf0c0a92af32.setContent(html_d1414da1c70f5b8b98a84577bc461483);
#
#
#
#         circle_marker_39a37d15cc07f179936e31e49b535426.bindPopup(popup_eb475944d0160dd4a3debf0c0a92af32)
#         ;

# %%
# Calcular as diferenças absolutas da coluna elevation entre pontos consecutivos
resultado_copia['diff_elev'] = resultado_copia['altimetria_interpolada'].diff().abs()

# Somar todas as diferenças para obter a variação total altimétrica
variacao_total = resultado_copia['diff_elev'].sum()

print("Variação para linha 500 em metros: ", variacao_total)
# Out:
# Variação para linha 500 em metros:  176.6362814867581

# %%
resultado_copia = resultado_copia.reset_index(drop=True)

# %%
resultado1 = resultado1.reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 resultado1 = resultado1.reset_index(drop=True)
#
# NameError: name 'resultado1' is not defined

# %%
#df = resultado1.iloc[[2]].copy()
#df = df.reset_index(drop=True)

# %%
resultado_copia
# Out:
#       SHP   Latitude  Longitude  COD                        geometry  \
# 0    4146 -25.406631 -49.252164   22  POINT (675806.082 7188874.605)
# 1    4146 -25.406486 -49.252032   22  POINT (675819.601 7188890.491)
# 2    4146 -25.406337 -49.251887   22  POINT (675834.373 7188906.805)
# 3    4146 -25.406844 -49.251460   22  POINT (675876.586 7188850.091)
# 4    4146 -25.407485 -49.250905   22   POINT (675931.528 7188778.41)
# ..    ...        ...        ...  ...                             ...
# 968  4146 -25.407225 -49.252731   22  POINT (675748.165 7188809.598)
# 969  4146 -25.407053 -49.252566   22  POINT (675764.983 7188828.429)
# 970  4146 -25.406902 -49.252426   22  POINT (675779.355 7188844.917)
# 971  4146 -25.406760 -49.252291   22  POINT (675793.141 7188860.539)
# 972  4146 -25.406639 -49.252170   22  POINT (675805.501 7188873.792)
#
#      idx_mais_proxima  idx_segunda_mais_proxima  linha1_gid  \
# 0               27337                     27342      122759
# 1               27337                     26830      122759
# 2               26830                     26361      122251
# 3               26361                     26830      121787
# 4               26361                     26830      121787
# ..                ...                       ...         ...
# 968             27012                     25033      122435
# 969             25033                     27012      120457
# 970             27342                     25033      122761
# 971             27342                     27337      122761
# 972             27337                     27342      122759
#
#             linha1_layer  linha1_elevation  ...  linha2_data_voo  \
# 0    CURVA INTERMEDIARIA             912.0  ...  1972 / NOV-1979
# 1    CURVA INTERMEDIARIA             912.0  ...  1972 / NOV-1979
# 2    CURVA INTERMEDIARIA             911.0  ...  1972 / NOV-1979
# 3           CURVA MESTRA             910.0  ...  1972 / NOV-1979
# 4           CURVA MESTRA             910.0  ...  1972 / NOV-1979
# ..                   ...               ...  ...              ...
# 968         CURVA MESTRA             915.0  ...  1972 / NOV-1979
# 969  CURVA INTERMEDIARIA             914.0  ...  1972 / NOV-1979
# 970  CURVA INTERMEDIARIA             913.0  ...  1972 / NOV-1979
# 971  CURVA INTERMEDIARIA             913.0  ...  1972 / NOV-1979
# 972  CURVA INTERMEDIARIA             912.0  ...  1972 / NOV-1979
#
#     linha2_data_rest          linha2_resp_tec linha2_escala  linha2_curvas_m  \
# 0        1972 / 1980  GEOFOTO SA / SAESP LTDA       1:2.000              1.0
# 1        1972 / 1980  GEOFOTO SA / SAESP LTDA       1:2.000              1.0
# 2        1972 / 1980  GEOFOTO SA / SAESP LTDA       1:2.000              1.0
# 3        1972 / 1980  GEOFOTO SA / SAESP LTDA       1:2.000              1.0
# 4        1972 / 1980  GEOFOTO SA / SAESP LTDA       1:2.000              1.0
# ..               ...                      ...           ...              ...
# 968      1972 / 1980  GEOFOTO SA / SAESP LTDA       1:2.000              1.0
# 969      1972 / 1980  GEOFOTO SA / SAESP LTDA       1:2.000              1.0
# 970      1972 / 1980  GEOFOTO SA / SAESP LTDA       1:2.000              1.0
# 971      1972 / 1980  GEOFOTO SA / SAESP LTDA       1:2.000              1.0
# 972      1972 / 1980  GEOFOTO SA / SAESP LTDA       1:2.000              1.0
#
#      linha2_shape_len                                        linha2_geom  \
# 0         1656.956598  0105000020E61000000100000001020000000401000000...
# 1         1639.730080  0105000020E61000000100000001020000000801000000...
# 2         1056.215358  0105000020E6100000010000000102000000E700000000...
# 3         1639.730080  0105000020E61000000100000001020000000801000000...
# 4         1639.730080  0105000020E61000000100000001020000000801000000...
# ..                ...                                                ...
# 968       1813.690400  0105000020E61000000100000001020000000D01000000...
# 969        718.615264  0105000020E6100000010000000102000000AB00000000...
# 970       1813.690400  0105000020E61000000100000001020000000D01000000...
# 971       1470.946414  0105000020E6100000010000000102000000EB00000000...
# 972       1656.956598  0105000020E61000000100000001020000000401000000...
#
#                                        linha2_geometry  \
# 0    MULTILINESTRING ((675637.999 7188999.693, 6756...
# 1    MULTILINESTRING ((675841.483 7188999.693, 6758...
# 2    MULTILINESTRING ((675977.209 7188999.693, 6759...
# 3    MULTILINESTRING ((675841.483 7188999.693, 6758...
# 4    MULTILINESTRING ((675841.483 7188999.693, 6758...
# ..                                                 ...
# 968  MULTILINESTRING ((675612.237 7188999.693, 6756...
# 969  MULTILINESTRING ((675720.773 7188890.643, 6757...
# 970  MULTILINESTRING ((675612.237 7188999.693, 6756...
# 971  MULTILINESTRING ((675768.674 7188999.693, 6757...
# 972  MULTILINESTRING ((675637.999 7188999.693, 6756...
#
#      altimetria_interpolada diff_elev
# 0                912.315568       NaN
# 1                911.791885  0.523682
# 2                910.773833  1.018052
# 3                910.464714  0.309119
# 4                910.426158  0.038557
# ..                      ...       ...
# 968              914.736353  1.955901
# 969              914.097941  0.638412
# 970              913.459392  0.638549
# 971              912.993179  0.466213
# 972              912.352636  0.640543
#
# [973 rows x 31 columns]

# %%
import folium
from folium import FeatureGroup, LayerControl
from shapely import wkt
import pandas as pd
from pyproj import Transformer, CRS # Importar pyproj

# ==============================================================================
# ATENÇÃO: Defina aqui o código EPSG do sistema de coordenadas dos seus dados de LINHA
# Exemplos comuns para a região de Curitiba (UTM Zone 22S):
# SOURCE_EPSG = "EPSG:31982"  # Para SIRGAS 2000 / UTM zone 22S
# SOURCE_EPSG = "EPSG:29192"  # Para SAD69 / UTM zone 22S
# Consulte a origem dos seus dados para saber o EPSG correto.
SOURCE_EPSG = "EPSG:31982" # <- MUDE AQUI SE NECESSÁRIO
TARGET_EPSG = "EPSG:4326"  # WGS84 (Latitude/Longitude) que o Folium usa
# ==============================================================================

# Criar o objeto Transformer uma vez para reutilização
try:
    transformer = Transformer.from_crs(CRS.from_string(SOURCE_EPSG), CRS.from_string(TARGET_EPSG), always_xy=True)
except Exception as e:
    print(f"Erro ao criar o transformador de coordenadas com pyproj: {e}")
    print(f"Verifique se o código SOURCE_EPSG ('{SOURCE_EPSG}') está correto e se pyproj está instalado.")
    exit()
'''
# Lendo o CSV
file_path = 'resultado1.csv'
try:
    df = pd.read_csv(file_path)
except FileNotFoundError:
    print(f"Erro: O arquivo '{file_path}' não foi encontrado.")
    exit()
'''
df = resultado_copia.copy()
if df.empty:
    print(f"Erro: O arquivo CSV '{file_path}' está vazio.")
    exit()

required_columns = ['Latitude', 'Longitude', 'linha1_geometry', 'linha2_geometry']
for col in required_columns:
    if col not in df.columns:
        print(f"Erro: A coluna '{col}' não foi encontrada no CSV. Colunas encontradas: {df.columns.tolist()}")
        exit()

# Obtendo coordenadas do ponto CENTRAL do mapa
# Certifique-se que estas coordenadas no CSV estão em graus decimais (Lat/Lon)
map_center_latitude = df.loc[0, 'Latitude']
map_center_longitude = df.loc[0, 'Longitude']
print(f"Centro do mapa definido para Latitude: {map_center_latitude}, Longitude: {map_center_longitude}")


# Criando o mapa centralizado no ponto
m = folium.Map(location=[map_center_latitude, map_center_longitude], zoom_start=15)

# ====== Camada do ponto ======
fg_ponto = FeatureGroup(name='Ponto Principal')
folium.Marker(
    location=[map_center_latitude, map_center_longitude],
    popup='Ponto Principal',
    icon=folium.Icon(color='red')
).add_to(fg_ponto)
fg_ponto.add_to(m)

# Função auxiliar para adicionar geometrias de linha com REPROJEÇÃO
def adicionar_geometria_linha(wkt_string, feature_group, cor_linha, nome_camada_debug):
    print(f"\nProcessando {nome_camada_debug}:")
    if pd.isna(wkt_string) or not str(wkt_string).strip():
        print(f"  Aviso: String WKT para '{nome_camada_debug}' está vazia ou é NaN. Camada pulada.")
        return

    wkt_string_preview = str(wkt_string)[:100] + ('...' if len(str(wkt_string)) > 100 else '')
    print(f"  WKT recebido: '{wkt_string_preview}'")

    try:
        geom = wkt.loads(str(wkt_string))
    except Exception as e:
        print(f"  Erro ao parsear WKT para '{nome_camada_debug}': {wkt_string_preview}. Erro: {e}")
        return

    if geom.is_empty:
        print(f"  Aviso: Geometria WKT parseada para '{nome_camada_debug}' está vazia. Camada pulada.")
        return

    print(f"  Tipo de geometria parseada: {geom.geom_type}")

    linhas_para_plotar_orig = []
    if geom.geom_type == 'LineString':
        linhas_para_plotar_orig.append(geom)
    elif geom.geom_type == 'MultiLineString':
        linhas_para_plotar_orig.extend(list(geom.geoms))
    else:
        print(f"  Aviso: Tipo de geometria não suportado '{geom.geom_type}' para '{nome_camada_debug}'. Camada pulada.")
        return

    if not linhas_para_plotar_orig:
        print(f"  Aviso: Nenhuma linha individual encontrada em '{nome_camada_debug}'.")
        return
        
    segmentos_adicionados = 0
    for i, linha_orig in enumerate(linhas_para_plotar_orig):
        if linha_orig.is_empty:
            print(f"  Aviso: Segmento {i} (original) de '{nome_camada_debug}' está vazio.")
            continue
        
        # Coordenadas em WKT projetado são (x, y) ou (Leste, Norte)
        coords_originais_projetadas = list(linha_orig.coords) # Lista de tuplas (x_proj, y_proj)
        
        if not coords_originais_projetadas:
            print(f"  Aviso: Segmento {i} (original) de '{nome_camada_debug}' não possui coordenadas.")
            continue
        
        # Reprojetar coordenadas
        coords_reprojetadas_folium = []
        try:
            for x_proj, y_proj in coords_originais_projetadas:
                # transformer.transform espera (x, y) e retorna (lon, lat) devido a always_xy=True
                lon_deg, lat_deg = transformer.transform(x_proj, y_proj)
                coords_reprojetadas_folium.append((lat_deg, lon_deg)) # Folium espera (lat, lon)
        except Exception as e:
            print(f"    Erro durante a reprojeção do segmento {i} de '{nome_camada_debug}': {e}")
            print(f"    Coordenadas problemáticas (primeiras 2): {coords_originais_projetadas[:2]}")
            continue # Pula para o próximo segmento se este falhar

        if not coords_reprojetadas_folium:
            print(f"  Aviso: Segmento {i} de '{nome_camada_debug}' não possui coordenadas após reprojeção.")
            continue
            
        # print(f"  Coordenadas reprojetadas para segmento {i} de '{nome_camada_debug}' (primeiras 2): {coords_reprojetadas_folium[:2]}...")
        folium.PolyLine(coords_reprojetadas_folium, color=cor_linha, weight=2.5, opacity=0.8).add_to(feature_group)
        segmentos_adicionados +=1
    
    if segmentos_adicionados > 0:
        print(f"  {segmentos_adicionados} segmento(s) de linha (reprojetados) adicionado(s) para '{nome_camada_debug}'.")
        if len(coords_reprojetadas_folium) > 0:
             print(f"    Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): {coords_reprojetadas_folium[0]}")
    else:
        print(f"  Nenhum segmento de linha válido foi adicionado para '{nome_camada_debug}'.")


# ====== Camada Curva de Nível 1 ======
fg_curva1 = FeatureGroup(name='Curva de Nível 1', show=True)
wkt_linha1 = df.loc[0, 'linha1_geometry']
adicionar_geometria_linha(wkt_linha1, fg_curva1, 'blue', 'Curva de Nível 1')
fg_curva1.add_to(m)

# ====== Camada Curva de Nível 2 ======
fg_curva2 = FeatureGroup(name='Curva de Nível 2', show=True)
wkt_linha2 = df.loc[0, 'linha2_geometry']
adicionar_geometria_linha(wkt_linha2, fg_curva2, 'green', 'Curva de Nível 2')
fg_curva2.add_to(m)

# ====== Controle de Camadas ======
LayerControl().add_to(m)

output_map_file = 'mapa_curvas_revisado_reprojetado.html'
m.save(output_map_file)
print(f"\nMapa salvo como '{output_map_file}'. Abra este arquivo em um navegador para visualizar.")
# m # Descomente para exibir no Jupyter Notebook
# Out:
# Centro do mapa definido para Latitude: -25.516848128860715, Longitude: -49.23005693809807
#
# Processando Curva de Nível 1:
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva de Nível 1'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva de Nível 2:
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva de Nível 2'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# Mapa salvo como 'mapa_curvas_revisado_reprojetado.html'. Abra este arquivo em um navegador para visualizar.

# %%
import folium
from folium import FeatureGroup, LayerControl
from shapely import wkt
import pandas as pd
from pyproj import Transformer, CRS # Importar pyproj

# ==============================================================================
# ATENÇÃO: Defina aqui o código EPSG do sistema de coordenadas dos seus dados de LINHA
# Exemplos comuns para a região de Curitiba (UTM Zone 22S):
# SOURCE_EPSG = "EPSG:31982"  # Para SIRGAS 2000 / UTM zone 22S
# SOURCE_EPSG = "EPSG:29192"  # Para SAD69 / UTM zone 22S
# Consulte a origem dos seus dados para saber o EPSG correto.
SOURCE_EPSG = "EPSG:31982" # <- MUDE AQUI SE NECESSÁRIO
TARGET_EPSG = "EPSG:4326"  # WGS84 (Latitude/Longitude) que o Folium usa
# ==============================================================================

df = resultado_copia.copy()

if df.empty:
    print(f"Erro: O DataFrame carregado de '{file_path}' está vazio.")
    exit()

# --- Verificação das colunas obrigatórias ---
required_columns = ['Latitude', 'Longitude', 'linha1_geometry', 'linha2_geometry']
for col in required_columns:
    if col not in df.columns:
        print(f"Erro: A coluna '{col}' não foi encontrada no CSV. Colunas encontradas: {df.columns.tolist()}")
        exit()

# --- Definição do centro do mapa (usando a primeira linha) ---
# Você pode alterar esta lógica se precisar de um centro diferente (ex: média das coordenadas)
map_center_latitude = df.loc[0, 'Latitude']
map_center_longitude = df.loc[0, 'Longitude']
print(f"Centro do mapa definido para Latitude: {map_center_latitude}, Longitude: {map_center_longitude} (da primeira linha do CSV)")

# --- Criação do mapa ---
# Ajustei o zoom_start para 12, pode ser necessário ajustar dependendo da dispersão dos seus dados
m = folium.Map(location=[map_center_latitude, map_center_longitude], zoom_start=12)

# --- Criação dos FeatureGroups gerais ---
# Um grupo para todos os marcadores de pontos
fg_pontos_todos = FeatureGroup(name='Todos os Pontos Principais', show=True)
m.add_child(fg_pontos_todos)

# Um grupo para todas as geometrias de "linha1"
fg_curva1_todas = FeatureGroup(name='Todas Curvas de Nível 1', show=True)
m.add_child(fg_curva1_todas)

# Um grupo para todas as geometrias de "linha2"
fg_curva2_todas = FeatureGroup(name='Todas Curvas de Nível 2', show=True)
m.add_child(fg_curva2_todas)


# Função auxiliar para adicionar geometrias de linha com REPROJEÇÃO (sem alterações nesta função)
def adicionar_geometria_linha(wkt_string, feature_group, cor_linha, nome_camada_debug):
    print(f"\nProcessando {nome_camada_debug}:")
    if pd.isna(wkt_string) or not str(wkt_string).strip():
        print(f"  Aviso: String WKT para '{nome_camada_debug}' está vazia ou é NaN. Camada pulada.")
        return

    wkt_string_preview = str(wkt_string)[:100] + ('...' if len(str(wkt_string)) > 100 else '')
    print(f"  WKT recebido: '{wkt_string_preview}'")

    try:
        geom = wkt.loads(str(wkt_string))
    except Exception as e:
        print(f"  Erro ao parsear WKT para '{nome_camada_debug}': {wkt_string_preview}. Erro: {e}")
        return

    if geom.is_empty:
        print(f"  Aviso: Geometria WKT parseada para '{nome_camada_debug}' está vazia. Camada pulada.")
        return

    print(f"  Tipo de geometria parseada: {geom.geom_type}")

    linhas_para_plotar_orig = []
    if geom.geom_type == 'LineString':
        linhas_para_plotar_orig.append(geom)
    elif geom.geom_type == 'MultiLineString':
        linhas_para_plotar_orig.extend(list(geom.geoms))
    else:
        print(f"  Aviso: Tipo de geometria não suportado '{geom.geom_type}' para '{nome_camada_debug}'. Camada pulada.")
        return

    if not linhas_para_plotar_orig:
        print(f"  Aviso: Nenhuma linha individual encontrada em '{nome_camada_debug}'.")
        return
        
    segmentos_adicionados = 0
    coords_reprojetadas_folium_exemplo = [] # Para imprimir exemplo
    for i, linha_orig in enumerate(linhas_para_plotar_orig):
        if linha_orig.is_empty:
            print(f"  Aviso: Segmento {i} (original) de '{nome_camada_debug}' está vazio.")
            continue
        
        coords_originais_projetadas = list(linha_orig.coords)
        
        if not coords_originais_projetadas:
            print(f"  Aviso: Segmento {i} (original) de '{nome_camada_debug}' não possui coordenadas.")
            continue
        
        coords_reprojetadas_folium = []
        try:
            for x_proj, y_proj in coords_originais_projetadas:
                lon_deg, lat_deg = transformer.transform(x_proj, y_proj)
                coords_reprojetadas_folium.append((lat_deg, lon_deg))
        except Exception as e:
            print(f"    Erro durante a reprojeção do segmento {i} de '{nome_camada_debug}': {e}")
            print(f"    Coordenadas problemáticas (primeiras 2): {coords_originais_projetadas[:2]}")
            continue

        if not coords_reprojetadas_folium:
            print(f"  Aviso: Segmento {i} de '{nome_camada_debug}' não possui coordenadas após reprojeção.")
            continue
        
        if not coords_reprojetadas_folium_exemplo: # Salva o primeiro conjunto de coords para exemplo
            coords_reprojetadas_folium_exemplo = coords_reprojetadas_folium

        folium.PolyLine(coords_reprojetadas_folium, color=cor_linha, weight=2.5, opacity=0.8).add_to(feature_group)
        segmentos_adicionados +=1
    
    if segmentos_adicionados > 0:
        print(f"  {segmentos_adicionados} segmento(s) de linha (reprojetados) adicionado(s) para '{nome_camada_debug}'.")
        if coords_reprojetadas_folium_exemplo and coords_reprojetadas_folium_exemplo[0]:
             print(f"    Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): {coords_reprojetadas_folium_exemplo[0]}")
    else:
        print(f"  Nenhum segmento de linha válido foi adicionado para '{nome_camada_debug}'.")

# --- Iterar sobre cada linha (tupla) do DataFrame ---
for index, row in df.iterrows():
    print(f"\n--- Processando dados da Linha {index} do CSV ---")
    
    current_lat = row['Latitude']
    current_lon = row['Longitude']
    
    # Adicionar marcador para o ponto principal da linha atual
    popup_text = f"Ponto ID {index}<br>Lat: {current_lat:.5f}<br>Lon: {current_lon:.5f}"
    folium.Marker(
        location=[current_lat, current_lon],
        popup=popup_text,
        icon=folium.Icon(color='purple', icon='info-sign') # Cor diferente para distinguir dos antigos
    ).add_to(fg_pontos_todos)

    # Processar e adicionar Curva de Nível 1 para a linha atual
    wkt_l1 = row['linha1_geometry']
    debug_name_l1 = f"Curva Nível 1 (CSV Linha {index})"
    adicionar_geometria_linha(wkt_l1, fg_curva1_todas, 'blue', debug_name_l1)

    # Processar e adicionar Curva de Nível 2 para a linha atual
    wkt_l2 = row['linha2_geometry']
    debug_name_l2 = f"Curva Nível 2 (CSV Linha {index})"
    adicionar_geometria_linha(wkt_l2, fg_curva2_todas, 'green', debug_name_l2)


# ====== Controle de Camadas ======
LayerControl().add_to(m)

# --- Salvamento do mapa ---
output_map_file = 'mapa_curvas_multiplas_linhas.html'
m.save(output_map_file)
print(f"\nMapa salvo como '{output_map_file}'. Abra este arquivo em um navegador para visualizar.")
# m # Descomente para exibir no Jupyter Notebook
# Out:
# Centro do mapa definido para Latitude: -25.516848128860715, Longitude: -49.23005693809807 (da primeira linha do CSV)
#
# --- Processando dados da Linha 0 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 0):
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 0)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva Nível 2 (CSV Linha 0):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 0)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 1 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 1):
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 1)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva Nível 2 (CSV Linha 1):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 1)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 2 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 2):
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 2)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva Nível 2 (CSV Linha 2):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 2)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 3 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 3):
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 3)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva Nível 2 (CSV Linha 3):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 3)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 4 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 4):
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 4)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva Nível 2 (CSV Linha 4):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 4)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 5 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 5):
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 5)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva Nível 2 (CSV Linha 5):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 5)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 6 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 6):
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 6)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva Nível 2 (CSV Linha 6):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 6)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 7 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 7):
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 7)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva Nível 2 (CSV Linha 7):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 7)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 8 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 8):
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 8)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva Nível 2 (CSV Linha 8):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 8)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 9 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 9):
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 9)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva Nível 2 (CSV Linha 9):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 9)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 10 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 10):
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 10)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva Nível 2 (CSV Linha 10):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 10)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 11 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 11):
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 11)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva Nível 2 (CSV Linha 11):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 11)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 12 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 12):
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 12)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva Nível 2 (CSV Linha 12):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 12)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 13 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 13):
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 13)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva Nível 2 (CSV Linha 13):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 13)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 14 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 14):
#   WKT recebido: 'MULTILINESTRING ((675640.1829833984 7183199.692993164, 675638.2030029297 7183197.963012695, 675637.1...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 14)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.45787453302728, -49.25307389469072)
#
# Processando Curva Nível 2 (CSV Linha 14):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 14)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 15 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 15):
#   WKT recebido: 'MULTILINESTRING ((675347.1030273438 7182257.743041992, 675348.6929931641 7182257.0330200195, 675351....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 15)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.466411532455577, -49.25586520984545)
#
# Processando Curva Nível 2 (CSV Linha 15):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 15)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 16 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 16):
#   WKT recebido: 'MULTILINESTRING ((675347.1030273438 7182257.743041992, 675348.6929931641 7182257.0330200195, 675351....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 16)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.466411532455577, -49.25586520984545)
#
# Processando Curva Nível 2 (CSV Linha 16):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 16)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 17 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 17):
#   WKT recebido: 'MULTILINESTRING ((674807.0530395508 7182335.682983398, 674809.9730224609 7182332.913024902, 674813.3...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 17)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.465771746050365, -49.26124510608592)
#
# Processando Curva Nível 2 (CSV Linha 17):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 17)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 18 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 18):
#   WKT recebido: 'MULTILINESTRING ((674807.0530395508 7182335.682983398, 674809.9730224609 7182332.913024902, 674813.3...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 18)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.465771746050365, -49.26124510608592)
#
# Processando Curva Nível 2 (CSV Linha 18):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 18)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 19 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 19):
#   WKT recebido: 'MULTILINESTRING ((675477.1329956055 7183199.692993164, 675475.1229858398 7183194.353027344, 675473.3...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 19)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.457893818602937, -49.25469500128204)
#
# Processando Curva Nível 2 (CSV Linha 19):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 19)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 20 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 20):
#   WKT recebido: 'MULTILINESTRING ((675432.7230224609 7183199.692993164, 675434.1030273438 7183195.043029785, 675435.1...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 20)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.45789906832163, -49.255136542849314)
#
# Processando Curva Nível 2 (CSV Linha 20):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 20)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 21 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 21):
#   WKT recebido: 'MULTILINESTRING ((675427.923034668 7183199.692993164, 675427.7830200195 7183194.663024902, 675428.09...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 21)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.45789963565043, -49.25518426623914)
#
# Processando Curva Nível 2 (CSV Linha 21):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 21)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 22 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 22):
#   WKT recebido: 'MULTILINESTRING ((675390.4329833984 7183199.692993164, 675390.5530395508 7183198.893005371, 675390.7...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 22)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.457904066208783, -49.255557007305704)
#
# Processando Curva Nível 2 (CSV Linha 22):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 22)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 23 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 23):
#   WKT recebido: 'MULTILINESTRING ((675390.4329833984 7183199.692993164, 675390.5530395508 7183198.893005371, 675390.7...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 23)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.457904066208783, -49.255557007305704)
#
# Processando Curva Nível 2 (CSV Linha 23):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 23)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 24 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 24):
#   WKT recebido: 'MULTILINESTRING ((675390.4329833984 7183199.692993164, 675390.5530395508 7183198.893005371, 675390.7...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 24)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.457904066208783, -49.255557007305704)
#
# Processando Curva Nível 2 (CSV Linha 24):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 24)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 25 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 25):
#   WKT recebido: 'MULTILINESTRING ((675390.4329833984 7183199.692993164, 675390.5530395508 7183198.893005371, 675390.7...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 25)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.457904066208783, -49.255557007305704)
#
# Processando Curva Nível 2 (CSV Linha 25):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 25)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 26 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 26):
#   WKT recebido: 'MULTILINESTRING ((675390.4329833984 7183199.692993164, 675390.5530395508 7183198.893005371, 675390.7...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 26)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.457904066208783, -49.255557007305704)
#
# Processando Curva Nível 2 (CSV Linha 26):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 26)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 27 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 27):
#   WKT recebido: 'MULTILINESTRING ((675312.4130249023 7182935.12298584, 675316.1329956055 7182936.013000488, 675319.14...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 27)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.460301379991442, -49.25629828996533)
#
# Processando Curva Nível 2 (CSV Linha 27):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 27)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 28 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 28):
#   WKT recebido: 'MULTILINESTRING ((675312.4130249023 7182935.12298584, 675316.1329956055 7182936.013000488, 675319.14...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 28)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.460301379991442, -49.25629828996533)
#
# Processando Curva Nível 2 (CSV Linha 28):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 28)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 29 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 29):
#   WKT recebido: 'MULTILINESTRING ((675312.4130249023 7182935.12298584, 675316.1329956055 7182936.013000488, 675319.14...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 29)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.460301379991442, -49.25629828996533)
#
# Processando Curva Nível 2 (CSV Linha 29):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 29)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 30 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 30):
#   WKT recebido: 'MULTILINESTRING ((675312.4130249023 7182935.12298584, 675316.1329956055 7182936.013000488, 675319.14...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 30)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.460301379991442, -49.25629828996533)
#
# Processando Curva Nível 2 (CSV Linha 30):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 30)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 31 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 31):
#   WKT recebido: 'MULTILINESTRING ((674803.6630249023 7182437.0830078125, 674805.5029907227 7182433.553039551, 674810....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 31)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.46485687361259, -49.2612919725031)
#
# Processando Curva Nível 2 (CSV Linha 31):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 31)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 32 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 32):
#   WKT recebido: 'MULTILINESTRING ((674803.6630249023 7182437.0830078125, 674805.5029907227 7182433.553039551, 674810....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 32)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.46485687361259, -49.2612919725031)
#
# Processando Curva Nível 2 (CSV Linha 32):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 32)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 33 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 33):
#   WKT recebido: 'MULTILINESTRING ((674803.6630249023 7182437.0830078125, 674805.5029907227 7182433.553039551, 674810....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 33)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.46485687361259, -49.2612919725031)
#
# Processando Curva Nível 2 (CSV Linha 33):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 33)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 34 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 34):
#   WKT recebido: 'MULTILINESTRING ((674803.2529907227 7182443.822998047, 674804.7930297852 7182441.983032227, 674808.1...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 34)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.464796084421387, -49.2612969241348)
#
# Processando Curva Nível 2 (CSV Linha 34):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 34)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 35 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 35):
#   WKT recebido: 'MULTILINESTRING ((674804.7730102539 7182453.822998047, 674808.923034668 7182450.2830200195, 674810.6...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 35)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.46470564187109, -49.26128310830889)
#
# Processando Curva Nível 2 (CSV Linha 35):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 35)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 36 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 36):
#   WKT recebido: 'MULTILINESTRING ((674805.3829956055 7182460.733032227, 674809.6929931641 7182459.502990723, 674812.1...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 36)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.46464319763641, -49.26127793996213)
#
# Processando Curva Nível 2 (CSV Linha 36):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 36)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 37 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 37):
#   WKT recebido: 'MULTILINESTRING ((674805.3829956055 7182460.733032227, 674809.6929931641 7182459.502990723, 674812.1...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 37)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.46464319763641, -49.26127793996213)
#
# Processando Curva Nível 2 (CSV Linha 37):
#   WKT recebido: 'MULTILINESTRING ((674350.8229980469 7186799.692993164, 674350.9030151367 7186798.853027344, 674351.9...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 37)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425531512440273, -49.26635865916389)
#
# --- Processando dados da Linha 38 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 38):
#   WKT recebido: 'MULTILINESTRING ((674808.7529907227 7182468.3330078125, 674813.8229980469 7182465.713012695, 674817....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 38)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.464574200594598, -49.26124541843464)
#
# Processando Curva Nível 2 (CSV Linha 38):
#   WKT recebido: 'MULTILINESTRING ((674350.8229980469 7186799.692993164, 674350.9030151367 7186798.853027344, 674351.9...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 38)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425531512440273, -49.26635865916389)
#
# --- Processando dados da Linha 39 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 39):
#   WKT recebido: 'MULTILINESTRING ((674807.3729858398 7182473.393005371, 674811.5230102539 7182471.403015137, 674815.6...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 39)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.464528689873838, -49.26125979644518)
#
# Processando Curva Nível 2 (CSV Linha 39):
#   WKT recebido: 'MULTILINESTRING ((674102.4130249023 7186799.692993164, 674102.7130126953 7186798.343017578, 674104.4...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 39)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425560629361737, -49.26882780661129)
#
# --- Processando dados da Linha 40 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 40):
#   WKT recebido: 'MULTILINESTRING ((674809.0230102539 7182476.192993164, 674811.7830200195 7182476.043029785, 674816.0...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 40)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.46450322182045, -49.26124375365884)
#
# Processando Curva Nível 2 (CSV Linha 40):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 40)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 41 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 41):
#   WKT recebido: 'MULTILINESTRING ((674809.0230102539 7182476.192993164, 674811.7830200195 7182476.043029785, 674816.0...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 41)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.46450322182045, -49.26124375365884)
#
# Processando Curva Nível 2 (CSV Linha 41):
#   WKT recebido: 'MULTILINESTRING ((673202.1530151367 7185925.023010254, 673205.4030151367 7185926.093017578, 673218.4...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 41)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.43356098640463, -49.27766399240444)
#
# --- Processando dados da Linha 42 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 42):
#   WKT recebido: 'MULTILINESTRING ((675303.4830322266 7183199.692993164, 675303.4830322266 7183199.663024902, 675303.4...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 42)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.457914338277394, -49.25642149879378)
#
# Processando Curva Nível 2 (CSV Linha 42):
#   WKT recebido: 'MULTILINESTRING ((674102.4130249023 7186799.692993164, 674102.7130126953 7186798.343017578, 674104.4...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 42)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425560629361737, -49.26882780661129)
#
# --- Processando dados da Linha 43 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 43):
#   WKT recebido: 'MULTILINESTRING ((675245.7678222656 7183107.140625, 675244.6829833984 7183106.733032227, 675237.4130...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 43)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.458756562505926, -49.25698329002697)
#
# Processando Curva Nível 2 (CSV Linha 43):
#   WKT recebido: 'MULTILINESTRING ((674102.4130249023 7186799.692993164, 674102.7130126953 7186798.343017578, 674104.4...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 43)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425560629361737, -49.26882780661129)
#
# --- Processando dados da Linha 44 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 44):
#   WKT recebido: 'MULTILINESTRING ((675291.2630004883 7183199.692993164, 675290.9030151367 7183193.463012695, 675289.8...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 44)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.45791578151637, -49.25654299531644)
#
# Processando Curva Nível 2 (CSV Linha 44):
#   WKT recebido: 'MULTILINESTRING ((674102.4130249023 7186799.692993164, 674102.7130126953 7186798.343017578, 674104.4...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 44)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425560629361737, -49.26882780661129)
#
# --- Processando dados da Linha 45 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 45):
#   WKT recebido: 'MULTILINESTRING ((675266.8030395508 7183199.692993164, 675269.4830322266 7183199.182983398, 675271.6...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 45)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.45791867004251, -49.25678618621842)
#
# Processando Curva Nível 2 (CSV Linha 45):
#   WKT recebido: 'MULTILINESTRING ((674102.4130249023 7186799.692993164, 674102.7130126953 7186798.343017578, 674104.4...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 45)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425560629361737, -49.26882780661129)
#
# --- Processando dados da Linha 46 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 46):
#   WKT recebido: 'MULTILINESTRING ((675284.8330078125 7183199.692993164, 675283.9530029297 7183197.0330200195, 675284....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 46)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.45791654088618, -49.256606924920995)
#
# Processando Curva Nível 2 (CSV Linha 46):
#   WKT recebido: 'MULTILINESTRING ((674038.3930053711 7185599.692993164, 674042.0830078125 7185593.1329956055, 674049....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 46)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.43639984052244, -49.26930938767225)
#
# --- Processando dados da Linha 47 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 47):
#   WKT recebido: 'MULTILINESTRING ((675291.2630004883 7183199.692993164, 675290.9030151367 7183193.463012695, 675289.8...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 47)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.45791578151637, -49.25654299531644)
#
# Processando Curva Nível 2 (CSV Linha 47):
#   WKT recebido: 'MULTILINESTRING ((674038.3930053711 7185599.692993164, 674042.0830078125 7185593.1329956055, 674049....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 47)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.43639984052244, -49.26930938767225)
#
# --- Processando dados da Linha 48 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 48):
#   WKT recebido: 'MULTILINESTRING ((675291.2630004883 7183199.692993164, 675290.9030151367 7183193.463012695, 675289.8...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 48)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.45791578151637, -49.25654299531644)
#
# Processando Curva Nível 2 (CSV Linha 48):
#   WKT recebido: 'MULTILINESTRING ((673202.1530151367 7185925.023010254, 673205.4030151367 7185926.093017578, 673218.4...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 48)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.43356098640463, -49.27766399240444)
#
# --- Processando dados da Linha 49 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 49):
#   WKT recebido: 'MULTILINESTRING ((675303.4830322266 7183199.692993164, 675303.4830322266 7183199.663024902, 675303.4...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 49)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.457914338277394, -49.25642149879378)
#
# Processando Curva Nível 2 (CSV Linha 49):
#   WKT recebido: 'MULTILINESTRING ((673202.1530151367 7185925.023010254, 673205.4030151367 7185926.093017578, 673218.4...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 49)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.43356098640463, -49.27766399240444)
#
# --- Processando dados da Linha 50 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 50):
#   WKT recebido: 'MULTILINESTRING ((675174.6430053711 7183002.502990723, 675176.923034668 7183002.793029785, 675179.49...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 50)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.459709453390435, -49.257676843323075)
#
# Processando Curva Nível 2 (CSV Linha 50):
#   WKT recebido: 'MULTILINESTRING ((673969.7230224609 7185599.692993164, 673963.4030151367 7185595.963012695, 673960.4...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 50)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.436407883185453, -49.269992016036824)
#
# --- Processando dados da Linha 51 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 51):
#   WKT recebido: 'MULTILINESTRING ((675245.7678222656 7183107.140625, 675244.6829833984 7183106.733032227, 675237.4130...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 51)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.458756562505926, -49.25698329002697)
#
# Processando Curva Nível 2 (CSV Linha 51):
#   WKT recebido: 'MULTILINESTRING ((673908.9130249023 7185599.692993164, 673922.2930297852 7185566.993041992, 673940.9...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 51)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.43641500263689, -49.27059651081267)
#
# --- Processando dados da Linha 52 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 52):
#   WKT recebido: 'MULTILINESTRING ((675266.8030395508 7183199.692993164, 675269.4830322266 7183199.182983398, 675271.6...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 52)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.45791867004251, -49.25678618621842)
#
# Processando Curva Nível 2 (CSV Linha 52):
#   WKT recebido: 'MULTILINESTRING ((673969.7230224609 7185599.692993164, 673963.4030151367 7185595.963012695, 673960.4...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 52)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.436407883185453, -49.269992016036824)
#
# --- Processando dados da Linha 53 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 53):
#   WKT recebido: 'MULTILINESTRING ((675266.8030395508 7183199.692993164, 675269.4830322266 7183199.182983398, 675271.6...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 53)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.45791867004251, -49.25678618621842)
#
# Processando Curva Nível 2 (CSV Linha 53):
#   WKT recebido: 'MULTILINESTRING ((673969.7230224609 7185599.692993164, 673963.4030151367 7185595.963012695, 673960.4...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 53)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.436407883185453, -49.269992016036824)
#
# --- Processando dados da Linha 54 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 54):
#   WKT recebido: 'MULTILINESTRING ((675143.1030273438 7183199.692993164, 675144.4530029297 7183197.233032227, 675145.7...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 54)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.457933271861393, -49.258016062734356)
#
# Processando Curva Nível 2 (CSV Linha 54):
#   WKT recebido: 'MULTILINESTRING ((673969.7230224609 7185599.692993164, 673963.4030151367 7185595.963012695, 673960.4...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 54)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.436407883185453, -49.269992016036824)
#
# --- Processando dados da Linha 55 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 55):
#   WKT recebido: 'MULTILINESTRING ((675038.6929931641 7183199.692993164, 675039.0330200195 7183198.023010254, 675039.4...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 55)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.45794558863749, -49.259054151079695)
#
# Processando Curva Nível 2 (CSV Linha 55):
#   WKT recebido: 'MULTILINESTRING ((673908.9130249023 7185599.692993164, 673922.2930297852 7185566.993041992, 673940.9...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 55)'.
# ...
#   WKT recebido: 'MULTILINESTRING ((677068.3430175781 7178399.692993164, 677071.5430297852 7178395.5830078125, 677071....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 541)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.50103070201143, -49.23824318130061)
#
# --- Processando dados da Linha 542 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 542):
#   WKT recebido: 'MULTILINESTRING ((676411.3430175781 7179828.223022461, 676415.0729980469 7179827.233032227, 676419.8...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 542)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.48821484264416, -49.24496500662535)
#
# Processando Curva Nível 2 (CSV Linha 542):
#   WKT recebido: 'MULTILINESTRING ((677068.3430175781 7178399.692993164, 677071.5430297852 7178395.5830078125, 677071....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 542)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.50103070201143, -49.23824318130061)
#
# --- Processando dados da Linha 543 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 543):
#   WKT recebido: 'MULTILINESTRING ((676411.3430175781 7179828.223022461, 676415.0729980469 7179827.233032227, 676419.8...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 543)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.48821484264416, -49.24496500662535)
#
# Processando Curva Nível 2 (CSV Linha 543):
#   WKT recebido: 'MULTILINESTRING ((677068.3430175781 7178399.692993164, 677071.5430297852 7178395.5830078125, 677071....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 543)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.50103070201143, -49.23824318130061)
#
# --- Processando dados da Linha 544 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 544):
#   WKT recebido: 'MULTILINESTRING ((676411.3430175781 7179828.223022461, 676415.0729980469 7179827.233032227, 676419.8...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 544)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.48821484264416, -49.24496500662535)
#
# Processando Curva Nível 2 (CSV Linha 544):
#   WKT recebido: 'MULTILINESTRING ((677068.3430175781 7178399.692993164, 677071.5430297852 7178395.5830078125, 677071....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 544)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.50103070201143, -49.23824318130061)
#
# --- Processando dados da Linha 545 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 545):
#   WKT recebido: 'MULTILINESTRING ((676411.3430175781 7179828.223022461, 676415.0729980469 7179827.233032227, 676419.8...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 545)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.48821484264416, -49.24496500662535)
#
# Processando Curva Nível 2 (CSV Linha 545):
#   WKT recebido: 'MULTILINESTRING ((677068.3430175781 7178399.692993164, 677071.5430297852 7178395.5830078125, 677071....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 545)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.50103070201143, -49.23824318130061)
#
# --- Processando dados da Linha 546 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 546):
#   WKT recebido: 'MULTILINESTRING ((676411.3430175781 7179828.223022461, 676415.0729980469 7179827.233032227, 676419.8...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 546)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.48821484264416, -49.24496500662535)
#
# Processando Curva Nível 2 (CSV Linha 546):
#   WKT recebido: 'MULTILINESTRING ((677068.3430175781 7178399.692993164, 677071.5430297852 7178395.5830078125, 677071....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 546)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.50103070201143, -49.23824318130061)
#
# --- Processando dados da Linha 547 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 547):
#   WKT recebido: 'MULTILINESTRING ((676465.6329956055 7179599.692993164, 676464.8530273438 7179598.5830078125, 676464....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 547)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.490271146346167, -49.24439512421466)
#
# Processando Curva Nível 2 (CSV Linha 547):
#   WKT recebido: 'MULTILINESTRING ((676403.2930297852 7179163.673034668, 676409.1030273438 7179160.942993164, 676414.4...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 547)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.494214186258436, -49.2449579113921)
#
# --- Processando dados da Linha 548 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 548):
#   WKT recebido: 'MULTILINESTRING ((676465.6329956055 7179599.692993164, 676464.8530273438 7179598.5830078125, 676464....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 548)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.490271146346167, -49.24439512421466)
#
# Processando Curva Nível 2 (CSV Linha 548):
#   WKT recebido: 'MULTILINESTRING ((676403.2930297852 7179163.673034668, 676409.1030273438 7179160.942993164, 676414.4...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 548)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.494214186258436, -49.2449579113921)
#
# --- Processando dados da Linha 549 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 549):
#   WKT recebido: 'MULTILINESTRING ((676465.6329956055 7179599.692993164, 676464.8530273438 7179598.5830078125, 676464....'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 549)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.490271146346167, -49.24439512421466)
#
# Processando Curva Nível 2 (CSV Linha 549):
#   WKT recebido: 'MULTILINESTRING ((677096.0230102539 7178399.692993164, 677095.423034668 7178398.713012695, 677094.48...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 549)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.501027393236473, -49.237967880112585)
#
# --- Processando dados da Linha 550 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 550):
#   WKT recebido: 'MULTILINESTRING ((676723.9030151367 7179400.62298584, 676721.7730102539 7179402.223022461, 676717.50...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 550)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.492037223336165, -49.241800476296106)
#
# Processando Curva Nível 2 (CSV Linha 550):
#   WKT recebido: 'MULTILINESTRING ((677096.0230102539 7178399.692993164, 677095.423034668 7178398.713012695, 677094.48...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 550)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.501027393236473, -49.237967880112585)
#
# --- Processando dados da Linha 551 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 551):
#   WKT recebido: 'MULTILINESTRING ((676403.4130249023 7179233.043029785, 676408.1229858398 7179231.20300293, 676413.23...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 551)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.493588022213395, -49.24496581669234)
#
# Processando Curva Nível 2 (CSV Linha 551):
#   WKT recebido: 'MULTILINESTRING ((676404.4429931641 7179108.62298584, 676409.1430053711 7179109.113037109, 676412.23...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 551)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.49471094390506, -49.24493925390696)
#
# --- Processando dados da Linha 552 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 552):
#   WKT recebido: 'MULTILINESTRING ((676403.4130249023 7179233.043029785, 676408.1229858398 7179231.20300293, 676413.23...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 552)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.493588022213395, -49.24496581669234)
#
# Processando Curva Nível 2 (CSV Linha 552):
#   WKT recebido: 'MULTILINESTRING ((676404.4429931641 7179108.62298584, 676409.1430053711 7179109.113037109, 676412.23...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 552)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.49471094390506, -49.24493925390696)
#
# --- Processando dados da Linha 553 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 553):
#   WKT recebido: 'MULTILINESTRING ((676403.4130249023 7179233.043029785, 676408.1229858398 7179231.20300293, 676413.23...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 553)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.493588022213395, -49.24496581669234)
#
# Processando Curva Nível 2 (CSV Linha 553):
#   WKT recebido: 'MULTILINESTRING ((676404.4429931641 7179108.62298584, 676409.1430053711 7179109.113037109, 676412.23...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 553)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.49471094390506, -49.24493925390696)
#
# --- Processando dados da Linha 554 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 554):
#   WKT recebido: 'MULTILINESTRING ((676403.4130249023 7179233.043029785, 676408.1229858398 7179231.20300293, 676413.23...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 554)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.493588022213395, -49.24496581669234)
#
# Processando Curva Nível 2 (CSV Linha 554):
#   WKT recebido: 'MULTILINESTRING ((676404.4429931641 7179108.62298584, 676409.1430053711 7179109.113037109, 676412.23...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 554)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.49471094390506, -49.24493925390696)
#
# --- Processando dados da Linha 555 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 555):
#   WKT recebido: 'MULTILINESTRING ((676403.4130249023 7179233.043029785, 676408.1229858398 7179231.20300293, 676413.23...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 555)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.493588022213395, -49.24496581669234)
#
# Processando Curva Nível 2 (CSV Linha 555):
#   WKT recebido: 'MULTILINESTRING ((676404.4429931641 7179108.62298584, 676409.1430053711 7179109.113037109, 676412.23...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 555)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.49471094390506, -49.24493925390696)
#
# --- Processando dados da Linha 556 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 556):
#   WKT recebido: 'MULTILINESTRING ((676790.5642089844 7179064.997802734, 676791.3930053711 7179065.093017578, 676795.1...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 556)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4950586977814, -49.24109340499131)
#
# Processando Curva Nível 2 (CSV Linha 556):
#   WKT recebido: 'MULTILINESTRING ((676404.4429931641 7179108.62298584, 676409.1430053711 7179109.113037109, 676412.23...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 556)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.49471094390506, -49.24493925390696)
#
# --- Processando dados da Linha 557 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 557):
#   WKT recebido: 'MULTILINESTRING ((676790.5642089844 7179064.997802734, 676791.3930053711 7179065.093017578, 676795.1...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 557)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4950586977814, -49.24109340499131)
#
# Processando Curva Nível 2 (CSV Linha 557):
#   WKT recebido: 'MULTILINESTRING ((676404.4429931641 7179108.62298584, 676409.1430053711 7179109.113037109, 676412.23...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 557)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.49471094390506, -49.24493925390696)
#
# --- Processando dados da Linha 558 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 558):
#   WKT recebido: 'MULTILINESTRING ((676790.5642089844 7179064.997802734, 676791.3930053711 7179065.093017578, 676795.1...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 558)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4950586977814, -49.24109340499131)
#
# Processando Curva Nível 2 (CSV Linha 558):
#   WKT recebido: 'MULTILINESTRING ((676404.4429931641 7179108.62298584, 676409.1430053711 7179109.113037109, 676412.23...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 558)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.49471094390506, -49.24493925390696)
#
# --- Processando dados da Linha 559 do CSV ---
#
# Processando Curva Nível 1 (CSV Linha 559):
#   WKT recebido: 'MULTILINESTRING ((676790.5642089844 7179064.997802734, 676791.3930053711 7179065.093017578, 676795.1...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 1 (CSV Linha 559)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4950586977814, -49.24109340499131)
#
# Processando Curva Nível 2 (CSV Linha 559):
#   WKT recebido: 'MULTILINESTRING ((676404.4429931641 7179108.62298584, 676409.1430053711 7179109.113037109, 676412.23...'
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha (reprojetados) adicionado(s) para 'Curva Nível 2 (CSV Linha 559)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.49471094390506, -49.24493925390696)
#
# Mapa salvo como 'mapa_curvas_multiplas_linhas.html'. Abra este arquivo em um navegador para visualizar.

# %%
import folium
from folium import FeatureGroup, LayerControl
from shapely import wkt
import pandas as pd
from pyproj import Transformer, CRS

# ==============================================================================
# CONFIGURAÇÕES DO USUÁRIO - AJUSTE CONFORME NECESSÁRIO
# ==============================================================================

# 1. Códigos EPSG para reprojeção de coordenadas das LINHAS
# Consulte a origem dos seus dados para saber o EPSG correto das geometrias de linha.
SOURCE_EPSG = "EPSG:31982"  # Ex: SIRGAS 2000 / UTM zone 22S (ajuste se necessário)
TARGET_EPSG = "EPSG:4326"    # WGS84 (Latitude/Longitude) que o Folium usa

# 2. Nomes das colunas de altitude no seu arquivo CSV
# Estes devem corresponder aos nomes de colunas identificados no seu arquivo:
ALTITUDE_PONTO_COL = 'altimetria_interpolada' # Altitude do ponto principal
ALTITUDE_LINHA1_COL = 'linha1_elevation'     # Altitude da primeira curva de nível associada
ALTITUDE_LINHA2_COL = 'linha2_elevation'     # Altitude da segunda curva de nível associada
UNIDADE_ALTITUDE = "m" # Ex: "metros", "unidades" - usado nos popups

# 3. Caminho para o arquivo CSV
FILE_PATH_CSV = 'resultado1.csv'

# 4. Nome do arquivo HTML de saída do mapa
OUTPUT_MAP_FILE = 'mapa_pontos_com_associacao_curvas.html'
# ==============================================================================

# Criar o objeto Transformer
try:
    transformer = Transformer.from_crs(CRS.from_string(SOURCE_EPSG), CRS.from_string(TARGET_EPSG), always_xy=True)
except Exception as e:
    print(f"Erro ao criar o transformador de coordenadas com pyproj: {e}")
    print(f"Verifique se o código SOURCE_EPSG ('{SOURCE_EPSG}') está correto e se pyproj está instalado.")
    exit()

df = resultado_copia.copy()

if df.empty:
    print(f"Erro: O DataFrame carregado de '{FILE_PATH_CSV}' está vazio.")
    exit()

# Verificação das colunas obrigatórias (incluindo altitudes)
required_columns = ['Latitude', 'Longitude', 'linha1_geometry', 'linha2_geometry', # Geometrias
                    ALTITUDE_PONTO_COL, ALTITUDE_LINHA1_COL, ALTITUDE_LINHA2_COL]   # Altitudes
missing_cols = [col for col in required_columns if col not in df.columns]
if missing_cols:
    print(f"Erro: As seguintes colunas obrigatórias não foram encontradas no CSV: {', '.join(missing_cols)}")
    print(f"Colunas encontradas no CSV: {df.columns.tolist()}")
    print(f"Verifique os nomes das colunas definidos em ALTITUDE_PONTO_COL, ALTITUDE_LINHA1_COL, ALTITUDE_LINHA2_COL.")
    exit()

# Definição do centro do mapa (usando a primeira linha)
map_center_latitude = df.loc[0, 'Latitude']
map_center_longitude = df.loc[0, 'Longitude']
print(f"Centro do mapa: Lat: {map_center_latitude}, Lon: {map_center_longitude} (da primeira linha do CSV)")

# Criação do mapa
m = folium.Map(location=[map_center_latitude, map_center_longitude], zoom_start=12)

# FeatureGroups gerais
fg_pontos_todos = FeatureGroup(name='Pontos Principais', show=True)
m.add_child(fg_pontos_todos)
fg_curva1_todas = FeatureGroup(name='Curvas de Nível 1', show=True)
m.add_child(fg_curva1_todas)
fg_curva2_todas = FeatureGroup(name='Curvas de Nível 2', show=True)
m.add_child(fg_curva2_todas)

# Função auxiliar para adicionar geometrias de linha com REPROJEÇÃO e ALTITUDE
def adicionar_geometria_linha(wkt_string, feature_group, cor_linha, nome_camada_debug, altitude_valor):
    print(f"\nProcessando {nome_camada_debug}:")
    if pd.isna(wkt_string) or not str(wkt_string).strip():
        print(f"  Aviso: String WKT para '{nome_camada_debug}' está vazia ou é NaN. Camada pulada.")
        return

    altitude_display = f"{altitude_valor} {UNIDADE_ALTITUDE}" if pd.notna(altitude_valor) else "N/A"
    popup_text_linha = f"Altitude da Curva: {altitude_display}" # Popup para a própria linha
    tooltip_text_linha = f"Alt: {altitude_display}" # Tooltip para a própria linha

    wkt_string_preview = str(wkt_string)[:100] + ('...' if len(str(wkt_string)) > 100 else '')
    print(f"  WKT recebido: '{wkt_string_preview}', Altitude associada à linha: {altitude_display}")

    try:
        geom = wkt.loads(str(wkt_string))
    except Exception as e:
        print(f"  Erro ao parsear WKT para '{nome_camada_debug}': {wkt_string_preview}. Erro: {e}")
        return

    if geom.is_empty:
        print(f"  Aviso: Geometria WKT parseada para '{nome_camada_debug}' está vazia. Camada pulada.")
        return
    print(f"  Tipo de geometria parseada: {geom.geom_type}")

    linhas_para_plotar_orig = []
    if geom.geom_type == 'LineString':
        linhas_para_plotar_orig.append(geom)
    elif geom.geom_type == 'MultiLineString':
        linhas_para_plotar_orig.extend(list(geom.geoms))
    else:
        print(f"  Aviso: Tipo de geometria não suportado '{geom.geom_type}' para '{nome_camada_debug}'. Camada pulada.")
        return

    if not linhas_para_plotar_orig:
        print(f"  Aviso: Nenhuma linha individual encontrada em '{nome_camada_debug}'.")
        return
        
    segmentos_adicionados = 0
    coords_reprojetadas_folium_exemplo = []
    for i, linha_orig in enumerate(linhas_para_plotar_orig):
        if linha_orig.is_empty:
            print(f"  Aviso: Segmento {i} (original) de '{nome_camada_debug}' está vazio.")
            continue
        
        coords_originais_projetadas = list(linha_orig.coords)
        if not coords_originais_projetadas:
            print(f"  Aviso: Segmento {i} (original) de '{nome_camada_debug}' não possui coordenadas.")
            continue
        
        coords_reprojetadas_folium = []
        try:
            for x_proj, y_proj in coords_originais_projetadas:
                lon_deg, lat_deg = transformer.transform(x_proj, y_proj)
                coords_reprojetadas_folium.append((lat_deg, lon_deg))
        except Exception as e:
            print(f"    Erro durante reprojeção do segmento {i} de '{nome_camada_debug}': {e}")
            continue

        if not coords_reprojetadas_folium:
            print(f"  Aviso: Segmento {i} de '{nome_camada_debug}' não possui coordenadas após reprojeção.")
            continue
        
        if not coords_reprojetadas_folium_exemplo:
            coords_reprojetadas_folium_exemplo = coords_reprojetadas_folium

        folium.PolyLine(
            coords_reprojetadas_folium,
            color=cor_linha,
            weight=2.5,
            opacity=0.8,
            popup=popup_text_linha, 
            tooltip=tooltip_text_linha 
        ).add_to(feature_group)
        segmentos_adicionados +=1
    
    if segmentos_adicionados > 0:
        print(f"  {segmentos_adicionados} segmento(s) de linha adicionado(s) para '{nome_camada_debug}'.")
        if coords_reprojetadas_folium_exemplo and coords_reprojetadas_folium_exemplo[0]:
             print(f"    Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): {coords_reprojetadas_folium_exemplo[0]}")
    else:
        print(f"  Nenhum segmento de linha válido foi adicionado para '{nome_camada_debug}'.")

# Iterar sobre cada linha do DataFrame
for index, row in df.iterrows():
    print(f"\n--- Processando dados da Linha {index} do CSV ---")
    
    current_lat = row['Latitude']
    current_lon = row['Longitude']
    
    # Altitude do Ponto
    altitude_ponto_val = row[ALTITUDE_PONTO_COL]
    altitude_ponto_display = f"{altitude_ponto_val} {UNIDADE_ALTITUDE}" if pd.notna(altitude_ponto_val) else "N/A"
    
    # Informações da Linha 1 associada
    altitude_l1_val = row[ALTITUDE_LINHA1_COL]
    linha1_elev_display = f"{altitude_l1_val} {UNIDADE_ALTITUDE}" if pd.notna(altitude_l1_val) else "Nenhuma"

    # Informações da Linha 2 associada
    altitude_l2_val = row[ALTITUDE_LINHA2_COL]
    linha2_elev_display = f"{altitude_l2_val} {UNIDADE_ALTITUDE}" if pd.notna(altitude_l2_val) else "Nenhuma"

    # --- ALTERAÇÃO AQUI: Popup e Tooltip do Marcador do Ponto ---
    popup_html_marker = f"""
    <b>Ponto ID: {index}</b><br>
    ------------------------------------<br>
    <b>Coordenadas:</b><br>
    &nbsp;&nbsp;Latitude: {current_lat:.5f}<br>
    &nbsp;&nbsp;Longitude: {current_lon:.5f}<br>
    <b>Altitude do Ponto:</b> {altitude_ponto_display}<br>
    ------------------------------------<br>
    <b>Curvas de Nível Associadas:</b><br>
    &nbsp;&nbsp;<b>1ª Mais Próxima:</b> Elev. {linha1_elev_display}<br>
    &nbsp;&nbsp;<b>2ª Mais Próxima:</b> Elev. {linha2_elev_display}
    """
    # Opcional: Adicionar GIDs ou outros identificadores se úteis
    # if 'linha1_gid' in row and pd.notna(row['linha1_gid']):
    #     popup_html_marker += f"<br>&nbsp;&nbsp;(GID Linha 1: {row['linha1_gid']})"
    # if 'linha2_gid' in row and pd.notna(row['linha2_gid']):
    #     popup_html_marker += f"<br>&nbsp;&nbsp;(GID Linha 2: {row['linha2_gid']})"

    tooltip_text_marker = (f"Ponto {index} (Alt: {altitude_ponto_display}) | "
                           f"L1: {linha1_elev_display} | L2: {linha2_elev_display}")

    folium.Marker(
        location=[current_lat, current_lon],
        popup=folium.Popup(popup_html_marker, max_width=400), 
        tooltip=tooltip_text_marker,
        icon=folium.Icon(color='purple', icon='info-sign')
    ).add_to(fg_pontos_todos)
    # --- FIM DA ALTERAÇÃO ---

    print(f"  Ponto Principal (Linha CSV {index}): Lat={current_lat}, Lon={current_lon}, Alt Ponto={altitude_ponto_display}")
    print(f"    -> Associado à Linha 1 (Elev: {linha1_elev_display}), Linha 2 (Elev: {linha2_elev_display})")

    # Processar Curva de Nível 1 (esta parte permanece como antes)
    wkt_l1 = row['linha1_geometry']
    # altitude_l1_val já foi obtida acima para o popup do ponto, usamos a mesma aqui para a linha
    debug_name_l1 = f"Curva Nível 1 (CSV Linha {index})"
    adicionar_geometria_linha(wkt_l1, fg_curva1_todas, 'blue', debug_name_l1, altitude_l1_val)

    # Processar Curva de Nível 2 (esta parte permanece como antes)
    wkt_l2 = row['linha2_geometry']
    # altitude_l2_val já foi obtida acima para o popup do ponto, usamos a mesma aqui para a linha
    debug_name_l2 = f"Curva Nível 2 (CSV Linha {index})"
    adicionar_geometria_linha(wkt_l2, fg_curva2_todas, 'green', debug_name_l2, altitude_l2_val)

# Controle de Camadas
LayerControl().add_to(m)

# Salvamento do mapa
m.save(OUTPUT_MAP_FILE)
print(f"\nMapa salvo como '{OUTPUT_MAP_FILE}'. Abra este arquivo em um navegador para visualizar.")
# Out:
# Centro do mapa: Lat: -25.516848128860715, Lon: -49.23005693809807 (da primeira linha do CSV)
#
# --- Processando dados da Linha 0 do CSV ---
#   Ponto Principal (Linha CSV 0): Lat=-25.516848128860715, Lon=-49.23005693809807, Alt Ponto=887.9621448635928 m
#     -> Associado à Linha 1 (Elev: 883.0 m), Linha 2 (Elev: 896.0 m)
#
# Processando Curva Nível 1 (CSV Linha 0):
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...', Altitude associada à linha: 883.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 0)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva Nível 2 (CSV Linha 0):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...', Altitude associada à linha: 896.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 0)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 1 do CSV ---
#   Ponto Principal (Linha CSV 1): Lat=-25.51686779171, Lon=-49.23013196903002, Alt Ponto=887.9616854362807 m
#     -> Associado à Linha 1 (Elev: 883.0 m), Linha 2 (Elev: 896.0 m)
#
# Processando Curva Nível 1 (CSV Linha 1):
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...', Altitude associada à linha: 883.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 1)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva Nível 2 (CSV Linha 1):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...', Altitude associada à linha: 896.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 1)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 2 do CSV ---
#   Ponto Principal (Linha CSV 2): Lat=-25.516919527273075, Lon=-49.2301003821536, Alt Ponto=887.9629781722624 m
#     -> Associado à Linha 1 (Elev: 883.0 m), Linha 2 (Elev: 896.0 m)
#
# Processando Curva Nível 1 (CSV Linha 2):
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...', Altitude associada à linha: 883.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 2)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva Nível 2 (CSV Linha 2):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...', Altitude associada à linha: 896.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 2)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 3 do CSV ---
#   Ponto Principal (Linha CSV 3): Lat=-25.51702360353063, Lon=-49.23004190226657, Alt Ponto=887.9655172312653 m
#     -> Associado à Linha 1 (Elev: 883.0 m), Linha 2 (Elev: 896.0 m)
#
# Processando Curva Nível 1 (CSV Linha 3):
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...', Altitude associada à linha: 883.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 3)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva Nível 2 (CSV Linha 3):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...', Altitude associada à linha: 896.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 3)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 4 do CSV ---
#   Ponto Principal (Linha CSV 4): Lat=-25.5171857650146, Lon=-49.22995042347812, Alt Ponto=887.2208387196874 m
#     -> Associado à Linha 1 (Elev: 883.0 m), Linha 2 (Elev: 894.0 m)
#
# Processando Curva Nível 1 (CSV Linha 4):
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...', Altitude associada à linha: 883.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 4)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva Nível 2 (CSV Linha 4):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....', Altitude associada à linha: 894.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 4)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 5 do CSV ---
#   Ponto Principal (Linha CSV 5): Lat=-25.517494354255668, Lon=-49.22977484197607, Alt Ponto=887.2271134873554 m
#     -> Associado à Linha 1 (Elev: 883.0 m), Linha 2 (Elev: 894.0 m)
#
# Processando Curva Nível 1 (CSV Linha 5):
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...', Altitude associada à linha: 883.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 5)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva Nível 2 (CSV Linha 5):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....', Altitude associada à linha: 894.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 5)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 6 do CSV ---
#   Ponto Principal (Linha CSV 6): Lat=-25.517573594340156, Lon=-49.22973337092479, Alt Ponto=887.2286810028943 m
#     -> Associado à Linha 1 (Elev: 883.0 m), Linha 2 (Elev: 894.0 m)
#
# Processando Curva Nível 1 (CSV Linha 6):
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...', Altitude associada à linha: 883.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 6)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva Nível 2 (CSV Linha 6):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....', Altitude associada à linha: 894.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 6)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 7 do CSV ---
#   Ponto Principal (Linha CSV 7): Lat=-25.51760278824863, Lon=-49.22971490172688, Alt Ponto=887.229287376855 m
#     -> Associado à Linha 1 (Elev: 883.0 m), Linha 2 (Elev: 894.0 m)
#
# Processando Curva Nível 1 (CSV Linha 7):
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...', Altitude associada à linha: 883.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 7)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva Nível 2 (CSV Linha 7):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....', Altitude associada à linha: 894.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 7)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 8 do CSV ---
#   Ponto Principal (Linha CSV 8): Lat=-25.517638033572982, Lon=-49.229749741433125, Alt Ponto=887.2294852120123 m
#     -> Associado à Linha 1 (Elev: 883.0 m), Linha 2 (Elev: 894.0 m)
#
# Processando Curva Nível 1 (CSV Linha 8):
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...', Altitude associada à linha: 883.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 8)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva Nível 2 (CSV Linha 8):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....', Altitude associada à linha: 894.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 8)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 9 do CSV ---
#   Ponto Principal (Linha CSV 9): Lat=-25.517697026519706, Lon=-49.229812715323085, Alt Ponto=887.2297752114761 m
#     -> Associado à Linha 1 (Elev: 883.0 m), Linha 2 (Elev: 894.0 m)
#
# Processando Curva Nível 1 (CSV Linha 9):
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...', Altitude associada à linha: 883.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 9)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva Nível 2 (CSV Linha 9):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....', Altitude associada à linha: 894.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 9)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 10 do CSV ---
#   Ponto Principal (Linha CSV 10): Lat=-25.517728640977914, Lon=-49.22986465411179, Alt Ponto=887.2297632697941 m
#     -> Associado à Linha 1 (Elev: 883.0 m), Linha 2 (Elev: 894.0 m)
#
# Processando Curva Nível 1 (CSV Linha 10):
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...', Altitude associada à linha: 883.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 10)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva Nível 2 (CSV Linha 10):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....', Altitude associada à linha: 894.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 10)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 11 do CSV ---
#   Ponto Principal (Linha CSV 11): Lat=-25.517738699365747, Lon=-49.22990638148411, Alt Ponto=887.2295265482595 m
#     -> Associado à Linha 1 (Elev: 883.0 m), Linha 2 (Elev: 894.0 m)
#
# Processando Curva Nível 1 (CSV Linha 11):
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...', Altitude associada à linha: 883.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 11)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva Nível 2 (CSV Linha 11):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....', Altitude associada à linha: 894.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 11)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 12 do CSV ---
#   Ponto Principal (Linha CSV 12): Lat=-25.51774391662384, Lon=-49.22995012051319, Alt Ponto=887.2291998057043 m
#     -> Associado à Linha 1 (Elev: 883.0 m), Linha 2 (Elev: 894.0 m)
#
# Processando Curva Nível 1 (CSV Linha 12):
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...', Altitude associada à linha: 883.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 12)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva Nível 2 (CSV Linha 12):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....', Altitude associada à linha: 894.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 12)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 13 do CSV ---
#   Ponto Principal (Linha CSV 13): Lat=-25.51774739201693, Lon=-49.23003659274297, Alt Ponto=887.2284535021432 m
#     -> Associado à Linha 1 (Elev: 883.0 m), Linha 2 (Elev: 894.0 m)
#
# Processando Curva Nível 1 (CSV Linha 13):
#   WKT recebido: 'MULTILINESTRING ((675208.1430053711 7182001.752990723, 675207.1430053711 7182005.733032227, 675205.9...', Altitude associada à linha: 883.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 13)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.468738598029258, -49.25721360195566)
#
# Processando Curva Nível 2 (CSV Linha 13):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....', Altitude associada à linha: 894.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 13)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 14 do CSV ---
#   Ponto Principal (Linha CSV 14): Lat=-25.51773271317477, Lon=-49.23012708828627, Alt Ponto=887.8602960937493 m
#     -> Associado à Linha 1 (Elev: 884.0 m), Linha 2 (Elev: 894.0 m)
#
# Processando Curva Nível 1 (CSV Linha 14):
#   WKT recebido: 'MULTILINESTRING ((675640.1829833984 7183199.692993164, 675638.2030029297 7183197.963012695, 675637.1...', Altitude associada à linha: 884.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 14)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.45787453302728, -49.25307389469072)
#
# Processando Curva Nível 2 (CSV Linha 14):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....', Altitude associada à linha: 894.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 14)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 15 do CSV ---
#   Ponto Principal (Linha CSV 15): Lat=-25.517702212193697, Lon=-49.23018782485944, Alt Ponto=888.5137438380391 m
#     -> Associado à Linha 1 (Elev: 885.0 m), Linha 2 (Elev: 894.0 m)
#
# Processando Curva Nível 1 (CSV Linha 15):
#   WKT recebido: 'MULTILINESTRING ((675347.1030273438 7182257.743041992, 675348.6929931641 7182257.0330200195, 675351....', Altitude associada à linha: 885.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 15)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.466411532455577, -49.25586520984545)
#
# Processando Curva Nível 2 (CSV Linha 15):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....', Altitude associada à linha: 894.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 15)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 16 do CSV ---
#   Ponto Principal (Linha CSV 16): Lat=-25.51765537239488, Lon=-49.23023783259657, Alt Ponto=888.5128845978746 m
#     -> Associado à Linha 1 (Elev: 885.0 m), Linha 2 (Elev: 894.0 m)
#
# Processando Curva Nível 1 (CSV Linha 16):
#   WKT recebido: 'MULTILINESTRING ((675347.1030273438 7182257.743041992, 675348.6929931641 7182257.0330200195, 675351....', Altitude associada à linha: 885.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 16)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.466411532455577, -49.25586520984545)
#
# Processando Curva Nível 2 (CSV Linha 16):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....', Altitude associada à linha: 894.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 16)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 17 do CSV ---
#   Ponto Principal (Linha CSV 17): Lat=-25.517613071161087, Lon=-49.230270405975126, Alt Ponto=889.1244110868253 m
#     -> Associado à Linha 1 (Elev: 886.0 m), Linha 2 (Elev: 894.0 m)
#
# Processando Curva Nível 1 (CSV Linha 17):
#   WKT recebido: 'MULTILINESTRING ((674807.0530395508 7182335.682983398, 674809.9730224609 7182332.913024902, 674813.3...', Altitude associada à linha: 886.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 17)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.465771746050365, -49.26124510608592)
#
# Processando Curva Nível 2 (CSV Linha 17):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....', Altitude associada à linha: 894.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 17)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 18 do CSV ---
#   Ponto Principal (Linha CSV 18): Lat=-25.517544748827376, Lon=-49.23030901432395, Alt Ponto=889.1234720457161 m
#     -> Associado à Linha 1 (Elev: 886.0 m), Linha 2 (Elev: 894.0 m)
#
# Processando Curva Nível 1 (CSV Linha 18):
#   WKT recebido: 'MULTILINESTRING ((674807.0530395508 7182335.682983398, 674809.9730224609 7182332.913024902, 674813.3...', Altitude associada à linha: 886.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 18)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.465771746050365, -49.26124510608592)
#
# Processando Curva Nível 2 (CSV Linha 18):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....', Altitude associada à linha: 894.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 18)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 19 do CSV ---
#   Ponto Principal (Linha CSV 19): Lat=-25.51735061558928, Lon=-49.23040567703697, Alt Ponto=891.5619025686465 m
#     -> Associado à Linha 1 (Elev: 890.0 m), Linha 2 (Elev: 894.0 m)
#
# Processando Curva Nível 1 (CSV Linha 19):
#   WKT recebido: 'MULTILINESTRING ((675477.1329956055 7183199.692993164, 675475.1229858398 7183194.353027344, 675473.3...', Altitude associada à linha: 890.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 19)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.457893818602937, -49.25469500128204)
#
# Processando Curva Nível 2 (CSV Linha 19):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....', Altitude associada à linha: 894.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 19)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 20 do CSV ---
#   Ponto Principal (Linha CSV 20): Lat=-25.51711896341527, Lon=-49.23051575079501, Alt Ponto=892.1705463197222 m
#     -> Associado à Linha 1 (Elev: 891.0 m), Linha 2 (Elev: 894.0 m)
#
# Processando Curva Nível 1 (CSV Linha 20):
#   WKT recebido: 'MULTILINESTRING ((675432.7230224609 7183199.692993164, 675434.1030273438 7183195.043029785, 675435.1...', Altitude associada à linha: 891.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 20)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.45789906832163, -49.255136542849314)
#
# Processando Curva Nível 2 (CSV Linha 20):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....', Altitude associada à linha: 894.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 20)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 21 do CSV ---
#   Ponto Principal (Linha CSV 21): Lat=-25.516484492655778, Lon=-49.23084260639495, Alt Ponto=892.7783315053002 m
#     -> Associado à Linha 1 (Elev: 892.0 m), Linha 2 (Elev: 894.0 m)
#
# Processando Curva Nível 1 (CSV Linha 21):
#   WKT recebido: 'MULTILINESTRING ((675427.923034668 7183199.692993164, 675427.7830200195 7183194.663024902, 675428.09...', Altitude associada à linha: 892.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 21)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.45789963565043, -49.25518426623914)
#
# Processando Curva Nível 2 (CSV Linha 21):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....', Altitude associada à linha: 894.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 21)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 22 do CSV ---
#   Ponto Principal (Linha CSV 22): Lat=-25.51629002784308, Lon=-49.23094462061306, Alt Ponto=894.0000000000001 m
#     -> Associado à Linha 1 (Elev: 894.0 m), Linha 2 (Elev: 894.0 m)
#
# Processando Curva Nível 1 (CSV Linha 22):
#   WKT recebido: 'MULTILINESTRING ((675390.4329833984 7183199.692993164, 675390.5530395508 7183198.893005371, 675390.7...', Altitude associada à linha: 894.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 22)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.457904066208783, -49.255557007305704)
#
# Processando Curva Nível 2 (CSV Linha 22):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....', Altitude associada à linha: 894.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 22)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 23 do CSV ---
#   Ponto Principal (Linha CSV 23): Lat=-25.51623294580173, Lon=-49.23083341341623, Alt Ponto=894.0 m
#     -> Associado à Linha 1 (Elev: 894.0 m), Linha 2 (Elev: 894.0 m)
#
# Processando Curva Nível 1 (CSV Linha 23):
#   WKT recebido: 'MULTILINESTRING ((675390.4329833984 7183199.692993164, 675390.5530395508 7183198.893005371, 675390.7...', Altitude associada à linha: 894.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 23)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.457904066208783, -49.255557007305704)
#
# Processando Curva Nível 2 (CSV Linha 23):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....', Altitude associada à linha: 894.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 23)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 24 do CSV ---
#   Ponto Principal (Linha CSV 24): Lat=-25.516138292253995, Lon=-49.2306467168522, Alt Ponto=894.0 m
#     -> Associado à Linha 1 (Elev: 894.0 m), Linha 2 (Elev: 894.0 m)
#
# Processando Curva Nível 1 (CSV Linha 24):
#   WKT recebido: 'MULTILINESTRING ((675390.4329833984 7183199.692993164, 675390.5530395508 7183198.893005371, 675390.7...', Altitude associada à linha: 894.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 24)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.457904066208783, -49.255557007305704)
#
# Processando Curva Nível 2 (CSV Linha 24):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....', Altitude associada à linha: 894.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 24)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 25 do CSV ---
#   Ponto Principal (Linha CSV 25): Lat=-25.516041218109244, Lon=-49.23046538470622, Alt Ponto=894.0 m
#     -> Associado à Linha 1 (Elev: 894.0 m), Linha 2 (Elev: 894.0 m)
#
# Processando Curva Nível 1 (CSV Linha 25):
#   WKT recebido: 'MULTILINESTRING ((675390.4329833984 7183199.692993164, 675390.5530395508 7183198.893005371, 675390.7...', Altitude associada à linha: 894.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 25)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.457904066208783, -49.255557007305704)
#
# Processando Curva Nível 2 (CSV Linha 25):
#   WKT recebido: 'MULTILINESTRING ((674443.7230224609 7186799.692993164, 674443.7529907227 7186799.0830078125, 674447....', Altitude associada à linha: 894.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 25)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4255206126827, -49.26543525173801)
#
# --- Processando dados da Linha 26 do CSV ---
#   Ponto Principal (Linha CSV 26): Lat=-25.515829520432543, Lon=-49.2305588635849, Alt Ponto=894.7767482774291 m
#     -> Associado à Linha 1 (Elev: 894.0 m), Linha 2 (Elev: 896.0 m)
#
# Processando Curva Nível 1 (CSV Linha 26):
#   WKT recebido: 'MULTILINESTRING ((675390.4329833984 7183199.692993164, 675390.5530395508 7183198.893005371, 675390.7...', Altitude associada à linha: 894.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 26)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.457904066208783, -49.255557007305704)
#
# Processando Curva Nível 2 (CSV Linha 26):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...', Altitude associada à linha: 896.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 26)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 27 do CSV ---
#   Ponto Principal (Linha CSV 27): Lat=-25.51557334416368, Lon=-49.23067346485953, Alt Ponto=895.3884320488253 m
#     -> Associado à Linha 1 (Elev: 895.0 m), Linha 2 (Elev: 896.0 m)
#
# Processando Curva Nível 1 (CSV Linha 27):
#   WKT recebido: 'MULTILINESTRING ((675312.4130249023 7182935.12298584, 675316.1329956055 7182936.013000488, 675319.14...', Altitude associada à linha: 895.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 27)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.460301379991442, -49.25629828996533)
#
# Processando Curva Nível 2 (CSV Linha 27):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...', Altitude associada à linha: 896.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 27)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 28 do CSV ---
#   Ponto Principal (Linha CSV 28): Lat=-25.515455141857306, Lon=-49.23072620768873, Alt Ponto=895.3882302009766 m
#     -> Associado à Linha 1 (Elev: 895.0 m), Linha 2 (Elev: 896.0 m)
#
# Processando Curva Nível 1 (CSV Linha 28):
#   WKT recebido: 'MULTILINESTRING ((675312.4130249023 7182935.12298584, 675316.1329956055 7182936.013000488, 675319.14...', Altitude associada à linha: 895.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 28)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.460301379991442, -49.25629828996533)
#
# Processando Curva Nível 2 (CSV Linha 28):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...', Altitude associada à linha: 896.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 28)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 29 do CSV ---
#   Ponto Principal (Linha CSV 29): Lat=-25.51533451891775, Lon=-49.230779285794064, Alt Ponto=895.3880239560556 m
#     -> Associado à Linha 1 (Elev: 895.0 m), Linha 2 (Elev: 896.0 m)
#
# Processando Curva Nível 1 (CSV Linha 29):
#   WKT recebido: 'MULTILINESTRING ((675312.4130249023 7182935.12298584, 675316.1329956055 7182936.013000488, 675319.14...', Altitude associada à linha: 895.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 29)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.460301379991442, -49.25629828996533)
#
# Processando Curva Nível 2 (CSV Linha 29):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...', Altitude associada à linha: 896.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 29)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 30 do CSV ---
#   Ponto Principal (Linha CSV 30): Lat=-25.515093273018348, Lon=-49.23088711838534, Alt Ponto=895.387608067248 m
#     -> Associado à Linha 1 (Elev: 895.0 m), Linha 2 (Elev: 896.0 m)
#
# Processando Curva Nível 1 (CSV Linha 30):
#   WKT recebido: 'MULTILINESTRING ((675312.4130249023 7182935.12298584, 675316.1329956055 7182936.013000488, 675319.14...', Altitude associada à linha: 895.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 30)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.460301379991442, -49.25629828996533)
#
# Processando Curva Nível 2 (CSV Linha 30):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...', Altitude associada à linha: 896.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 30)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 31 do CSV ---
#   Ponto Principal (Linha CSV 31): Lat=-25.514897111346794, Lon=-49.23097567259936, Alt Ponto=896.0 m
#     -> Associado à Linha 1 (Elev: 896.0 m), Linha 2 (Elev: 896.0 m)
#
# Processando Curva Nível 1 (CSV Linha 31):
#   WKT recebido: 'MULTILINESTRING ((674803.6630249023 7182437.0830078125, 674805.5029907227 7182433.553039551, 674810....', Altitude associada à linha: 896.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 31)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.46485687361259, -49.2612919725031)
#
# Processando Curva Nível 2 (CSV Linha 31):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...', Altitude associada à linha: 896.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 31)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 32 do CSV ---
#   Ponto Principal (Linha CSV 32): Lat=-25.514804779474645, Lon=-49.23101642930703, Alt Ponto=896.0 m
#     -> Associado à Linha 1 (Elev: 896.0 m), Linha 2 (Elev: 896.0 m)
#
# Processando Curva Nível 1 (CSV Linha 32):
#   WKT recebido: 'MULTILINESTRING ((674803.6630249023 7182437.0830078125, 674805.5029907227 7182433.553039551, 674810....', Altitude associada à linha: 896.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 32)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.46485687361259, -49.2612919725031)
#
# Processando Curva Nível 2 (CSV Linha 32):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...', Altitude associada à linha: 896.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 32)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 33 do CSV ---
#   Ponto Principal (Linha CSV 33): Lat=-25.514710026978623, Lon=-49.23106120932823, Alt Ponto=896.0 m
#     -> Associado à Linha 1 (Elev: 896.0 m), Linha 2 (Elev: 896.0 m)
#
# Processando Curva Nível 1 (CSV Linha 33):
#   WKT recebido: 'MULTILINESTRING ((674803.6630249023 7182437.0830078125, 674805.5029907227 7182433.553039551, 674810....', Altitude associada à linha: 896.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 33)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.46485687361259, -49.2612919725031)
#
# Processando Curva Nível 2 (CSV Linha 33):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...', Altitude associada à linha: 896.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 33)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 34 do CSV ---
#   Ponto Principal (Linha CSV 34): Lat=-25.514372258509848, Lon=-49.23122620649917, Alt Ponto=896.6120507159784 m
#     -> Associado à Linha 1 (Elev: 897.0 m), Linha 2 (Elev: 896.0 m)
#
# Processando Curva Nível 1 (CSV Linha 34):
#   WKT recebido: 'MULTILINESTRING ((674803.2529907227 7182443.822998047, 674804.7930297852 7182441.983032227, 674808.1...', Altitude associada à linha: 897.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 34)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.464796084421387, -49.2612969241348)
#
# Processando Curva Nível 2 (CSV Linha 34):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...', Altitude associada à linha: 896.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 34)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 35 do CSV ---
#   Ponto Principal (Linha CSV 35): Lat=-25.514217898062245, Lon=-49.23130300539043, Alt Ponto=897.2240455951176 m
#     -> Associado à Linha 1 (Elev: 898.0 m), Linha 2 (Elev: 896.0 m)
#
# Processando Curva Nível 1 (CSV Linha 35):
#   WKT recebido: 'MULTILINESTRING ((674804.7730102539 7182453.822998047, 674808.923034668 7182450.2830200195, 674810.6...', Altitude associada à linha: 898.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 35)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.46470564187109, -49.26128310830889)
#
# Processando Curva Nível 2 (CSV Linha 35):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...', Altitude associada à linha: 896.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 35)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 36 do CSV ---
#   Ponto Principal (Linha CSV 36): Lat=-25.51406595824742, Lon=-49.231375780968335, Alt Ponto=897.8334425311294 m
#     -> Associado à Linha 1 (Elev: 899.0 m), Linha 2 (Elev: 896.0 m)
#
# Processando Curva Nível 1 (CSV Linha 36):
#   WKT recebido: 'MULTILINESTRING ((674805.3829956055 7182460.733032227, 674809.6929931641 7182459.502990723, 674812.1...', Altitude associada à linha: 899.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 36)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.46464319763641, -49.26127793996213)
#
# Processando Curva Nível 2 (CSV Linha 36):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...', Altitude associada à linha: 896.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 36)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 37 do CSV ---
#   Ponto Principal (Linha CSV 37): Lat=-25.513709723967512, Lon=-49.23154863212818, Alt Ponto=897.4445271048085 m
#     -> Associado à Linha 1 (Elev: 899.0 m), Linha 2 (Elev: 895.0 m)
#
# Processando Curva Nível 1 (CSV Linha 37):
#   WKT recebido: 'MULTILINESTRING ((674805.3829956055 7182460.733032227, 674809.6929931641 7182459.502990723, 674812.1...', Altitude associada à linha: 899.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 37)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.46464319763641, -49.26127793996213)
#
# Processando Curva Nível 2 (CSV Linha 37):
#   WKT recebido: 'MULTILINESTRING ((674350.8229980469 7186799.692993164, 674350.9030151367 7186798.853027344, 674351.9...', Altitude associada à linha: 895.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 37)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425531512440273, -49.26635865916389)
#
# --- Processando dados da Linha 38 do CSV ---
#   Ponto Principal (Linha CSV 38): Lat=-25.51355984952855, Lon=-49.23162224155453, Alt Ponto=898.6611242884231 m
#     -> Associado à Linha 1 (Elev: 901.0 m), Linha 2 (Elev: 895.0 m)
#
# Processando Curva Nível 1 (CSV Linha 38):
#   WKT recebido: 'MULTILINESTRING ((674808.7529907227 7182468.3330078125, 674813.8229980469 7182465.713012695, 674817....', Altitude associada à linha: 901.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 38)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.464574200594598, -49.26124541843464)
#
# Processando Curva Nível 2 (CSV Linha 38):
#   WKT recebido: 'MULTILINESTRING ((674350.8229980469 7186799.692993164, 674350.9030151367 7186798.853027344, 674351.9...', Altitude associada à linha: 895.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 38)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425531512440273, -49.26635865916389)
#
# --- Processando dados da Linha 39 do CSV ---
#   Ponto Principal (Linha CSV 39): Lat=-25.513340079045797, Lon=-49.23172837276519, Alt Ponto=900.0565257941586 m
#     -> Associado à Linha 1 (Elev: 902.0 m), Linha 2 (Elev: 897.0 m)
#
# Processando Curva Nível 1 (CSV Linha 39):
#   WKT recebido: 'MULTILINESTRING ((674807.3729858398 7182473.393005371, 674811.5230102539 7182471.403015137, 674815.6...', Altitude associada à linha: 902.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 39)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.464528689873838, -49.26125979644518)
#
# Processando Curva Nível 2 (CSV Linha 39):
#   WKT recebido: 'MULTILINESTRING ((674102.4130249023 7186799.692993164, 674102.7130126953 7186798.343017578, 674104.4...', Altitude associada à linha: 897.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 39)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425560629361737, -49.26882780661129)
#
# --- Processando dados da Linha 40 do CSV ---
#   Ponto Principal (Linha CSV 40): Lat=-25.513151171838444, Lon=-49.23182042237863, Alt Ponto=900.2758969160391 m
#     -> Associado à Linha 1 (Elev: 903.0 m), Linha 2 (Elev: 896.0 m)
#
# Processando Curva Nível 1 (CSV Linha 40):
#   WKT recebido: 'MULTILINESTRING ((674809.0230102539 7182476.192993164, 674811.7830200195 7182476.043029785, 674816.0...', Altitude associada à linha: 903.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 40)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.46450322182045, -49.26124375365884)
#
# Processando Curva Nível 2 (CSV Linha 40):
#   WKT recebido: 'MULTILINESTRING ((674142.0330200195 7186799.692993164, 674144.5029907227 7186796.023010254, 674146.2...', Altitude associada à linha: 896.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 40)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425555988155054, -49.268433991209015)
#
# --- Processando dados da Linha 41 do CSV ---
#   Ponto Principal (Linha CSV 41): Lat=-25.512909464312656, Lon=-49.23193761770142, Alt Ponto=901.0623816266171 m
#     -> Associado à Linha 1 (Elev: 903.0 m), Linha 2 (Elev: 898.0 m)
#
# Processando Curva Nível 1 (CSV Linha 41):
#   WKT recebido: 'MULTILINESTRING ((674809.0230102539 7182476.192993164, 674811.7830200195 7182476.043029785, 674816.0...', Altitude associada à linha: 903.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 41)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.46450322182045, -49.26124375365884)
#
# Processando Curva Nível 2 (CSV Linha 41):
#   WKT recebido: 'MULTILINESTRING ((673202.1530151367 7185925.023010254, 673205.4030151367 7185926.093017578, 673218.4...', Altitude associada à linha: 898.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 41)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.43356098640463, -49.27766399240444)
#
# --- Processando dados da Linha 42 do CSV ---
#   Ponto Principal (Linha CSV 42): Lat=-25.512675018735663, Lon=-49.23205146026305, Alt Ponto=901.2849641303202 m
#     -> Associado à Linha 1 (Elev: 904.0 m), Linha 2 (Elev: 897.0 m)
#
# Processando Curva Nível 1 (CSV Linha 42):
#   WKT recebido: 'MULTILINESTRING ((675303.4830322266 7183199.692993164, 675303.4830322266 7183199.663024902, 675303.4...', Altitude associada à linha: 904.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 42)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.457914338277394, -49.25642149879378)
#
# Processando Curva Nível 2 (CSV Linha 42):
#   WKT recebido: 'MULTILINESTRING ((674102.4130249023 7186799.692993164, 674102.7130126953 7186798.343017578, 674104.4...', Altitude associada à linha: 897.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 42)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425560629361737, -49.26882780661129)
#
# --- Processando dados da Linha 43 do CSV ---
#   Ponto Principal (Linha CSV 43): Lat=-25.512158924636086, Lon=-49.23230194416294, Alt Ponto=901.9033375232455 m
#     -> Associado à Linha 1 (Elev: 905.0 m), Linha 2 (Elev: 897.0 m)
#
# Processando Curva Nível 1 (CSV Linha 43):
#   WKT recebido: 'MULTILINESTRING ((675245.7678222656 7183107.140625, 675244.6829833984 7183106.733032227, 675237.4130...', Altitude associada à linha: 905.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 43)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.458756562505926, -49.25698329002697)
#
# Processando Curva Nível 2 (CSV Linha 43):
#   WKT recebido: 'MULTILINESTRING ((674102.4130249023 7186799.692993164, 674102.7130126953 7186798.343017578, 674104.4...', Altitude associada à linha: 897.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 43)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425560629361737, -49.26882780661129)
#
# --- Processando dados da Linha 44 do CSV ---
#   Ponto Principal (Linha CSV 44): Lat=-25.511956394306647, Lon=-49.232398359037575, Alt Ponto=902.5169476902461 m
#     -> Associado à Linha 1 (Elev: 906.0 m), Linha 2 (Elev: 897.0 m)
#
# Processando Curva Nível 1 (CSV Linha 44):
#   WKT recebido: 'MULTILINESTRING ((675291.2630004883 7183199.692993164, 675290.9030151367 7183193.463012695, 675289.8...', Altitude associada à linha: 906.0 m
# ...
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 545)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.48821484264416, -49.24496500662535)
#
# Processando Curva Nível 2 (CSV Linha 545):
#   WKT recebido: 'MULTILINESTRING ((677068.3430175781 7178399.692993164, 677071.5430297852 7178395.5830078125, 677071....', Altitude associada à linha: 888.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 545)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.50103070201143, -49.23824318130061)
#
# --- Processando dados da Linha 546 do CSV ---
#   Ponto Principal (Linha CSV 546): Lat=-25.43368493818264, Lon=-49.269387450392735, Alt Ponto=884.6013086223952 m
#     -> Associado à Linha 1 (Elev: 882.0 m), Linha 2 (Elev: 888.0 m)
#
# Processando Curva Nível 1 (CSV Linha 546):
#   WKT recebido: 'MULTILINESTRING ((676411.3430175781 7179828.223022461, 676415.0729980469 7179827.233032227, 676419.8...', Altitude associada à linha: 882.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 546)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.48821484264416, -49.24496500662535)
#
# Processando Curva Nível 2 (CSV Linha 546):
#   WKT recebido: 'MULTILINESTRING ((677068.3430175781 7178399.692993164, 677071.5430297852 7178395.5830078125, 677071....', Altitude associada à linha: 888.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 546)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.50103070201143, -49.23824318130061)
#
# --- Processando dados da Linha 547 do CSV ---
#   Ponto Principal (Linha CSV 547): Lat=-25.4336680952272, Lon=-49.26939554653008, Alt Ponto=884.9442277295249 m
#     -> Associado à Linha 1 (Elev: 883.0 m), Linha 2 (Elev: 887.0 m)
#
# Processando Curva Nível 1 (CSV Linha 547):
#   WKT recebido: 'MULTILINESTRING ((676465.6329956055 7179599.692993164, 676464.8530273438 7179598.5830078125, 676464....', Altitude associada à linha: 883.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 547)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.490271146346167, -49.24439512421466)
#
# Processando Curva Nível 2 (CSV Linha 547):
#   WKT recebido: 'MULTILINESTRING ((676403.2930297852 7179163.673034668, 676409.1030273438 7179160.942993164, 676414.4...', Altitude associada à linha: 887.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 547)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.494214186258436, -49.2449579113921)
#
# --- Processando dados da Linha 548 do CSV ---
#   Ponto Principal (Linha CSV 548): Lat=-25.433650343925464, Lon=-49.26940397794356, Alt Ponto=884.9442452749494 m
#     -> Associado à Linha 1 (Elev: 883.0 m), Linha 2 (Elev: 887.0 m)
#
# Processando Curva Nível 1 (CSV Linha 548):
#   WKT recebido: 'MULTILINESTRING ((676465.6329956055 7179599.692993164, 676464.8530273438 7179598.5830078125, 676464....', Altitude associada à linha: 883.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 548)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.490271146346167, -49.24439512421466)
#
# Processando Curva Nível 2 (CSV Linha 548):
#   WKT recebido: 'MULTILINESTRING ((676403.2930297852 7179163.673034668, 676409.1030273438 7179160.942993164, 676414.4...', Altitude associada à linha: 887.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 548)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.494214186258436, -49.2449579113921)
#
# --- Processando dados da Linha 549 do CSV ---
#   Ponto Principal (Linha CSV 549): Lat=-25.433636623758524, Lon=-49.26940987003094, Alt Ponto=884.818658088293 m
#     -> Associado à Linha 1 (Elev: 883.0 m), Linha 2 (Elev: 887.0 m)
#
# Processando Curva Nível 1 (CSV Linha 549):
#   WKT recebido: 'MULTILINESTRING ((676465.6329956055 7179599.692993164, 676464.8530273438 7179598.5830078125, 676464....', Altitude associada à linha: 883.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 549)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.490271146346167, -49.24439512421466)
#
# Processando Curva Nível 2 (CSV Linha 549):
#   WKT recebido: 'MULTILINESTRING ((677096.0230102539 7178399.692993164, 677095.423034668 7178398.713012695, 677094.48...', Altitude associada à linha: 887.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 549)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.501027393236473, -49.237967880112585)
#
# --- Processando dados da Linha 550 do CSV ---
#   Ponto Principal (Linha CSV 550): Lat=-25.43362835367216, Lon=-49.26941408573769, Alt Ponto=884.8585396699268 m
#     -> Associado à Linha 1 (Elev: 883.0 m), Linha 2 (Elev: 887.0 m)
#
# Processando Curva Nível 1 (CSV Linha 550):
#   WKT recebido: 'MULTILINESTRING ((676723.9030151367 7179400.62298584, 676721.7730102539 7179402.223022461, 676717.50...', Altitude associada à linha: 883.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 550)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.492037223336165, -49.241800476296106)
#
# Processando Curva Nível 2 (CSV Linha 550):
#   WKT recebido: 'MULTILINESTRING ((677096.0230102539 7178399.692993164, 677095.423034668 7178398.713012695, 677094.48...', Altitude associada à linha: 887.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 550)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.501027393236473, -49.237967880112585)
#
# --- Processando dados da Linha 551 do CSV ---
#   Ponto Principal (Linha CSV 551): Lat=-25.433614633504, Lon=-49.269419810187, Alt Ponto=885.9835229108448 m
#     -> Associado à Linha 1 (Elev: 884.0 m), Linha 2 (Elev: 888.0 m)
#
# Processando Curva Nível 1 (CSV Linha 551):
#   WKT recebido: 'MULTILINESTRING ((676403.4130249023 7179233.043029785, 676408.1229858398 7179231.20300293, 676413.23...', Altitude associada à linha: 884.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 551)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.493588022213395, -49.24496581669234)
#
# Processando Curva Nível 2 (CSV Linha 551):
#   WKT recebido: 'MULTILINESTRING ((676404.4429931641 7179108.62298584, 676409.1430053711 7179109.113037109, 676412.23...', Altitude associada à linha: 888.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 551)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.49471094390506, -49.24493925390696)
#
# --- Processando dados da Linha 552 do CSV ---
#   Ponto Principal (Linha CSV 552): Lat=-25.43359516047044, Lon=-49.26942888739758, Alt Ponto=885.9835283963255 m
#     -> Associado à Linha 1 (Elev: 884.0 m), Linha 2 (Elev: 888.0 m)
#
# Processando Curva Nível 1 (CSV Linha 552):
#   WKT recebido: 'MULTILINESTRING ((676403.4130249023 7179233.043029785, 676408.1229858398 7179231.20300293, 676413.23...', Altitude associada à linha: 884.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 552)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.493588022213395, -49.24496581669234)
#
# Processando Curva Nível 2 (CSV Linha 552):
#   WKT recebido: 'MULTILINESTRING ((676404.4429931641 7179108.62298584, 676409.1430053711 7179109.113037109, 676412.23...', Altitude associada à linha: 888.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 552)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.49471094390506, -49.24493925390696)
#
# --- Processando dados da Linha 553 do CSV ---
#   Ponto Principal (Linha CSV 553): Lat=-25.43350901614333, Lon=-49.26946764219343, Alt Ponto=885.983552403383 m
#     -> Associado à Linha 1 (Elev: 884.0 m), Linha 2 (Elev: 888.0 m)
#
# Processando Curva Nível 1 (CSV Linha 553):
#   WKT recebido: 'MULTILINESTRING ((676403.4130249023 7179233.043029785, 676408.1229858398 7179231.20300293, 676413.23...', Altitude associada à linha: 884.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 553)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.493588022213395, -49.24496581669234)
#
# Processando Curva Nível 2 (CSV Linha 553):
#   WKT recebido: 'MULTILINESTRING ((676404.4429931641 7179108.62298584, 676409.1430053711 7179109.113037109, 676412.23...', Altitude associada à linha: 888.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 553)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.49471094390506, -49.24493925390696)
#
# --- Processando dados da Linha 554 do CSV ---
#   Ponto Principal (Linha CSV 554): Lat=-25.43352594217956, Lon=-49.26951898895116, Alt Ponto=885.9835567880888 m
#     -> Associado à Linha 1 (Elev: 884.0 m), Linha 2 (Elev: 888.0 m)
#
# Processando Curva Nível 1 (CSV Linha 554):
#   WKT recebido: 'MULTILINESTRING ((676403.4130249023 7179233.043029785, 676408.1229858398 7179231.20300293, 676413.23...', Altitude associada à linha: 884.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 554)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.493588022213395, -49.24496581669234)
#
# Processando Curva Nível 2 (CSV Linha 554):
#   WKT recebido: 'MULTILINESTRING ((676404.4429931641 7179108.62298584, 676409.1430053711 7179109.113037109, 676412.23...', Altitude associada à linha: 888.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 554)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.49471094390506, -49.24493925390696)
#
# --- Processando dados da Linha 555 do CSV ---
#   Ponto Principal (Linha CSV 555): Lat=-25.43354529048168, Lon=-49.269572347365646, Alt Ponto=885.9835609984076 m
#     -> Associado à Linha 1 (Elev: 884.0 m), Linha 2 (Elev: 888.0 m)
#
# Processando Curva Nível 1 (CSV Linha 555):
#   WKT recebido: 'MULTILINESTRING ((676403.4130249023 7179233.043029785, 676408.1229858398 7179231.20300293, 676413.23...', Altitude associada à linha: 884.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 555)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.493588022213395, -49.24496581669234)
#
# Processando Curva Nível 2 (CSV Linha 555):
#   WKT recebido: 'MULTILINESTRING ((676404.4429931641 7179108.62298584, 676409.1430053711 7179109.113037109, 676412.23...', Altitude associada à linha: 888.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 555)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.49471094390506, -49.24493925390696)
#
# --- Processando dados da Linha 556 do CSV ---
#   Ponto Principal (Linha CSV 556): Lat=-25.433582775959746, Lon=-49.269681746403634, Alt Ponto=886.5182628461303 m
#     -> Associado à Linha 1 (Elev: 885.0 m), Linha 2 (Elev: 888.0 m)
#
# Processando Curva Nível 1 (CSV Linha 556):
#   WKT recebido: 'MULTILINESTRING ((676790.5642089844 7179064.997802734, 676791.3930053711 7179065.093017578, 676795.1...', Altitude associada à linha: 885.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 556)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4950586977814, -49.24109340499131)
#
# Processando Curva Nível 2 (CSV Linha 556):
#   WKT recebido: 'MULTILINESTRING ((676404.4429931641 7179108.62298584, 676409.1430053711 7179109.113037109, 676412.23...', Altitude associada à linha: 888.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 556)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.49471094390506, -49.24493925390696)
#
# --- Processando dados da Linha 557 do CSV ---
#   Ponto Principal (Linha CSV 557): Lat=-25.433632069944128, Lon=-49.26981729697952, Alt Ponto=886.5183343263685 m
#     -> Associado à Linha 1 (Elev: 885.0 m), Linha 2 (Elev: 888.0 m)
#
# Processando Curva Nível 1 (CSV Linha 557):
#   WKT recebido: 'MULTILINESTRING ((676790.5642089844 7179064.997802734, 676791.3930053711 7179065.093017578, 676795.1...', Altitude associada à linha: 885.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 557)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4950586977814, -49.24109340499131)
#
# Processando Curva Nível 2 (CSV Linha 557):
#   WKT recebido: 'MULTILINESTRING ((676404.4429931641 7179108.62298584, 676409.1430053711 7179109.113037109, 676412.23...', Altitude associada à linha: 888.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 557)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.49471094390506, -49.24493925390696)
#
# --- Processando dados da Linha 558 do CSV ---
#   Ponto Principal (Linha CSV 558): Lat=-25.43367845282021, Lon=-49.26995123198133, Alt Ponto=886.5184037460668 m
#     -> Associado à Linha 1 (Elev: 885.0 m), Linha 2 (Elev: 888.0 m)
#
# Processando Curva Nível 1 (CSV Linha 558):
#   WKT recebido: 'MULTILINESTRING ((676790.5642089844 7179064.997802734, 676791.3930053711 7179065.093017578, 676795.1...', Altitude associada à linha: 885.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 558)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4950586977814, -49.24109340499131)
#
# Processando Curva Nível 2 (CSV Linha 558):
#   WKT recebido: 'MULTILINESTRING ((676404.4429931641 7179108.62298584, 676409.1430053711 7179109.113037109, 676412.23...', Altitude associada à linha: 888.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 558)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.49471094390506, -49.24493925390696)
#
# --- Processando dados da Linha 559 do CSV ---
#   Ponto Principal (Linha CSV 559): Lat=-25.433788223421573, Lon=-49.27026584744453, Alt Ponto=886.5185665912702 m
#     -> Associado à Linha 1 (Elev: 885.0 m), Linha 2 (Elev: 888.0 m)
#
# Processando Curva Nível 1 (CSV Linha 559):
#   WKT recebido: 'MULTILINESTRING ((676790.5642089844 7179064.997802734, 676791.3930053711 7179065.093017578, 676795.1...', Altitude associada à linha: 885.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 559)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.4950586977814, -49.24109340499131)
#
# Processando Curva Nível 2 (CSV Linha 559):
#   WKT recebido: 'MULTILINESTRING ((676404.4429931641 7179108.62298584, 676409.1430053711 7179109.113037109, 676412.23...', Altitude associada à linha: 888.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 559)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.49471094390506, -49.24493925390696)
#
# Mapa salvo como 'mapa_pontos_com_associacao_curvas.html'. Abra este arquivo em um navegador para visualizar.

# %%
import folium
from folium import FeatureGroup, LayerControl
from shapely import wkt
# Não precisaremos mais de shapely.ops.nearest_points para esta abordagem
import pandas as pd
from pyproj import Transformer, CRS

# ==============================================================================
# CONFIGURAÇÕES DO USUÁRIO - AJUSTE CONFORME NECESSÁRIO
# ==============================================================================

SOURCE_EPSG = "EPSG:31982"
TARGET_EPSG = "EPSG:4326"

# Nomes das colunas de ATRIBUTOS no seu arquivo CSV
ALTITUDE_PONTO_COL = 'altimetria_interpolada'
ALTITUDE_LINHA1_COL = 'linha1_elevation'
ALTITUDE_LINHA2_COL = 'linha2_elevation'
ID_LINHA1_COL = 'linha1_gid' # <- NOVO: Coluna para o ID/GID da Linha 1
ID_LINHA2_COL = 'linha2_gid' # <- NOVO: Coluna para o ID/GID da Linha 2
UNIDADE_ALTITUDE = "m"

# Coluna com a geometria WKT das linhas (não do ponto original para esta versão)
# A coluna GEOMETRIA_PONTO_ORIGINAL_COL não é mais necessária para esta abordagem.

FILE_PATH_CSV = 'resultado1.csv'
OUTPUT_MAP_FILE = 'mapa_pontos_com_id_curvas.html'
# ==============================================================================

try:
    transformer = Transformer.from_crs(CRS.from_string(SOURCE_EPSG), CRS.from_string(TARGET_EPSG), always_xy=True)
except Exception as e:
    print(f"Erro ao criar o transformador de coordenadas: {e}")
    exit()
'''
try:
    df = pd.read_csv(FILE_PATH_CSV)
except Exception as e:
    print(f"Erro ao ler o CSV '{FILE_PATH_CSV}': {e}")
    exit()
'''
'''
ten = resultado_copia.head(50)

df = ten.copy()
'''

df = resultado_copia.copy()
if df.empty:
    print(f"DataFrame carregado de '{FILE_PATH_CSV}' está vazio.")
    exit()

# Colunas obrigatórias para esta funcionalidade
required_columns = ['Latitude', 'Longitude', # Coordenadas do Ponto
                    'linha1_geometry', 'linha2_geometry', # Geometrias das linhas associadas
                    ALTITUDE_PONTO_COL, ALTITUDE_LINHA1_COL, ALTITUDE_LINHA2_COL, # Altitudes
                    ID_LINHA1_COL, ID_LINHA2_COL] # IDs das linhas associadas
missing_cols = [col for col in required_columns if col not in df.columns]
if missing_cols:
    print(f"Erro: Colunas obrigatórias não encontradas: {', '.join(missing_cols)}")
    print(f"Colunas no CSV: {df.columns.tolist()}")
    print(f"Verifique os nomes das colunas definidos nas configurações.")
    exit()

map_center_latitude = df.loc[0, 'Latitude']
map_center_longitude = df.loc[0, 'Longitude']
print(f"Centro do mapa: Lat: {map_center_latitude}, Lon: {map_center_longitude}")

m = folium.Map(location=[map_center_latitude, map_center_longitude], zoom_start=12)

fg_pontos_todos = FeatureGroup(name='Pontos Principais', show=True)
m.add_child(fg_pontos_todos)
fg_curva1_todas = FeatureGroup(name='Curvas de Nível 1', show=True)
m.add_child(fg_curva1_todas)
fg_curva2_todas = FeatureGroup(name='Curvas de Nível 2', show=True)
m.add_child(fg_curva2_todas)
# Não precisamos mais dos FeatureGroups para linhas de conexão


def adicionar_geometria_linha(wkt_string, feature_group, cor_linha, nome_camada_debug, altitude_valor, id_linha_valor=None): # Adicionado id_linha_valor opcional
    print(f"\nProcessando {nome_camada_debug}:")
    if pd.isna(wkt_string) or not str(wkt_string).strip():
        print(f"  Aviso: String WKT para '{nome_camada_debug}' está vazia ou é NaN. Camada pulada.")
        return

    altitude_display = f"{altitude_valor} {UNIDADE_ALTITUDE}" if pd.notna(altitude_valor) else "N/A"
    id_display = f"ID: {id_linha_valor}" if pd.notna(id_linha_valor) else "ID: N/A" # Display para ID da linha

    popup_text_linha = f"Curva de Nível<br>{id_display}<br>Altitude: {altitude_display}"
    tooltip_text_linha = f"{id_display}, Alt: {altitude_display}"

    wkt_string_preview = str(wkt_string)[:100] + ('...' if len(str(wkt_string)) > 100 else '')
    print(f"  WKT recebido: '{wkt_string_preview}', {id_display}, Altitude da linha: {altitude_display}")

    try:
        geom = wkt.loads(str(wkt_string))
    except Exception as e:
        print(f"  Erro ao parsear WKT para '{nome_camada_debug}': {wkt_string_preview}. Erro: {e}")
        return

    if geom.is_empty:
        print(f"  Aviso: Geometria WKT parseada para '{nome_camada_debug}' está vazia. Camada pulada.")
        return
    print(f"  Tipo de geometria parseada: {geom.geom_type}")

    linhas_para_plotar_orig = []
    if geom.geom_type == 'LineString':
        linhas_para_plotar_orig.append(geom)
    elif geom.geom_type == 'MultiLineString':
        linhas_para_plotar_orig.extend(list(geom.geoms))
    else:
        print(f"  Aviso: Tipo de geometria não suportado '{geom.geom_type}' para '{nome_camada_debug}'. Camada pulada.")
        return

    if not linhas_para_plotar_orig:
        print(f"  Aviso: Nenhuma linha individual encontrada em '{nome_camada_debug}'.")
        return
        
    segmentos_adicionados = 0
    coords_reprojetadas_folium_exemplo = []
    for i, linha_orig in enumerate(linhas_para_plotar_orig):
        if linha_orig.is_empty:
            print(f"  Aviso: Segmento {i} (original) de '{nome_camada_debug}' está vazio.")
            continue
        
        coords_originais_projetadas = list(linha_orig.coords)
        if not coords_originais_projetadas:
            print(f"  Aviso: Segmento {i} (original) de '{nome_camada_debug}' não possui coordenadas.")
            continue
        
        coords_reprojetadas_folium = []
        try:
            for x_proj, y_proj in coords_originais_projetadas:
                lon_deg, lat_deg = transformer.transform(x_proj, y_proj)
                coords_reprojetadas_folium.append((lat_deg, lon_deg))
        except Exception as e:
            print(f"    Erro durante reprojeção do segmento {i} de '{nome_camada_debug}': {e}")
            continue

        if not coords_reprojetadas_folium:
            print(f"  Aviso: Segmento {i} de '{nome_camada_debug}' não possui coordenadas após reprojeção.")
            continue
        
        if not coords_reprojetadas_folium_exemplo:
            coords_reprojetadas_folium_exemplo = coords_reprojetadas_folium

        folium.PolyLine(
            coords_reprojetadas_folium, color=cor_linha, weight=2.5, opacity=0.8,
            popup=folium.Popup(popup_text_linha, max_width=250), # Usando folium.Popup
            tooltip=tooltip_text_linha
        ).add_to(feature_group)
        segmentos_adicionados +=1
    
    if segmentos_adicionados > 0:
        print(f"  {segmentos_adicionados} segmento(s) de linha adicionado(s) para '{nome_camada_debug}'.")
        if coords_reprojetadas_folium_exemplo and coords_reprojetadas_folium_exemplo[0]:
             print(f"    Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): {coords_reprojetadas_folium_exemplo[0]}")
    else:
        print(f"  Nenhum segmento de linha válido foi adicionado para '{nome_camada_debug}'.")


for index, row in df.iterrows():
    print(f"\n--- Processando dados da Linha {index} do CSV ---")
    
    current_lat = row['Latitude']
    current_lon = row['Longitude']
    
    altitude_ponto_val = row[ALTITUDE_PONTO_COL]
    altitude_ponto_display = f"{altitude_ponto_val} {UNIDADE_ALTITUDE}" if pd.notna(altitude_ponto_val) else "N/A"
    
    # Informações da Linha 1 associada
    altitude_l1_val = row[ALTITUDE_LINHA1_COL]
    id_l1_val = row[ID_LINHA1_COL]
    linha1_elev_display = f"{altitude_l1_val} {UNIDADE_ALTITUDE}" if pd.notna(altitude_l1_val) else "N/A"
    linha1_id_display = str(id_l1_val) if pd.notna(id_l1_val) else "N/A"

    # Informações da Linha 2 associada
    altitude_l2_val = row[ALTITUDE_LINHA2_COL]
    id_l2_val = row[ID_LINHA2_COL]
    linha2_elev_display = f"{altitude_l2_val} {UNIDADE_ALTITUDE}" if pd.notna(altitude_l2_val) else "N/A"
    linha2_id_display = str(id_l2_val) if pd.notna(id_l2_val) else "N/A"

    # --- Popup e Tooltip do Marcador do Ponto com IDs das Curvas ---
    popup_html_marker = f"""
    <b>Ponto ID {index}</b> (Lat: {current_lat:.5f}, Lon: {current_lon:.5f})<br>
    Altitude do Ponto: {altitude_ponto_display}<br>
    <hr style="margin: 5px 0;">
    <b>Curvas de Nível Associadas:</b><br>
    <u>1ª Mais Próxima:</u><br>
    &nbsp;&nbsp;ID da Curva: {linha1_id_display}<br>
    &nbsp;&nbsp;Elevação: {linha1_elev_display}<br>
    <u>2ª Mais Próxima:</u><br>
    &nbsp;&nbsp;ID da Curva: {linha2_id_display}<br>
    &nbsp;&nbsp;Elevação: {linha2_elev_display}
    """

    tooltip_text_marker = (f"Ponto {index} (Alt: {altitude_ponto_display}) | "
                           f"L1 ID: {linha1_id_display} (Elev: {linha1_elev_display}) | "
                           f"L2 ID: {linha2_id_display} (Elev: {linha2_elev_display})")

    folium.Marker(
        location=[current_lat, current_lon],
        popup=folium.Popup(popup_html_marker, max_width=400), 
        tooltip=tooltip_text_marker,
        icon=folium.Icon(color='purple', icon='info-sign')
    ).add_to(fg_pontos_todos)
    # --- FIM DA ALTERAÇÃO Popup e Tooltip ---

    print(f"  Ponto Principal (Linha CSV {index}): Lat={current_lat}, Lon={current_lon}, Alt Ponto={altitude_ponto_display}")
    print(f"    -> Associado à Curva 1 (ID: {linha1_id_display}, Elev: {linha1_elev_display})")
    print(f"    -> Associado à Curva 2 (ID: {linha2_id_display}, Elev: {linha2_elev_display})")

    # Adiciona as geometrias das curvas de nível ao mapa
    # Passando também o ID da linha para a função, para que possa ser incluído no popup da própria linha
    adicionar_geometria_linha(row['linha1_geometry'], fg_curva1_todas, 'blue', 
                              f"Curva Nível 1 (CSV Linha {index})", altitude_l1_val, id_l1_val)
    adicionar_geometria_linha(row['linha2_geometry'], fg_curva2_todas, 'green', 
                              f"Curva Nível 2 (CSV Linha {index})", altitude_l2_val, id_l2_val)

    # A lógica para desenhar linhas de conexão foi removida.

LayerControl().add_to(m)
m.save(OUTPUT_MAP_FILE)
print(f"\nMapa salvo como '{OUTPUT_MAP_FILE}'.")
# Out:
# Centro do mapa: Lat: -25.40663119894788, Lon: -49.25216384754277
#
# --- Processando dados da Linha 0 do CSV ---
#   Ponto Principal (Linha CSV 0): Lat=-25.40663119894788, Lon=-49.25216384754277, Alt Ponto=912.3155675899501 m
#     -> Associado à Curva 1 (ID: 122759, Elev: 912.0 m)
#     -> Associado à Curva 2 (ID: 122761, Elev: 913.0 m)
#
# Processando Curva Nível 1 (CSV Linha 0):
#   WKT recebido: 'MULTILINESTRING ((675768.6744384766 7188999.692993164, 675765.6829833984 7188997.37298584, 675766.27...', ID: 122759, Altitude da linha: 912.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 0)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.405506523340453, -49.25255188210982)
#
# Processando Curva Nível 2 (CSV Linha 0):
#   WKT recebido: 'MULTILINESTRING ((675637.999206543 7188999.692993164, 675637.9930419922 7188999.562988281, 675634.66...', ID: 122761, Altitude da linha: 913.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 0)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40552195608842, -49.2538505442922)
#
# --- Processando dados da Linha 1 do CSV ---
#   Ponto Principal (Linha CSV 1): Lat=-25.40648620669207, Lon=-49.25203156420009, Alt Ponto=911.7918851065305 m
#     -> Associado à Curva 1 (ID: 122759, Elev: 912.0 m)
#     -> Associado à Curva 2 (ID: 122251, Elev: 911.0 m)
#
# Processando Curva Nível 1 (CSV Linha 1):
#   WKT recebido: 'MULTILINESTRING ((675768.6744384766 7188999.692993164, 675765.6829833984 7188997.37298584, 675766.27...', ID: 122759, Altitude da linha: 912.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 1)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.405506523340453, -49.25255188210982)
#
# Processando Curva Nível 2 (CSV Linha 1):
#   WKT recebido: 'MULTILINESTRING ((675841.4830322266 7188999.692993164, 675839.7930297852 7188995.653015137, 675842.5...', ID: 122251, Altitude da linha: 911.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 1)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40549791967183, -49.251828304233904)
#
# --- Processando dados da Linha 2 do CSV ---
#   Ponto Principal (Linha CSV 2): Lat=-25.406337198731404, Lon=-49.25188687564072, Alt Ponto=910.7738329898422 m
#     -> Associado à Curva 1 (ID: 122251, Elev: 911.0 m)
#     -> Associado à Curva 2 (ID: 121787, Elev: 910.0 m)
#
# Processando Curva Nível 1 (CSV Linha 2):
#   WKT recebido: 'MULTILINESTRING ((675841.4830322266 7188999.692993164, 675839.7930297852 7188995.653015137, 675842.5...', ID: 122251, Altitude da linha: 911.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 2)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40549791967183, -49.251828304233904)
#
# Processando Curva Nível 2 (CSV Linha 2):
#   WKT recebido: 'MULTILINESTRING ((675977.2088012695 7188999.692993164, 675976.2730102539 7188999.182983398, 675972.1...', ID: 121787, Altitude da linha: 910.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 2)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40548187168832, -49.25047945110854)
#
# --- Processando dados da Linha 3 do CSV ---
#   Ponto Principal (Linha CSV 3): Lat=-25.40684413053865, Lon=-49.25145997685701, Alt Ponto=910.4647143996306 m
#     -> Associado à Curva 1 (ID: 121787, Elev: 910.0 m)
#     -> Associado à Curva 2 (ID: 122251, Elev: 911.0 m)
#
# Processando Curva Nível 1 (CSV Linha 3):
#   WKT recebido: 'MULTILINESTRING ((675977.2088012695 7188999.692993164, 675976.2730102539 7188999.182983398, 675972.1...', ID: 121787, Altitude da linha: 910.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 3)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40548187168832, -49.25047945110854)
#
# Processando Curva Nível 2 (CSV Linha 3):
#   WKT recebido: 'MULTILINESTRING ((675841.4830322266 7188999.692993164, 675839.7930297852 7188995.653015137, 675842.5...', ID: 122251, Altitude da linha: 911.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 3)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40549791967183, -49.251828304233904)
#
# --- Processando dados da Linha 4 do CSV ---
#   Ponto Principal (Linha CSV 4): Lat=-25.40748465967415, Lon=-49.250904621179416, Alt Ponto=910.4261576850589 m
#     -> Associado à Curva 1 (ID: 121787, Elev: 910.0 m)
#     -> Associado à Curva 2 (ID: 122251, Elev: 911.0 m)
#
# Processando Curva Nível 1 (CSV Linha 4):
#   WKT recebido: 'MULTILINESTRING ((675977.2088012695 7188999.692993164, 675976.2730102539 7188999.182983398, 675972.1...', ID: 121787, Altitude da linha: 910.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 4)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40548187168832, -49.25047945110854)
#
# Processando Curva Nível 2 (CSV Linha 4):
#   WKT recebido: 'MULTILINESTRING ((675841.4830322266 7188999.692993164, 675839.7930297852 7188995.653015137, 675842.5...', ID: 122251, Altitude da linha: 911.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 4)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40549791967183, -49.251828304233904)
#
# --- Processando dados da Linha 5 do CSV ---
#   Ponto Principal (Linha CSV 5): Lat=-25.408057350770303, Lon=-49.250408274100096, Alt Ponto=909.4459316371049 m
#     -> Associado à Curva 1 (ID: 122250, Elev: 909.0 m)
#     -> Associado à Curva 2 (ID: 121787, Elev: 910.0 m)
#
# Processando Curva Nível 1 (CSV Linha 5):
#   WKT recebido: 'MULTILINESTRING ((675997.5723876953 7188999.692993164, 675996.3229980469 7188998.1329956055, 675992....', ID: 122250, Altitude da linha: 909.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 5)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.405479462865884, -49.25027707632082)
#
# Processando Curva Nível 2 (CSV Linha 5):
#   WKT recebido: 'MULTILINESTRING ((675977.2088012695 7188999.692993164, 675976.2730102539 7188999.182983398, 675972.1...', ID: 121787, Altitude da linha: 910.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 5)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40548187168832, -49.25047945110854)
#
# --- Processando dados da Linha 6 do CSV ---
#   Ponto Principal (Linha CSV 6): Lat=-25.4090246400848, Lon=-49.24957267371764, Alt Ponto=907.7505318682763 m
#     -> Associado à Curva 1 (ID: 122081, Elev: 908.0 m)
#     -> Associado à Curva 2 (ID: 122080, Elev: 907.0 m)
#
# Processando Curva Nível 1 (CSV Linha 6):
#   WKT recebido: 'MULTILINESTRING ((676402.5330200195 7188826.413024902, 676396.0930175781 7188823.243041992, 676394.6...', ID: 122081, Altitude da linha: 908.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 6)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.406995587159265, -49.24622993197413)
#
# Processando Curva Nível 2 (CSV Linha 6):
#   WKT recebido: 'MULTILINESTRING ((676402.1530151367 7188807.543029785, 676393.3030395508 7188805.713012695, 676388.8...', ID: 122080, Altitude da linha: 907.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 6)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40716595932677, -49.24623124492871)
#
# --- Processando dados da Linha 7 do CSV ---
#   Ponto Principal (Linha CSV 7): Lat=-25.40993491474235, Lon=-49.24878748894321, Alt Ponto=907.237309462802 m
#     -> Associado à Curva 1 (ID: 122080, Elev: 907.0 m)
#     -> Associado à Curva 2 (ID: 122081, Elev: 908.0 m)
#
# Processando Curva Nível 1 (CSV Linha 7):
#   WKT recebido: 'MULTILINESTRING ((676402.1530151367 7188807.543029785, 676393.3030395508 7188805.713012695, 676388.8...', ID: 122080, Altitude da linha: 907.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 7)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40716595932677, -49.24623124492871)
#
# Processando Curva Nível 2 (CSV Linha 7):
#   WKT recebido: 'MULTILINESTRING ((676402.5330200195 7188826.413024902, 676396.0930175781 7188823.243041992, 676394.6...', ID: 122081, Altitude da linha: 908.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 7)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.406995587159265, -49.24622993197413)
#
# --- Processando dados da Linha 8 do CSV ---
#   Ponto Principal (Linha CSV 8): Lat=-25.409979925851975, Lon=-49.24877520080436, Alt Ponto=907.027540972758 m
#     -> Associado à Curva 1 (ID: 122080, Elev: 907.0 m)
#     -> Associado à Curva 2 (ID: 122081, Elev: 908.0 m)
#
# Processando Curva Nível 1 (CSV Linha 8):
#   WKT recebido: 'MULTILINESTRING ((676402.1530151367 7188807.543029785, 676393.3030395508 7188805.713012695, 676388.8...', ID: 122080, Altitude da linha: 907.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 8)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40716595932677, -49.24623124492871)
#
# Processando Curva Nível 2 (CSV Linha 8):
#   WKT recebido: 'MULTILINESTRING ((676402.5330200195 7188826.413024902, 676396.0930175781 7188823.243041992, 676394.6...', ID: 122081, Altitude da linha: 908.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 8)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.406995587159265, -49.24622993197413)
#
# --- Processando dados da Linha 9 do CSV ---
#   Ponto Principal (Linha CSV 9): Lat=-25.41005461544683, Lon=-49.24872603229153, Alt Ponto=907.5843796317208 m
#     -> Associado à Curva 1 (ID: 122081, Elev: 908.0 m)
#     -> Associado à Curva 2 (ID: 122080, Elev: 907.0 m)
#
# Processando Curva Nível 1 (CSV Linha 9):
#   WKT recebido: 'MULTILINESTRING ((676402.5330200195 7188826.413024902, 676396.0930175781 7188823.243041992, 676394.6...', ID: 122081, Altitude da linha: 908.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 9)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.406995587159265, -49.24622993197413)
#
# Processando Curva Nível 2 (CSV Linha 9):
#   WKT recebido: 'MULTILINESTRING ((676402.1530151367 7188807.543029785, 676393.3030395508 7188805.713012695, 676388.8...', ID: 122080, Altitude da linha: 907.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 9)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40716595932677, -49.24623124492871)
#
# --- Processando dados da Linha 10 do CSV ---
#   Ponto Principal (Linha CSV 10): Lat=-25.410106781134026, Lon=-49.24869090635019, Alt Ponto=907.7833800470622 m
#     -> Associado à Curva 1 (ID: 122081, Elev: 908.0 m)
#     -> Associado à Curva 2 (ID: 122080, Elev: 907.0 m)
#
# Processando Curva Nível 1 (CSV Linha 10):
#   WKT recebido: 'MULTILINESTRING ((676402.5330200195 7188826.413024902, 676396.0930175781 7188823.243041992, 676394.6...', ID: 122081, Altitude da linha: 908.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 10)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.406995587159265, -49.24622993197413)
#
# Processando Curva Nível 2 (CSV Linha 10):
#   WKT recebido: 'MULTILINESTRING ((676402.1530151367 7188807.543029785, 676393.3030395508 7188805.713012695, 676388.8...', ID: 122080, Altitude da linha: 907.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 10)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40716595932677, -49.24623124492871)
#
# --- Processando dados da Linha 11 do CSV ---
#   Ponto Principal (Linha CSV 11): Lat=-25.41041272770106, Lon=-49.24843718037397, Alt Ponto=907.8284712209263 m
#     -> Associado à Curva 1 (ID: 122081, Elev: 908.0 m)
#     -> Associado à Curva 2 (ID: 122080, Elev: 907.0 m)
#
# Processando Curva Nível 1 (CSV Linha 11):
#   WKT recebido: 'MULTILINESTRING ((676402.5330200195 7188826.413024902, 676396.0930175781 7188823.243041992, 676394.6...', ID: 122081, Altitude da linha: 908.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 11)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.406995587159265, -49.24622993197413)
#
# Processando Curva Nível 2 (CSV Linha 11):
#   WKT recebido: 'MULTILINESTRING ((676402.1530151367 7188807.543029785, 676393.3030395508 7188805.713012695, 676388.8...', ID: 122080, Altitude da linha: 907.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 11)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40716595932677, -49.24623124492871)
#
# --- Processando dados da Linha 12 do CSV ---
#   Ponto Principal (Linha CSV 12): Lat=-25.41090878844364, Lon=-49.24799206671264, Alt Ponto=905.5267885199329 m
#     -> Associado à Curva 1 (ID: 122079, Elev: 906.0 m)
#     -> Associado à Curva 2 (ID: 121786, Elev: 905.0 m)
#
# Processando Curva Nível 1 (CSV Linha 12):
#   WKT recebido: 'MULTILINESTRING ((676402.2430419922 7188798.942993164, 676394.2930297852 7188796.143005371, 676391.1...', ID: 122079, Altitude da linha: 906.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 12)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40724357555742, -49.24622922742643)
#
# Processando Curva Nível 2 (CSV Linha 12):
#   WKT recebido: 'MULTILINESTRING ((676402.1530151367 7188593.273010254, 676391.3729858398 7188605.213012695, 676386.6...', ID: 121786, Altitude da linha: 905.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 12)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.409100034396705, -49.2462032690229)
#
# --- Processando dados da Linha 13 do CSV ---
#   Ponto Principal (Linha CSV 13): Lat=-25.411146674549848, Lon=-49.24777545526615, Alt Ponto=905.4447483349768 m
#     -> Associado à Curva 1 (ID: 121786, Elev: 905.0 m)
#     -> Associado à Curva 2 (ID: 122079, Elev: 906.0 m)
#
# Processando Curva Nível 1 (CSV Linha 13):
#   WKT recebido: 'MULTILINESTRING ((676402.1530151367 7188593.273010254, 676391.3729858398 7188605.213012695, 676386.6...', ID: 121786, Altitude da linha: 905.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 13)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.409100034396705, -49.2462032690229)
#
# Processando Curva Nível 2 (CSV Linha 13):
#   WKT recebido: 'MULTILINESTRING ((676402.2430419922 7188798.942993164, 676394.2930297852 7188796.143005371, 676391.1...', ID: 122079, Altitude da linha: 906.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 13)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40724357555742, -49.24622922742643)
#
# --- Processando dados da Linha 14 do CSV ---
#   Ponto Principal (Linha CSV 14): Lat=-25.41119554675795, Lon=-49.24771912310968, Alt Ponto=905.4123062332698 m
#     -> Associado à Curva 1 (ID: 121786, Elev: 905.0 m)
#     -> Associado à Curva 2 (ID: 122079, Elev: 906.0 m)
#
# Processando Curva Nível 1 (CSV Linha 14):
#   WKT recebido: 'MULTILINESTRING ((676402.1530151367 7188593.273010254, 676391.3729858398 7188605.213012695, 676386.6...', ID: 121786, Altitude da linha: 905.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 14)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.409100034396705, -49.2462032690229)
#
# Processando Curva Nível 2 (CSV Linha 14):
#   WKT recebido: 'MULTILINESTRING ((676402.2430419922 7188798.942993164, 676394.2930297852 7188796.143005371, 676391.1...', ID: 122079, Altitude da linha: 906.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 14)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40724357555742, -49.24622922742643)
#
# --- Processando dados da Linha 15 do CSV ---
#   Ponto Principal (Linha CSV 15): Lat=-25.41121413509452, Lon=-49.24768558972983, Alt Ponto=905.3153319332253 m
#     -> Associado à Curva 1 (ID: 121786, Elev: 905.0 m)
#     -> Associado à Curva 2 (ID: 122079, Elev: 906.0 m)
#
# Processando Curva Nível 1 (CSV Linha 15):
#   WKT recebido: 'MULTILINESTRING ((676402.1530151367 7188593.273010254, 676391.3729858398 7188605.213012695, 676386.6...', ID: 121786, Altitude da linha: 905.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 15)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.409100034396705, -49.2462032690229)
#
# Processando Curva Nível 2 (CSV Linha 15):
#   WKT recebido: 'MULTILINESTRING ((676402.2430419922 7188798.942993164, 676394.2930297852 7188796.143005371, 676391.1...', ID: 122079, Altitude da linha: 906.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 15)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40724357555742, -49.24622922742643)
#
# --- Processando dados da Linha 16 do CSV ---
#   Ponto Principal (Linha CSV 16): Lat=-25.411312672798797, Lon=-49.24758768333368, Alt Ponto=905.1806475235406 m
#     -> Associado à Curva 1 (ID: 121786, Elev: 905.0 m)
#     -> Associado à Curva 2 (ID: 122079, Elev: 906.0 m)
#
# Processando Curva Nível 1 (CSV Linha 16):
#   WKT recebido: 'MULTILINESTRING ((676402.1530151367 7188593.273010254, 676391.3729858398 7188605.213012695, 676386.6...', ID: 121786, Altitude da linha: 905.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 16)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.409100034396705, -49.2462032690229)
#
# Processando Curva Nível 2 (CSV Linha 16):
#   WKT recebido: 'MULTILINESTRING ((676402.2430419922 7188798.942993164, 676394.2930297852 7188796.143005371, 676391.1...', ID: 122079, Altitude da linha: 906.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 16)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40724357555742, -49.24622922742643)
#
# --- Processando dados da Linha 17 do CSV ---
#   Ponto Principal (Linha CSV 17): Lat=-25.41148603297185, Lon=-49.24743176551681, Alt Ponto=905.1710604071636 m
#     -> Associado à Curva 1 (ID: 121786, Elev: 905.0 m)
#     -> Associado à Curva 2 (ID: 122079, Elev: 906.0 m)
#
# Processando Curva Nível 1 (CSV Linha 17):
#   WKT recebido: 'MULTILINESTRING ((676402.1530151367 7188593.273010254, 676391.3729858398 7188605.213012695, 676386.6...', ID: 121786, Altitude da linha: 905.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 17)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.409100034396705, -49.2462032690229)
#
# Processando Curva Nível 2 (CSV Linha 17):
#   WKT recebido: 'MULTILINESTRING ((676402.2430419922 7188798.942993164, 676394.2930297852 7188796.143005371, 676391.1...', ID: 122079, Altitude da linha: 906.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 17)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40724357555742, -49.24622922742643)
#
# --- Processando dados da Linha 18 do CSV ---
#   Ponto Principal (Linha CSV 18): Lat=-25.41165697044156, Lon=-49.24727987101346, Alt Ponto=904.8198127256605 m
#     -> Associado à Curva 1 (ID: 121786, Elev: 905.0 m)
#     -> Associado à Curva 2 (ID: 122078, Elev: 904.0 m)
#
# Processando Curva Nível 1 (CSV Linha 18):
#   WKT recebido: 'MULTILINESTRING ((676402.1530151367 7188593.273010254, 676391.3729858398 7188605.213012695, 676386.6...', ID: 121786, Altitude da linha: 905.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 18)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.409100034396705, -49.2462032690229)
#
# Processando Curva Nível 2 (CSV Linha 18):
#   WKT recebido: 'MULTILINESTRING ((676402.1530151367 7188560.803039551, 676397.1130371094 7188565.062988281, 676390.7...', ID: 122078, Altitude da linha: 904.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 18)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.409393119499995, -49.24619902936915)
#
# --- Processando dados da Linha 19 do CSV ---
#   Ponto Principal (Linha CSV 19): Lat=-25.41226841327561, Lon=-49.24673567172249, Alt Ponto=903.6959978077743 m
#     -> Associado à Curva 1 (ID: 122078, Elev: 904.0 m)
#     -> Associado à Curva 2 (ID: 121793, Elev: 903.0 m)
#
# Processando Curva Nível 1 (CSV Linha 19):
#   WKT recebido: 'MULTILINESTRING ((676402.1530151367 7188560.803039551, 676397.1130371094 7188565.062988281, 676390.7...', ID: 122078, Altitude da linha: 904.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 19)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.409393119499995, -49.24619902936915)
#
# Processando Curva Nível 2 (CSV Linha 19):
#   WKT recebido: 'MULTILINESTRING ((676396.2230224609 7188364.932983398, 676391.4830322266 7188358.143005371, 676382.2...', ID: 121793, Altitude da linha: 903.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 19)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.411161812894512, -49.24623238823584)
#
# --- Processando dados da Linha 20 do CSV ---
#   Ponto Principal (Linha CSV 20): Lat=-25.41241763996436, Lon=-49.24660297466107, Alt Ponto=902.7879685429987 m
#     -> Associado à Curva 1 (ID: 121793, Elev: 903.0 m)
#     -> Associado à Curva 2 (ID: 121935, Elev: 902.0 m)
#
# Processando Curva Nível 1 (CSV Linha 20):
#   WKT recebido: 'MULTILINESTRING ((676396.2230224609 7188364.932983398, 676391.4830322266 7188358.143005371, 676382.2...', ID: 121793, Altitude da linha: 903.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 20)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.411161812894512, -49.24623238823584)
#
# Processando Curva Nível 2 (CSV Linha 20):
#   WKT recebido: 'MULTILINESTRING ((676282.0029907227 7187999.692993164, 676286.0930175781 7188003.613037109, 676289.5...', ID: 121935, Altitude da linha: 902.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 20)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.414472136468678, -49.247319899638455)
#
# --- Processando dados da Linha 21 do CSV ---
#   Ponto Principal (Linha CSV 21): Lat=-25.412474804681757, Lon=-49.24655610828802, Alt Ponto=902.2215238471406 m
#     -> Associado à Curva 1 (ID: 121935, Elev: 902.0 m)
#     -> Associado à Curva 2 (ID: 121793, Elev: 903.0 m)
#
# Processando Curva Nível 1 (CSV Linha 21):
#   WKT recebido: 'MULTILINESTRING ((676282.0029907227 7187999.692993164, 676286.0930175781 7188003.613037109, 676289.5...', ID: 121935, Altitude da linha: 902.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 21)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.414472136468678, -49.247319899638455)
#
# Processando Curva Nível 2 (CSV Linha 21):
#   WKT recebido: 'MULTILINESTRING ((676396.2230224609 7188364.932983398, 676391.4830322266 7188358.143005371, 676382.2...', ID: 121793, Altitude da linha: 903.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 21)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.411161812894512, -49.24623238823584)
#
# --- Processando dados da Linha 22 do CSV ---
#   Ponto Principal (Linha CSV 22): Lat=-25.41279161508513, Lon=-49.24632554673974, Alt Ponto=901.1436054573959 m
#     -> Associado à Curva 1 (ID: 121934, Elev: 901.0 m)
#     -> Associado à Curva 2 (ID: 121935, Elev: 902.0 m)
#
# Processando Curva Nível 1 (CSV Linha 22):
#   WKT recebido: 'MULTILINESTRING ((676402.1530151367 7188254.562988281, 676393.9530029297 7188245.192993164, 676390.6...', ID: 121934, Altitude da linha: 901.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 22)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.412157346735146, -49.24615903988323)
#
# Processando Curva Nível 2 (CSV Linha 22):
#   WKT recebido: 'MULTILINESTRING ((676282.0029907227 7187999.692993164, 676286.0930175781 7188003.613037109, 676289.5...', ID: 121935, Altitude da linha: 902.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 22)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.414472136468678, -49.247319899638455)
#
# --- Processando dados da Linha 23 do CSV ---
#   Ponto Principal (Linha CSV 23): Lat=-25.412858448124112, Lon=-49.24628466112347, Alt Ponto=900.8674715153452 m
#     -> Associado à Curva 1 (ID: 121934, Elev: 901.0 m)
#     -> Associado à Curva 2 (ID: 120485, Elev: 900.0 m)
#
# Processando Curva Nível 1 (CSV Linha 23):
#   WKT recebido: 'MULTILINESTRING ((676402.1530151367 7188254.562988281, 676393.9530029297 7188245.192993164, 676390.6...', ID: 121934, Altitude da linha: 901.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 23)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.412157346735146, -49.24615903988323)
#
# Processando Curva Nível 2 (CSV Linha 23):
#   WKT recebido: 'MULTILINESTRING ((676420.0130004883 7188131.093017578, 676418.6030273438 7188134.182983398, 676409.3...', ID: 120485, Altitude da linha: 900.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 23)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.413269710031944, -49.24596541043378)
#
# --- Processando dados da Linha 24 do CSV ---
#   Ponto Principal (Linha CSV 24): Lat=-25.41291316778196, Lon=-49.24625718655227, Alt Ponto=900.8803856168083 m
#     -> Associado à Curva 1 (ID: 121934, Elev: 901.0 m)
#     -> Associado à Curva 2 (ID: 120485, Elev: 900.0 m)
#
# Processando Curva Nível 1 (CSV Linha 24):
#   WKT recebido: 'MULTILINESTRING ((676402.1530151367 7188254.562988281, 676393.9530029297 7188245.192993164, 676390.6...', ID: 121934, Altitude da linha: 901.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 24)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.412157346735146, -49.24615903988323)
#
# Processando Curva Nível 2 (CSV Linha 24):
#   WKT recebido: 'MULTILINESTRING ((676420.0130004883 7188131.093017578, 676418.6030273438 7188134.182983398, 676409.3...', ID: 120485, Altitude da linha: 900.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 24)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.413269710031944, -49.24596541043378)
#
# --- Processando dados da Linha 25 do CSV ---
#   Ponto Principal (Linha CSV 25): Lat=-25.412986192583386, Lon=-49.246231659429554, Alt Ponto=900.8242215263591 m
#     -> Associado à Curva 1 (ID: 121934, Elev: 901.0 m)
#     -> Associado à Curva 2 (ID: 120485, Elev: 900.0 m)
#
# Processando Curva Nível 1 (CSV Linha 25):
#   WKT recebido: 'MULTILINESTRING ((676402.1530151367 7188254.562988281, 676393.9530029297 7188245.192993164, 676390.6...', ID: 121934, Altitude da linha: 901.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 25)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.412157346735146, -49.24615903988323)
#
# Processando Curva Nível 2 (CSV Linha 25):
#   WKT recebido: 'MULTILINESTRING ((676420.0130004883 7188131.093017578, 676418.6030273438 7188134.182983398, 676409.3...', ID: 120485, Altitude da linha: 900.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 25)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.413269710031944, -49.24596541043378)
#
# --- Processando dados da Linha 26 do CSV ---
#   Ponto Principal (Linha CSV 26): Lat=-25.41305238272274, Lon=-49.24623431856992, Alt Ponto=900.7717264951036 m
#     -> Associado à Curva 1 (ID: 121934, Elev: 901.0 m)
#     -> Associado à Curva 2 (ID: 120485, Elev: 900.0 m)
#
# Processando Curva Nível 1 (CSV Linha 26):
#   WKT recebido: 'MULTILINESTRING ((676402.1530151367 7188254.562988281, 676393.9530029297 7188245.192993164, 676390.6...', ID: 121934, Altitude da linha: 901.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 26)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.412157346735146, -49.24615903988323)
#
# Processando Curva Nível 2 (CSV Linha 26):
#   WKT recebido: 'MULTILINESTRING ((676420.0130004883 7188131.093017578, 676418.6030273438 7188134.182983398, 676409.3...', ID: 120485, Altitude da linha: 900.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 26)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.413269710031944, -49.24596541043378)
#
# --- Processando dados da Linha 27 do CSV ---
#   Ponto Principal (Linha CSV 27): Lat=-25.413134925877, Lon=-49.24624837709871, Alt Ponto=900.654965783855 m
#     -> Associado à Curva 1 (ID: 121934, Elev: 901.0 m)
#     -> Associado à Curva 2 (ID: 120485, Elev: 900.0 m)
#
# Processando Curva Nível 1 (CSV Linha 27):
#   WKT recebido: 'MULTILINESTRING ((676402.1530151367 7188254.562988281, 676393.9530029297 7188245.192993164, 676390.6...', ID: 121934, Altitude da linha: 901.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 27)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.412157346735146, -49.24615903988323)
#
# Processando Curva Nível 2 (CSV Linha 27):
#   WKT recebido: 'MULTILINESTRING ((676420.0130004883 7188131.093017578, 676418.6030273438 7188134.182983398, 676409.3...', ID: 120485, Altitude da linha: 900.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 27)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.413269710031944, -49.24596541043378)
#
# --- Processando dados da Linha 28 do CSV ---
#   Ponto Principal (Linha CSV 28): Lat=-25.41328151882393, Lon=-49.24629160465048, Alt Ponto=901.0000000000001 m
#     -> Associado à Curva 1 (ID: 121792, Elev: 901.0 m)
#     -> Associado à Curva 2 (ID: 121934, Elev: 901.0 m)
#
# Processando Curva Nível 1 (CSV Linha 28):
#   WKT recebido: 'MULTILINESTRING ((676396.2230224609 7188130.973022461, 676394.9730224609 7188130.072998047, 676391.7...', ID: 121792, Altitude da linha: 901.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 28)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.413273614991148, -49.24620183592057)
#
# Processando Curva Nível 2 (CSV Linha 28):
#   WKT recebido: 'MULTILINESTRING ((676402.1530151367 7188254.562988281, 676393.9530029297 7188245.192993164, 676390.6...', ID: 121934, Altitude da linha: 901.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 28)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.412157346735146, -49.24615903988323)
#
# --- Processando dados da Linha 29 do CSV ---
#   Ponto Principal (Linha CSV 29): Lat=-25.41336147764189, Lon=-49.24633199388944, Alt Ponto=901.1848485161746 m
#     -> Associado à Curva 1 (ID: 121792, Elev: 901.0 m)
#     -> Associado à Curva 2 (ID: 121935, Elev: 902.0 m)
#
# Processando Curva Nível 1 (CSV Linha 29):
#   WKT recebido: 'MULTILINESTRING ((676396.2230224609 7188130.973022461, 676394.9730224609 7188130.072998047, 676391.7...', ID: 121792, Altitude da linha: 901.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 29)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.413273614991148, -49.24620183592057)
#
# Processando Curva Nível 2 (CSV Linha 29):
#   WKT recebido: 'MULTILINESTRING ((676282.0029907227 7187999.692993164, 676286.0930175781 7188003.613037109, 676289.5...', ID: 121935, Altitude da linha: 902.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 29)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.414472136468678, -49.247319899638455)
#
# --- Processando dados da Linha 30 do CSV ---
#   Ponto Principal (Linha CSV 30): Lat=-25.413428409193173, Lon=-49.24636995814368, Alt Ponto=901.0684792652343 m
#     -> Associado à Curva 1 (ID: 121792, Elev: 901.0 m)
#     -> Associado à Curva 2 (ID: 121935, Elev: 902.0 m)
#
# Processando Curva Nível 1 (CSV Linha 30):
#   WKT recebido: 'MULTILINESTRING ((676396.2230224609 7188130.973022461, 676394.9730224609 7188130.072998047, 676391.7...', ID: 121792, Altitude da linha: 901.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 30)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.413273614991148, -49.24620183592057)
#
# Processando Curva Nível 2 (CSV Linha 30):
#   WKT recebido: 'MULTILINESTRING ((676282.0029907227 7187999.692993164, 676286.0930175781 7188003.613037109, 676289.5...', ID: 121935, Altitude da linha: 902.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 30)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.414472136468678, -49.247319899638455)
#
# --- Processando dados da Linha 31 do CSV ---
#   Ponto Principal (Linha CSV 31): Lat=-25.41349958040706, Lon=-49.24642468620425, Alt Ponto=901.0000000000001 m
#     -> Associado à Curva 1 (ID: 121791, Elev: 901.0 m)
#     -> Associado à Curva 2 (ID: 121792, Elev: 901.0 m)
#
# Processando Curva Nível 1 (CSV Linha 31):
#   WKT recebido: 'MULTILINESTRING ((676369.8129882812 7188103.7830200195, 676366.1929931641 7188099.653015137, 676357....', ID: 121791, Altitude da linha: 901.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 31)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.413522173359137, -49.24646076666701)
#
# Processando Curva Nível 2 (CSV Linha 31):
#   WKT recebido: 'MULTILINESTRING ((676396.2230224609 7188130.973022461, 676394.9730224609 7188130.072998047, 676391.7...', ID: 121792, Altitude da linha: 901.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 31)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.413273614991148, -49.24620183592057)
#
# --- Processando dados da Linha 32 do CSV ---
#   Ponto Principal (Linha CSV 32): Lat=-25.41408225243661, Lon=-49.24705665863485, Alt Ponto=901.8896893064177 m
#     -> Associado à Curva 1 (ID: 121935, Elev: 902.0 m)
#     -> Associado à Curva 2 (ID: 121791, Elev: 901.0 m)
#
# Processando Curva Nível 1 (CSV Linha 32):
#   WKT recebido: 'MULTILINESTRING ((676282.0029907227 7187999.692993164, 676286.0930175781 7188003.613037109, 676289.5...', ID: 121935, Altitude da linha: 902.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 32)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.414472136468678, -49.247319899638455)
#
# Processando Curva Nível 2 (CSV Linha 32):
#   WKT recebido: 'MULTILINESTRING ((676369.8129882812 7188103.7830200195, 676366.1929931641 7188099.653015137, 676357....', ID: 121791, Altitude da linha: 901.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 32)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.413522173359137, -49.24646076666701)
#
# --- Processando dados da Linha 33 do CSV ---
#   Ponto Principal (Linha CSV 33): Lat=-25.414644937464946, Lon=-49.24766650284096, Alt Ponto=903.7411429324569 m
#     -> Associado à Curva 1 (ID: 121720, Elev: 904.0 m)
#     -> Associado à Curva 2 (ID: 121721, Elev: 903.0 m)
#
# Processando Curva Nível 1 (CSV Linha 33):
#   WKT recebido: 'MULTILINESTRING ((675381.3930053711 7186799.692993164, 675383.1229858398 7186801.5330200195, 675385....', ID: 121720, Altitude da linha: 904.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 33)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425410273310643, -49.256115032075066)
#
# Processando Curva Nível 2 (CSV Linha 33):
#   WKT recebido: 'MULTILINESTRING ((675430.9830322266 7186799.692993164, 675431.1530151367 7186803.343017578, 675431.8...', ID: 121721, Altitude da linha: 903.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 33)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425404421409038, -49.25562212036664)
#
# --- Processando dados da Linha 34 do CSV ---
#   Ponto Principal (Linha CSV 34): Lat=-25.414856621877217, Lon=-49.247680578671066, Alt Ponto=903.4094745828894 m
#     -> Associado à Curva 1 (ID: 121721, Elev: 903.0 m)
#     -> Associado à Curva 2 (ID: 121720, Elev: 904.0 m)
#
# Processando Curva Nível 1 (CSV Linha 34):
#   WKT recebido: 'MULTILINESTRING ((675430.9830322266 7186799.692993164, 675431.1530151367 7186803.343017578, 675431.8...', ID: 121721, Altitude da linha: 903.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 34)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425404421409038, -49.25562212036664)
#
# Processando Curva Nível 2 (CSV Linha 34):
#   WKT recebido: 'MULTILINESTRING ((675381.3930053711 7186799.692993164, 675383.1229858398 7186801.5330200195, 675385....', ID: 121720, Altitude da linha: 904.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 34)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425410273310643, -49.256115032075066)
#
# --- Processando dados da Linha 35 do CSV ---
#   Ponto Principal (Linha CSV 35): Lat=-25.41503014977287, Lon=-49.24770806554636, Alt Ponto=901.7619354711001 m
#     -> Associado à Curva 1 (ID: 121722, Elev: 902.0 m)
#     -> Associado à Curva 2 (ID: 121723, Elev: 901.0 m)
#
# Processando Curva Nível 1 (CSV Linha 35):
#   WKT recebido: 'MULTILINESTRING ((675499.0230102539 7186799.692993164, 675499.8930053711 7186804.593017578, 675500.0...', ID: 121722, Altitude da linha: 902.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 35)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425396389621223, -49.25494582128901)
#
# Processando Curva Nível 2 (CSV Linha 35):
#   WKT recebido: 'MULTILINESTRING ((675590.1130371094 7186799.692993164, 675589.3430175781 7186801.233032227, 675588.0...', ID: 121723, Altitude da linha: 901.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 35)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.42538563201861, -49.254040411379584)
#
# --- Processando dados da Linha 36 do CSV ---
#   Ponto Principal (Linha CSV 36): Lat=-25.41534601425269, Lon=-49.24774325800543, Alt Ponto=900.5212813411326 m
#     -> Associado à Curva 1 (ID: 121723, Elev: 901.0 m)
#     -> Associado à Curva 2 (ID: 121243, Elev: 900.0 m)
#
# Processando Curva Nível 1 (CSV Linha 36):
#   WKT recebido: 'MULTILINESTRING ((675590.1130371094 7186799.692993164, 675589.3430175781 7186801.233032227, 675588.0...', ID: 121723, Altitude da linha: 901.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 36)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.42538563201861, -49.254040411379584)
#
# Processando Curva Nível 2 (CSV Linha 36):
#   WKT recebido: 'MULTILINESTRING ((675641.6271972656 7187296.5244140625, 675637.5629882812 7187296.3330078125, 675634...', ID: 121243, Altitude da linha: 900.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 36)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.42089496561347, -49.253593015240746)
#
# --- Processando dados da Linha 37 do CSV ---
#   Ponto Principal (Linha CSV 37): Lat=-25.41575091024826, Lon=-49.24779052040502, Alt Ponto=899.0596328563598 m
#     -> Associado à Curva 1 (ID: 122002, Elev: 899.0 m)
#     -> Associado à Curva 2 (ID: 121243, Elev: 900.0 m)
#
# Processando Curva Nível 1 (CSV Linha 37):
#   WKT recebido: 'MULTILINESTRING ((675638.4530029297 7186799.692993164, 675639.0029907227 7186802.682983398, 675639.4...', ID: 122002, Altitude da linha: 899.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 37)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425379920873453, -49.25355992557442)
#
# Processando Curva Nível 2 (CSV Linha 37):
#   WKT recebido: 'MULTILINESTRING ((675641.6271972656 7187296.5244140625, 675637.5629882812 7187296.3330078125, 675634...', ID: 121243, Altitude da linha: 900.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 37)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.42089496561347, -49.253593015240746)
#
# --- Processando dados da Linha 38 do CSV ---
#   Ponto Principal (Linha CSV 38): Lat=-25.41603376681692, Lon=-49.24782101899825, Alt Ponto=898.7196808937839 m
#     -> Associado à Curva 1 (ID: 122002, Elev: 899.0 m)
#     -> Associado à Curva 2 (ID: 122001, Elev: 898.0 m)
#
# Processando Curva Nível 1 (CSV Linha 38):
#   WKT recebido: 'MULTILINESTRING ((675638.4530029297 7186799.692993164, 675639.0029907227 7186802.682983398, 675639.4...', ID: 122002, Altitude da linha: 899.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 38)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425379920873453, -49.25355992557442)
#
# Processando Curva Nível 2 (CSV Linha 38):
#   WKT recebido: 'MULTILINESTRING ((675664.5830078125 7186799.692993164, 675664.4830322266 7186799.87298584, 675662.45...', ID: 122001, Altitude da linha: 898.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 38)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425376833079646, -49.253300200659815)
#
# --- Processando dados da Linha 39 do CSV ---
#   Ponto Principal (Linha CSV 39): Lat=-25.41639490416441, Lon=-49.247850344125055, Alt Ponto=897.2459031679546 m
#     -> Associado à Curva 1 (ID: 121848, Elev: 897.0 m)
#     -> Associado à Curva 2 (ID: 122001, Elev: 898.0 m)
#
# Processando Curva Nível 1 (CSV Linha 39):
#   WKT recebido: 'MULTILINESTRING ((675729.8129882812 7186799.692993164, 675728.6530151367 7186801.423034668, 675725.6...', ID: 121848, Altitude da linha: 897.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 39)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425369122823337, -49.25265183314836)
#
# Processando Curva Nível 2 (CSV Linha 39):
#   WKT recebido: 'MULTILINESTRING ((675664.5830078125 7186799.692993164, 675664.4830322266 7186799.87298584, 675662.45...', ID: 122001, Altitude da linha: 898.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 39)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425376833079646, -49.253300200659815)
#
# --- Processando dados da Linha 40 do CSV ---
#   Ponto Principal (Linha CSV 40): Lat=-25.41675725281976, Lon=-49.24787698704283, Alt Ponto=896.6131517998341 m
#     -> Associado à Curva 1 (ID: 121848, Elev: 897.0 m)
#     -> Associado à Curva 2 (ID: 121847, Elev: 896.0 m)
#
# Processando Curva Nível 1 (CSV Linha 40):
#   WKT recebido: 'MULTILINESTRING ((675729.8129882812 7186799.692993164, 675728.6530151367 7186801.423034668, 675725.6...', ID: 121848, Altitude da linha: 897.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 40)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425369122823337, -49.25265183314836)
#
# Processando Curva Nível 2 (CSV Linha 40):
#   WKT recebido: 'MULTILINESTRING ((675782.4130249023 7186799.692993164, 675779.9329833984 7186800.643005371, 675775.0...', ID: 121847, Altitude da linha: 896.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 40)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.425362903358625, -49.25212900389163)
#
# --- Processando dados da Linha 41 do CSV ---
#   Ponto Principal (Linha CSV 41): Lat=-25.417374144323908, Lon=-49.24792591428877, Alt Ponto=894.3762448981864 m
#     -> Associado à Curva 1 (ID: 121533, Elev: 894.0 m)
#     -> Associado à Curva 2 (ID: 121075, Elev: 895.0 m)
#
# Processando Curva Nível 1 (CSV Linha 41):
#   WKT recebido: 'MULTILINESTRING ((676233.4329833984 7187703.442993164, 676235.4429931641 7187706.213012695, 676236.2...', ID: 121533, Altitude da linha: 894.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 41)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.41715194708209, -49.2477639685886)
#
# Processando Curva Nível 2 (CSV Linha 41):
#   WKT recebido: 'MULTILINESTRING ((676238.5830078125 7187713.932983398, 676238.7730102539 7187709.95300293, 676237.44...', ID: 121075, Altitude da linha: 895.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 41)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.417056650473626, -49.24771415141869)
#
# --- Processando dados da Linha 42 do CSV ---
#   Ponto Principal (Linha CSV 42): Lat=-25.41743124120169, Lon=-49.24726893495102, Alt Ponto=897.3944078029375 m
#     -> Associado à Curva 1 (ID: 121389, Elev: 897.0 m)
#     -> Associado à Curva 2 (ID: 122126, Elev: 898.0 m)
#
# Processando Curva Nível 1 (CSV Linha 42):
#   WKT recebido: 'MULTILINESTRING ((676402.1530151367 7187824.182983398, 676400.9530029297 7187819.87298584, 676398.87...', ID: 121389, Altitude da linha: 897.0 m
#   Tipo de geometria parseada: MultiLineString
# ...
#
# --- Processando dados da Linha 959 do CSV ---
#   Ponto Principal (Linha CSV 959): Lat=-25.409851289624648, Lon=-49.25419369264239, Alt Ponto=925.3454910748574 m
#     -> Associado à Curva 1 (ID: 122267, Elev: 925.0 m)
#     -> Associado à Curva 2 (ID: 120752, Elev: 926.0 m)
#
# Processando Curva Nível 1 (CSV Linha 959):
#   WKT recebido: 'MULTILINESTRING ((675385.5354003906 7188999.692993164, 675387.3430175781 7188995.7830200195, 675386....', ID: 122267, Altitude da linha: 925.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 959)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40555173960801, -49.256359555275154)
#
# Processando Curva Nível 2 (CSV Linha 959):
#   WKT recebido: 'MULTILINESTRING ((675347.7504272461 7188999.692993164, 675349.2630004883 7188994.713012695, 675350.5...', ID: 120752, Altitude da linha: 926.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 959)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40555619347531, -49.25673506652342)
#
# --- Processando dados da Linha 960 do CSV ---
#   Ponto Principal (Linha CSV 960): Lat=-25.409719736645044, Lon=-49.25412118711984, Alt Ponto=926.7080660301008 m
#     -> Associado à Curva 1 (ID: 120753, Elev: 927.0 m)
#     -> Associado à Curva 2 (ID: 120752, Elev: 926.0 m)
#
# Processando Curva Nível 1 (CSV Linha 960):
#   WKT recebido: 'MULTILINESTRING ((675340.6032104492 7188999.692993164, 675342.6229858398 7188997.752990723, 675341.6...', ID: 120753, Altitude da linha: 927.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 960)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40555703583883, -49.2568060963656)
#
# Processando Curva Nível 2 (CSV Linha 960):
#   WKT recebido: 'MULTILINESTRING ((675347.7504272461 7188999.692993164, 675349.2630004883 7188994.713012695, 675350.5...', ID: 120752, Altitude da linha: 926.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 960)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40555619347531, -49.25673506652342)
#
# --- Processando dados da Linha 961 do CSV ---
#   Ponto Principal (Linha CSV 961): Lat=-25.409651780614443, Lon=-49.254080868105575, Alt Ponto=927.8039813805167 m
#     -> Associado à Curva 1 (ID: 120873, Elev: 928.0 m)
#     -> Associado à Curva 2 (ID: 120753, Elev: 927.0 m)
#
# Processando Curva Nível 1 (CSV Linha 961):
#   WKT recebido: 'MULTILINESTRING ((675323.673034668 7188999.692993164, 675323.673034668 7188999.322998047, 675322.613...', ID: 120873, Altitude da linha: 928.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 961)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.405559031074883, -49.25697435036417)
#
# Processando Curva Nível 2 (CSV Linha 961):
#   WKT recebido: 'MULTILINESTRING ((675340.6032104492 7188999.692993164, 675342.6229858398 7188997.752990723, 675341.6...', ID: 120753, Altitude da linha: 927.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 961)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40555703583883, -49.2568060963656)
#
# --- Processando dados da Linha 962 do CSV ---
#   Ponto Principal (Linha CSV 962): Lat=-25.409410939039383, Lon=-49.25385316572442, Alt Ponto=926.8362492388092 m
#     -> Associado à Curva 1 (ID: 120753, Elev: 927.0 m)
#     -> Associado à Curva 2 (ID: 120752, Elev: 926.0 m)
#
# Processando Curva Nível 1 (CSV Linha 962):
#   WKT recebido: 'MULTILINESTRING ((675340.6032104492 7188999.692993164, 675342.6229858398 7188997.752990723, 675341.6...', ID: 120753, Altitude da linha: 927.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 962)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40555703583883, -49.2568060963656)
#
# Processando Curva Nível 2 (CSV Linha 962):
#   WKT recebido: 'MULTILINESTRING ((675347.7504272461 7188999.692993164, 675349.2630004883 7188994.713012695, 675350.5...', ID: 120752, Altitude da linha: 926.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 962)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40555619347531, -49.25673506652342)
#
# --- Processando dados da Linha 963 do CSV ---
#   Ponto Principal (Linha CSV 963): Lat=-25.409149504029845, Lon=-49.25360735843248, Alt Ponto=923.9396637030517 m
#     -> Associado à Curva 1 (ID: 120751, Elev: 924.0 m)
#     -> Associado à Curva 2 (ID: 122413, Elev: 923.0 m)
#
# Processando Curva Nível 1 (CSV Linha 963):
#   WKT recebido: 'MULTILINESTRING ((675410.7182006836 7188999.692993164, 675411.2230224609 7188999.2830200195, 675421....', ID: 120751, Altitude da linha: 924.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 963)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.405548770677534, -49.25610928586599)
#
# Processando Curva Nível 2 (CSV Linha 963):
#   WKT recebido: 'MULTILINESTRING ((675428.0758056641 7188999.692993164, 675435.3630371094 7188993.353027344, 675437.1...', ID: 122413, Altitude da linha: 923.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 963)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40554672405197, -49.255936784122234)
#
# --- Processando dados da Linha 964 do CSV ---
#   Ponto Principal (Linha CSV 964): Lat=-25.408777450450213, Lon=-49.25325454816493, Alt Ponto=919.878475682435 m
#     -> Associado à Curva 1 (ID: 122269, Elev: 920.0 m)
#     -> Associado à Curva 2 (ID: 120451, Elev: 919.0 m)
#
# Processando Curva Nível 1 (CSV Linha 964):
#   WKT recebido: 'MULTILINESTRING ((675466.1544189453 7188999.692993164, 675467.2529907227 7188993.613037109, 675468.7...', ID: 122269, Altitude da linha: 920.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 964)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.405542233515398, -49.255558354836914)
#
# Processando Curva Nível 2 (CSV Linha 964):
#   WKT recebido: 'MULTILINESTRING ((675476.3944091797 7188999.692993164, 675476.2630004883 7188999.442993164, 675474.8...', ID: 120451, Altitude da linha: 919.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 964)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.405541025767278, -49.2554565887466)
#
# --- Processando dados da Linha 965 do CSV ---
#   Ponto Principal (Linha CSV 965): Lat=-25.407863750653988, Lon=-49.25240677055229, Alt Ponto=914.2684394981425 m
#     -> Associado à Curva 1 (ID: 120457, Elev: 914.0 m)
#     -> Associado à Curva 2 (ID: 122435, Elev: 915.0 m)
#
# Processando Curva Nível 1 (CSV Linha 965):
#   WKT recebido: 'MULTILINESTRING ((675612.2368164062 7188999.692993164, 675610.4130249023 7188996.143005371, 675609.9...', ID: 120457, Altitude da linha: 914.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 965)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.405524997274785, -49.2541065733633)
#
# Processando Curva Nível 2 (CSV Linha 965):
#   WKT recebido: 'MULTILINESTRING ((675720.7730102539 7188890.643005371, 675719.7730102539 7188886.803039551, 675720.1...', ID: 122435, Altitude da linha: 915.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 965)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40649650849052, -49.25301374927457)
#
# --- Processando dados da Linha 966 do CSV ---
#   Ponto Principal (Linha CSV 966): Lat=-25.407659238691856, Lon=-49.25267183758302, Alt Ponto=915.5518680103089 m
#     -> Associado à Curva 1 (ID: 120458, Elev: 916.0 m)
#     -> Associado à Curva 2 (ID: 122435, Elev: 915.0 m)
#
# Processando Curva Nível 1 (CSV Linha 966):
#   WKT recebido: 'MULTILINESTRING ((675532.0568237305 7188999.692993164, 675533.7330322266 7188994.053039551, 675532.8...', ID: 120458, Altitude da linha: 916.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 966)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.405534459473657, -49.254903409983264)
#
# Processando Curva Nível 2 (CSV Linha 966):
#   WKT recebido: 'MULTILINESTRING ((675720.7730102539 7188890.643005371, 675719.7730102539 7188886.803039551, 675720.1...', ID: 122435, Altitude da linha: 915.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 966)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40649650849052, -49.25301374927457)
#
# --- Processando dados da Linha 967 do CSV ---
#   Ponto Principal (Linha CSV 967): Lat=-25.40744564129321, Lon=-49.252939586822784, Alt Ponto=916.6922543325841 m
#     -> Associado à Curva 1 (ID: 120459, Elev: 917.0 m)
#     -> Associado à Curva 2 (ID: 120458, Elev: 916.0 m)
#
# Processando Curva Nível 1 (CSV Linha 967):
#   WKT recebido: 'MULTILINESTRING ((675516.9974365234 7188999.692993164, 675517.2130126953 7188999.263000488, 675516.0...', ID: 120459, Altitude da linha: 917.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 967)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.405536236180275, -49.255053071693)
#
# Processando Curva Nível 2 (CSV Linha 967):
#   WKT recebido: 'MULTILINESTRING ((675532.0568237305 7188999.692993164, 675533.7330322266 7188994.053039551, 675532.8...', ID: 120458, Altitude da linha: 916.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 967)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.405534459473657, -49.254903409983264)
#
# --- Processando dados da Linha 968 do CSV ---
#   Ponto Principal (Linha CSV 968): Lat=-25.407224819481836, Lon=-49.2527309768791, Alt Ponto=914.7363534276533 m
#     -> Associado à Curva 1 (ID: 122435, Elev: 915.0 m)
#     -> Associado à Curva 2 (ID: 120457, Elev: 914.0 m)
#
# Processando Curva Nível 1 (CSV Linha 968):
#   WKT recebido: 'MULTILINESTRING ((675720.7730102539 7188890.643005371, 675719.7730102539 7188886.803039551, 675720.1...', ID: 122435, Altitude da linha: 915.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 968)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40649650849052, -49.25301374927457)
#
# Processando Curva Nível 2 (CSV Linha 968):
#   WKT recebido: 'MULTILINESTRING ((675612.2368164062 7188999.692993164, 675610.4130249023 7188996.143005371, 675609.9...', ID: 120457, Altitude da linha: 914.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 968)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.405524997274785, -49.2541065733633)
#
# --- Processando dados da Linha 969 do CSV ---
#   Ponto Principal (Linha CSV 969): Lat=-25.407052857200803, Lon=-49.25256628810797, Alt Ponto=914.0979411919664 m
#     -> Associado à Curva 1 (ID: 120457, Elev: 914.0 m)
#     -> Associado à Curva 2 (ID: 122435, Elev: 915.0 m)
#
# Processando Curva Nível 1 (CSV Linha 969):
#   WKT recebido: 'MULTILINESTRING ((675612.2368164062 7188999.692993164, 675610.4130249023 7188996.143005371, 675609.9...', ID: 120457, Altitude da linha: 914.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 969)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.405524997274785, -49.2541065733633)
#
# Processando Curva Nível 2 (CSV Linha 969):
#   WKT recebido: 'MULTILINESTRING ((675720.7730102539 7188890.643005371, 675719.7730102539 7188886.803039551, 675720.1...', ID: 122435, Altitude da linha: 915.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 969)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40649650849052, -49.25301374927457)
#
# --- Processando dados da Linha 970 do CSV ---
#   Ponto Principal (Linha CSV 970): Lat=-25.406902326247646, Lon=-49.2524256056763, Alt Ponto=913.4593919455381 m
#     -> Associado à Curva 1 (ID: 122761, Elev: 913.0 m)
#     -> Associado à Curva 2 (ID: 120457, Elev: 914.0 m)
#
# Processando Curva Nível 1 (CSV Linha 970):
#   WKT recebido: 'MULTILINESTRING ((675637.999206543 7188999.692993164, 675637.9930419922 7188999.562988281, 675634.66...', ID: 122761, Altitude da linha: 913.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 970)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40552195608842, -49.2538505442922)
#
# Processando Curva Nível 2 (CSV Linha 970):
#   WKT recebido: 'MULTILINESTRING ((675612.2368164062 7188999.692993164, 675610.4130249023 7188996.143005371, 675609.9...', ID: 120457, Altitude da linha: 914.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 970)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.405524997274785, -49.2541065733633)
#
# --- Processando dados da Linha 971 do CSV ---
#   Ponto Principal (Linha CSV 971): Lat=-25.406759685587105, Lon=-49.25229062293886, Alt Ponto=912.9931793720648 m
#     -> Associado à Curva 1 (ID: 122761, Elev: 913.0 m)
#     -> Associado à Curva 2 (ID: 122759, Elev: 912.0 m)
#
# Processando Curva Nível 1 (CSV Linha 971):
#   WKT recebido: 'MULTILINESTRING ((675637.999206543 7188999.692993164, 675637.9930419922 7188999.562988281, 675634.66...', ID: 122761, Altitude da linha: 913.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 971)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40552195608842, -49.2538505442922)
#
# Processando Curva Nível 2 (CSV Linha 971):
#   WKT recebido: 'MULTILINESTRING ((675768.6744384766 7188999.692993164, 675765.6829833984 7188997.37298584, 675766.27...', ID: 122759, Altitude da linha: 912.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 971)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.405506523340453, -49.25255188210982)
#
# --- Processando dados da Linha 972 do CSV ---
#   Ponto Principal (Linha CSV 972): Lat=-25.40663860356741, Lon=-49.252169520064285, Alt Ponto=912.3526363829142 m
#     -> Associado à Curva 1 (ID: 122759, Elev: 912.0 m)
#     -> Associado à Curva 2 (ID: 122761, Elev: 913.0 m)
#
# Processando Curva Nível 1 (CSV Linha 972):
#   WKT recebido: 'MULTILINESTRING ((675768.6744384766 7188999.692993164, 675765.6829833984 7188997.37298584, 675766.27...', ID: 122759, Altitude da linha: 912.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 1 (CSV Linha 972)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.405506523340453, -49.25255188210982)
#
# Processando Curva Nível 2 (CSV Linha 972):
#   WKT recebido: 'MULTILINESTRING ((675637.999206543 7188999.692993164, 675637.9930419922 7188999.562988281, 675634.66...', ID: 122761, Altitude da linha: 913.0 m
#   Tipo de geometria parseada: MultiLineString
#   1 segmento(s) de linha adicionado(s) para 'Curva Nível 2 (CSV Linha 972)'.
#     Exemplo de primeiras coordenadas reprojetadas (Lat, Lon): (-25.40552195608842, -49.2538505442922)
#
# Mapa salvo como 'mapa_pontos_com_id_curvas.html'.

# %%
import folium
from folium import FeatureGroup, LayerControl
from folium.plugins import HeatMap
import branca.colormap as cm
from shapely import wkt
import pandas as pd
from pyproj import Transformer, CRS

# ==============================================================================
# CONFIGURAÇÕES DO USUÁRIO - AJUSTE CONFORME NECESSÁRIO
# ==============================================================================

SOURCE_EPSG = "EPSG:31982"
TARGET_EPSG = "EPSG:4326"

# Nomes das colunas de ATRIBUTOS no seu arquivo CSV
ALTITUDE_PONTO_COL = 'altimetria_interpolada'
ALTITUDE_LINHA1_COL = 'linha1_elevation'
ALTITUDE_LINHA2_COL = 'linha2_elevation'
ID_LINHA1_COL = 'linha1_gid'
ID_LINHA2_COL = 'linha2_gid'
UNIDADE_ALTITUDE = "m"

# Configurações para destaque de variação altimétrica
TOP_N_PONTOS = 50  # Número de pontos com maior variação a destacar
COR_BAIXA_VARIACAO = 'green'
COR_ALTA_VARIACAO = 'red'

FILE_PATH_CSV = 'resultado1.csv'
OUTPUT_MAP_FILE = 'mapa_variacao_altimetrica.html'
# ==============================================================================

# Criar transformador de coordenadas
try:
    transformer = Transformer.from_crs(CRS.from_string(SOURCE_EPSG), CRS.from_string(TARGET_EPSG), always_xy=True)
except Exception as e:
    print(f"Erro ao criar o transformador de coordenadas: {e}")
    exit()

df = resultado_copia.copy()

if df.empty:
    print(f"DataFrame carregado de '{FILE_PATH_CSV}' está vazio.")
    exit()

# Verificar colunas obrigatórias
required_columns = ['Latitude', 'Longitude', 
                    'linha1_geometry', 'linha2_geometry',
                    ALTITUDE_PONTO_COL, ALTITUDE_LINHA1_COL, ALTITUDE_LINHA2_COL,
                    ID_LINHA1_COL, ID_LINHA2_COL]

missing_cols = [col for col in required_columns if col not in df.columns]
if missing_cols:
    print(f"Erro: Colunas obrigatórias não encontradas: {', '.join(missing_cols)}")
    print(f"Colunas no CSV: {df.columns.tolist()}")
    exit()

# Calcular variação altimétrica
df['variacao_altimetrica'] = abs(df[ALTITUDE_LINHA1_COL] - df[ALTITUDE_LINHA2_COL])

# Identificar pontos com maior variação
df_ordenado = df.sort_values('variacao_altimetrica', ascending=False)
top_variacoes = df_ordenado.head(TOP_N_PONTOS)

# Criar mapa
map_center_latitude = df['Latitude'].mean()
map_center_longitude = df['Longitude'].mean()
print(f"Centro do mapa: Lat: {map_center_latitude}, Lon: {map_center_longitude}")

m = folium.Map(location=[map_center_latitude, map_center_longitude], 
               zoom_start=12, 
               tiles='OpenStreetMap')

# ==============================================================================
# FUNÇÃO PARA ADICIONAR GEOMETRIAS DE LINHA
# ==============================================================================
def adicionar_geometria_linha(wkt_string, feature_group, cor_linha, nome_camada_debug, altitude_valor, id_linha_valor=None):
    if pd.isna(wkt_string) or not str(wkt_string).strip():
        return

    altitude_display = f"{altitude_valor} {UNIDADE_ALTITUDE}" if pd.notna(altitude_valor) else "N/A"
    id_display = f"ID: {id_linha_valor}" if pd.notna(id_linha_valor) else "ID: N/A"

    popup_text_linha = f"Curva de Nível<br>{id_display}<br>Altitude: {altitude_display}"
    tooltip_text_linha = f"{id_display}, Alt: {altitude_display}"

    try:
        geom = wkt.loads(str(wkt_string))
    except Exception as e:
        return

    if geom.is_empty:
        return

    linhas_para_plotar_orig = []
    if geom.geom_type == 'LineString':
        linhas_para_plotar_orig.append(geom)
    elif geom.geom_type == 'MultiLineString':
        linhas_para_plotar_orig.extend(list(geom.geoms))
    else:
        return
        
    for linha_orig in linhas_para_plotar_orig:
        if linha_orig.is_empty:
            continue
        
        coords_originais_projetadas = list(linha_orig.coords)
        if not coords_originais_projetadas:
            continue
        
        coords_reprojetadas_folium = []
        try:
            for x_proj, y_proj in coords_originais_projetadas:
                lon_deg, lat_deg = transformer.transform(x_proj, y_proj)
                coords_reprojetadas_folium.append((lat_deg, lon_deg))
        except Exception as e:
            continue

        if not coords_reprojetadas_folium:
            continue
        
        folium.PolyLine(
            coords_reprojetadas_folium, color=cor_linha, weight=2.5, opacity=0.8,
            popup=folium.Popup(popup_text_linha, max_width=250),
            tooltip=tooltip_text_linha
        ).add_to(feature_group)

# ==============================================================================
# CONFIGURAR CAMADAS DO MAPA
# ==============================================================================

# Camada para todos os pontos
fg_pontos_todos = FeatureGroup(name='Todos os Pontos', show=True)
m.add_child(fg_pontos_todos)

# Camada para curvas de nível
fg_curva1_todas = FeatureGroup(name='Curvas de Nível 1', show=False)
m.add_child(fg_curva1_todas)
fg_curva2_todas = FeatureGroup(name='Curvas de Nível 2', show=False)
m.add_child(fg_curva2_todas)

# Camada para pontos de alta variação
fg_variacoes = FeatureGroup(name=f'Top {TOP_N_PONTOS} Variações', show=True)
m.add_child(fg_variacoes)

# Camada para heatmap
fg_heatmap = FeatureGroup(name='Heatmap de Variação', show=True)
m.add_child(fg_heatmap)

# ==============================================================================
# ADICIONAR DADOS AO MAPA
# ==============================================================================

# Criar colormap para as variações
if df['variacao_altimetrica'].notna().any():
    min_variacao = df['variacao_altimetrica'].min()
    max_variacao = df['variacao_altimetrica'].max()
    colormap = cm.LinearColormap(
        [COR_BAIXA_VARIACAO, COR_ALTA_VARIACAO],
        vmin=min_variacao,
        vmax=max_variacao
    )
    colormap.caption = 'Variação Altimétrica (m)'
    m.add_child(colormap)

# Adicionar heatmap
heat_data = [[row['Latitude'], row['Longitude'], row['variacao_altimetrica']] 
             for _, row in df.iterrows() if pd.notna(row['variacao_altimetrica'])]

if heat_data:
    HeatMap(
        heat_data,
        name='Variação Altimétrica',
        min_opacity=0.3,
        max_val=df['variacao_altimetrica'].quantile(0.95),
        radius=15,
        blur=15,
        gradient={0.4: 'blue', 0.65: 'lime', 1: 'red'}
    ).add_to(fg_heatmap)

# Processar todos os pontos
for index, row in df.iterrows():
    current_lat = row['Latitude']
    current_lon = row['Longitude']
    
    altitude_ponto_val = row[ALTITUDE_PONTO_COL]
    altitude_ponto_display = f"{altitude_ponto_val} {UNIDADE_ALTITUDE}" if pd.notna(altitude_ponto_val) else "N/A"
    
    # Informações das curvas associadas
    altitude_l1_val = row[ALTITUDE_LINHA1_COL]
    id_l1_val = row[ID_LINHA1_COL]
    linha1_elev_display = f"{altitude_l1_val} {UNIDADE_ALTITUDE}" if pd.notna(altitude_l1_val) else "N/A"
    linha1_id_display = str(id_l1_val) if pd.notna(id_l1_val) else "N/A"

    altitude_l2_val = row[ALTITUDE_LINHA2_COL]
    id_l2_val = row[ID_LINHA2_COL]
    linha2_elev_display = f"{altitude_l2_val} {UNIDADE_ALTITUDE}" if pd.notna(altitude_l2_val) else "N/A"
    linha2_id_display = str(id_l2_val) if pd.notna(id_l2_val) else "N/A"
    
    variacao_val = row['variacao_altimetrica'] if 'variacao_altimetrica' in row else 0
    variacao_display = f"{variacao_val:.1f} {UNIDADE_ALTITUDE}" if pd.notna(variacao_val) else "N/A"

    # Popup para todos os pontos
    popup_html_marker = f"""
    <b>Ponto {index}</b><br>
    Variação Altimétrica: <b>{variacao_display}</b><br>
    Altitude do Ponto: {altitude_ponto_display}<br>
    <hr style="margin: 5px 0;">
    <b>Curvas de Nível Associadas:</b><br>
    <u>1ª Mais Próxima:</u><br>
    &nbsp;&nbsp;ID: {linha1_id_display}<br>
    &nbsp;&nbsp;Elevação: {linha1_elev_display}<br>
    <u>2ª Mais Próxima:</u><br>
    &nbsp;&nbsp;ID: {linha2_id_display}<br>
    &nbsp;&nbsp;Elevação: {linha2_elev_display}
    """

    # Adicionar marcador para todos os pontos
    folium.CircleMarker(
        location=[current_lat, current_lon],
        radius=3,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.5,
        popup=folium.Popup(popup_html_marker, max_width=400),
        tooltip=f"Ponto {index} (Variação: {variacao_display})"
    ).add_to(fg_pontos_todos)
    
    # Adicionar geometrias das curvas de nível
    adicionar_geometria_linha(row['linha1_geometry'], fg_curva1_todas, 'blue', 
                              f"Curva Nível 1", altitude_l1_val, id_l1_val)
    adicionar_geometria_linha(row['linha2_geometry'], fg_curva2_todas, 'green', 
                              f"Curva Nível 2", altitude_l2_val, id_l2_val)

# Adicionar pontos de alta variação
for index, row in top_variacoes.iterrows():
    current_lat = row['Latitude']
    current_lon = row['Longitude']
    variacao = row['variacao_altimetrica']
    
    # Popup detalhado para alta variação
    popup_html = f"""
    <b>Ponto {index} - Alta Variação</b><br>
    Variação Altimétrica: <b>{variacao:.1f} m</b><br>
    <hr>
    <b>Curva 1:</b> {row[ALTITUDE_LINHA1_COL]} m (ID: {row[ID_LINHA1_COL]})<br>
    <b>Curva 2:</b> {row[ALTITUDE_LINHA2_COL]} m (ID: {row[ID_LINHA2_COL]})<br>
    <b>Diferença:</b> {abs(row[ALTITUDE_LINHA1_COL] - row[ALTITUDE_LINHA2_COL]):.1f} m
    """
    
    # Adicionar marcador especial
    folium.CircleMarker(
        location=[current_lat, current_lon],
        radius=8 + (variacao / 5),  # Tamanho proporcional à variação
        color=colormap(variacao),
        fill=True,
        fill_color=colormap(variacao),
        fill_opacity=0.7,
        popup=folium.Popup(popup_html, max_width=300),
        tooltip=f"Variação: {variacao:.1f} m"
    ).add_to(fg_variacoes)

# ==============================================================================
# FINALIZAR E SALVAR O MAPA
# ==============================================================================

# Adicionar controle de camadas
LayerControl(collapsed=False).add_to(m)

# Adicionar título
title_html = '''
     <h3 align="center" style="font-size:16px"><b>Mapa de Variação Altimétrica</b></h3>
     <p align="center">Pontos vermelhos: maiores variações entre curvas de nível</p>
     '''
m.get_root().html.add_child(folium.Element(title_html))

# Salvar mapa
m.save(OUTPUT_MAP_FILE)
print(f"\nMapa salvo como '{OUTPUT_MAP_FILE}'.")
print(f"Total de pontos processados: {len(df)}")
print(f"Pontos com maior variação destacados: {TOP_N_PONTOS}")
print(f"Máxima variação encontrada: {df['variacao_altimetrica'].max():.1f} m")
# Out:
# Centro do mapa: Lat: -25.472152698921207, Lon: -49.25169232440742
# /tmp/ipykernel_7858/298245317.py:171: UserWarning: The `max_val` parameter is no longer necessary. The largest intensity is calculated automatically.
#   HeatMap(
# Mapa salvo como 'mapa_variacao_altimetrica.html'.
# Total de pontos processados: 560
# Pontos com maior variação destacados: 50
# Máxima variação encontrada: 2.0 m

# %%
import folium
from folium import FeatureGroup, LayerControl
# HeatMap não é mais usado, então a importação foi removida
import branca.colormap as cm
from shapely import wkt
import pandas as pd
from pyproj import Transformer, CRS

# ==============================================================================
# CONFIGURAÇÕES DO USUÁRIO - AJUSTE CONFORME NECESSÁRIO
# ==============================================================================

SOURCE_EPSG = "EPSG:31982"
TARGET_EPSG = "EPSG:4326"

# Nomes das colunas de ATRIBUTOS no seu arquivo CSV
ALTITUDE_PONTO_COL = 'altimetria_interpolada'
ALTITUDE_LINHA1_COL = 'linha1_elevation'
ALTITUDE_LINHA2_COL = 'linha2_elevation'
ID_LINHA1_COL = 'linha1_gid'
ID_LINHA2_COL = 'linha2_gid'
UNIDADE_ALTITUDE = "m"

# Configurações para destaque de variação altimétrica
COR_BAIXA_VARIACAO = 'green'
COR_ALTA_VARIACAO = 'red'

# ATENÇÃO: Assumindo que seu DataFrame já está carregado na variável 'resultado_copia'
# Se estiver lendo de um CSV, descomente a linha abaixo e ajuste o nome do arquivo
# FILE_PATH_CSV = 'resultado1.csv'
OUTPUT_MAP_FILE = 'mapa_variacao_altimetrica.html'
# ==============================================================================

# Criar transformador de coordenadas
try:
    transformer = Transformer.from_crs(CRS.from_string(SOURCE_EPSG), CRS.from_string(TARGET_EPSG), always_xy=True)
except Exception as e:
    print(f"Erro ao criar o transformador de coordenadas: {e}")
    exit()

# Copia o DataFrame da variável existente no seu ambiente
# Se for ler de um arquivo, use: df = pd.read_csv(FILE_PATH_CSV)
df = resultado_copia.copy()

if df.empty:
    print("O DataFrame está vazio.")
    exit()

# Verificar colunas obrigatórias
required_columns = ['Latitude', 'Longitude',
                    'linha1_geometry', 'linha2_geometry',
                    ALTITUDE_PONTO_COL, ALTITUDE_LINHA1_COL, ALTITUDE_LINHA2_COL,
                    ID_LINHA1_COL, ID_LINHA2_COL]

missing_cols = [col for col in required_columns if col not in df.columns]
if missing_cols:
    print(f"Erro: Colunas obrigatórias não encontradas: {', '.join(missing_cols)}")
    print(f"Colunas existentes: {df.columns.tolist()}")
    exit()

# Calcular variação altimétrica
df['variacao_altimetrica'] = abs(df[ALTITUDE_LINHA1_COL] - df[ALTITUDE_LINHA2_COL])

# Criar mapa
map_center_latitude = df['Latitude'].mean()
map_center_longitude = df['Longitude'].mean()
print(f"Centro do mapa: Lat: {map_center_latitude}, Lon: {map_center_longitude}")

m = folium.Map(location=[map_center_latitude, map_center_longitude],
               zoom_start=12,
               tiles='OpenStreetMap')

# ==============================================================================
# FUNÇÃO PARA ADICIONAR GEOMETRIAS DE LINHA (sem alterações)
# ==============================================================================
def adicionar_geometria_linha(wkt_string, feature_group, cor_linha, nome_camada_debug, altitude_valor, id_linha_valor=None):
    if pd.isna(wkt_string) or not str(wkt_string).strip():
        return

    altitude_display = f"{altitude_valor} {UNIDADE_ALTITUDE}" if pd.notna(altitude_valor) else "N/A"
    id_display = f"ID: {id_linha_valor}" if pd.notna(id_linha_valor) else "ID: N/A"

    popup_text_linha = f"Curva de Nível<br>{id_display}<br>Altitude: {altitude_display}"
    tooltip_text_linha = f"{id_display}, Alt: {altitude_display}"

    try:
        geom = wkt.loads(str(wkt_string))
    except Exception as e:
        return

    if geom.is_empty:
        return

    linhas_para_plotar_orig = []
    if geom.geom_type == 'LineString':
        linhas_para_plotar_orig.append(geom)
    elif geom.geom_type == 'MultiLineString':
        linhas_para_plotar_orig.extend(list(geom.geoms))
    else:
        return

    for linha_orig in linhas_para_plotar_orig:
        if linha_orig.is_empty:
            continue

        coords_originais_projetadas = list(linha_orig.coords)
        if not coords_originais_projetadas:
            continue

        coords_reprojetadas_folium = []
        try:
            for x_proj, y_proj in coords_originais_projetadas:
                lon_deg, lat_deg = transformer.transform(x_proj, y_proj)
                coords_reprojetadas_folium.append((lat_deg, lon_deg))
        except Exception as e:
            continue

        if not coords_reprojetadas_folium:
            continue

        folium.PolyLine(
            coords_reprojetadas_folium, color=cor_linha, weight=2.5, opacity=0.8,
            popup=folium.Popup(popup_text_linha, max_width=250),
            tooltip=tooltip_text_linha
        ).add_to(feature_group)

# ==============================================================================
# CONFIGURAR CAMADAS DO MAPA
# ==============================================================================

# Camada para todos os pontos (serão todos coloridos)
fg_pontos_todos = FeatureGroup(name='Todos os Pontos por Variação', show=True)
m.add_child(fg_pontos_todos)

# Camada para curvas de nível
fg_curva1_todas = FeatureGroup(name='Curvas de Nível 1', show=False)
m.add_child(fg_curva1_todas)
fg_curva2_todas = FeatureGroup(name='Curvas de Nível 2', show=False)
m.add_child(fg_curva2_todas)

# A CAMADA DO HEATMAP FOI REMOVIDA DAQUI

# ==============================================================================
# ADICIONAR DADOS AO MAPA
# ==============================================================================

# Criar colormap para as variações de verde a vermelho
if df['variacao_altimetrica'].notna().any():
    min_variacao = df['variacao_altimetrica'].min()
    max_variacao = df['variacao_altimetrica'].max()
    colormap = cm.LinearColormap(
        [COR_BAIXA_VARIACAO, COR_ALTA_VARIACAO],
        vmin=min_variacao,
        vmax=max_variacao
    )
    colormap.caption = 'Variação Altimétrica (m)'
    m.add_child(colormap)

# O BLOCO DE CÓDIGO DO HEATMAP FOI REMOVIDO DAQUI

# Processar e adicionar TODOS os pontos ao mapa, já coloridos
for index, row in df.iterrows():
    current_lat = row['Latitude']
    current_lon = row['Longitude']

    altitude_ponto_val = row[ALTITUDE_PONTO_COL]
    altitude_ponto_display = f"{altitude_ponto_val} {UNIDADE_ALTITUDE}" if pd.notna(altitude_ponto_val) else "N/A"

    altitude_l1_val = row[ALTITUDE_LINHA1_COL]
    id_l1_val = row[ID_LINHA1_COL]
    linha1_elev_display = f"{altitude_l1_val} {UNIDADE_ALTITUDE}" if pd.notna(altitude_l1_val) else "N/A"
    linha1_id_display = str(id_l1_val) if pd.notna(id_l1_val) else "N/A"

    altitude_l2_val = row[ALTITUDE_LINHA2_COL]
    id_l2_val = row[ID_LINHA2_COL]
    linha2_elev_display = f"{altitude_l2_val} {UNIDADE_ALTITUDE}" if pd.notna(altitude_l2_val) else "N/A"
    linha2_id_display = str(id_l2_val) if pd.notna(id_l2_val) else "N/A"

    variacao_val = row['variacao_altimetrica']
    variacao_display = f"{variacao_val:.1f} {UNIDADE_ALTITUDE}" if pd.notna(variacao_val) else "N/A"

    # Popup para todos os pontos
    popup_html_marker = f"""
    <b>Ponto {index}</b><br>
    Variação Altimétrica: <b>{variacao_display}</b><br>
    Altitude do Ponto: {altitude_ponto_display}<br>
    <hr style="margin: 5px 0;">
    <b>Curvas de Nível Associadas:</b><br>
    <u>1ª Mais Próxima:</u><br>
    &nbsp;&nbsp;ID: {linha1_id_display}<br>
    &nbsp;&nbsp;Elevação: {linha1_elev_display}<br>
    <u>2ª Mais Próxima:</u><br>
    &nbsp;&nbsp;ID: {linha2_id_display}<br>
    &nbsp;&nbsp;Elevação: {linha2_elev_display}
    """

    # Adicionar marcador para todos os pontos, usando a cor da variação
    folium.CircleMarker(
        location=[current_lat, current_lon],
        radius=5,
        color=colormap(variacao_val),
        fill=True,
        fill_color=colormap(variacao_val),
        fill_opacity=0.7,
        popup=folium.Popup(popup_html_marker, max_width=400),
        tooltip=f"Ponto {index} (Variação: {variacao_display})"
    ).add_to(fg_pontos_todos)

    # Adicionar geometrias das curvas de nível
    adicionar_geometria_linha(row['linha1_geometry'], fg_curva1_todas, 'blue',
                              f"Curva Nível 1", altitude_l1_val, id_l1_val)
    adicionar_geometria_linha(row['linha2_geometry'], fg_curva2_todas, 'green',
                              f"Curva Nível 2", altitude_l2_val, id_l2_val)

# ==============================================================================
# FINALIZAR E SALVAR O MAPA
# ==============================================================================

# Adicionar controle de camadas
LayerControl(collapsed=False).add_to(m)

# Adicionar título
title_html = '''
     <h3 align="center" style="font-size:16px"><b>Mapa de Variação Altimétrica</b></h3>
     <p align="center">Cada ponto é colorido pela sua variação (Verde: Baixa, Vermelho: Alta)</p>
     '''
m.get_root().html.add_child(folium.Element(title_html))

# Salvar mapa
m.save(OUTPUT_MAP_FILE)
print(f"\nMapa salvo como '{OUTPUT_MAP_FILE}'.")
print(f"Total de pontos processados: {len(df)}")
print(f"Máxima variação encontrada: {df['variacao_altimetrica'].max():.1f} m")
# Out:
# Centro do mapa: Lat: -25.472152698921207, Lon: -49.25169232440742
#
# Mapa salvo como 'mapa_variacao_altimetrica.html'.
# Total de pontos processados: 560
# Máxima variação encontrada: 2.0 m
